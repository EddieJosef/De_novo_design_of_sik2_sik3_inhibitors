# %%
# !sudo apt-get update
# !sudo apt-get install ipython3 python3-setuptools python3-pip
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,463 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [50.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,834 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,070 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,796 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,343 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,742 kB]
# Fetched 9,532 kB in 3s (3,783 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-lyx libimagequant0 liblbfgsb0 libraqm0 libxsimd-dev
#   python-matplotlib-data python3-appdirs python3-attr python3-backcall
#   python3-beniget python3-brotli python3-bs4 python3-chardet python3-cycler
#   python3-dateutil python3-decorator python3-fonttools python3-fs python3-gast
#   python3-html5lib python3-ipython python3-jedi python3-kiwisolver
#   python3-lxml python3-lz4 python3-matplotlib python3-matplotlib-inline
#   python3-mpmath python3-numpy python3-olefile python3-packaging python3-parso
#   python3-pexpect python3-pickleshare python3-pil python3-pil.imagetk
#   python3-ply python3-prompt-toolkit python3-ptyprocess python3-pygments
#   python3-pythran python3-scipy python3-soupsieve python3-sympy
#   python3-traitlets python3-tz python3-ufolib2 python3-unicodedata2
#   python3-wcwidth python3-webencodings python3-wheel unicode-data
# Suggested packages:
#   libxsimd-doc python-attr-doc python-cycler-doc python3-genshi
#   python-ipython-doc python-lxml-doc dvipng fonts-staypuft ghostscript
#   gir1.2-gtk-3.0 inkscape librsvg2-common python-matplotlib-doc
#   python3-cairocffi python3-gi-cairo python3-gobject python3-pyqt5 python3-sip
#   python3-tornado texlive-extra-utils texlive-latex-extra python-mpmath-doc
#   python3-gmpy2 python-numpy-doc python3-pytest python-pexpect-doc
#   python-pil-doc python-ply-doc python-pygments-doc ttf-bitstream-vera
#   python-scipy-doc python-setuptools-doc texlive-fonts-extra python-sympy-doc
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-lyx ipython3 libimagequant0 liblbfgsb0 libraqm0
#   libxsimd-dev python-matplotlib-data python3-appdirs python3-attr
#   python3-backcall python3-beniget python3-brotli python3-bs4 python3-chardet
#   python3-cycler python3-dateutil python3-decorator python3-fonttools
#   python3-fs python3-gast python3-html5lib python3-ipython python3-jedi
#   python3-kiwisolver python3-lxml python3-lz4 python3-matplotlib
#   python3-matplotlib-inline python3-mpmath python3-numpy python3-olefile
#   python3-packaging python3-parso python3-pexpect python3-pickleshare
#   python3-pil python3-pil.imagetk python3-pip python3-ply
#   python3-prompt-toolkit python3-ptyprocess python3-pygments python3-pythran
#   python3-scipy python3-setuptools python3-soupsieve python3-sympy
#   python3-traitlets python3-tz python3-ufolib2 python3-unicodedata2
#   python3-wcwidth python3-webencodings python3-wheel unicode-data
# 0 upgraded, 56 newly installed, 0 to remove and 43 not upgraded.
# Need to get 49.8 MB of archives.
# After this operation, 226 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lyx all 2.3.6-1 [159 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-backcall all 0.2.0-2 [11.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-decorator all 4.4.2-0ubuntu1 [10.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-parso all 0.8.1-1 [64.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-jedi all 0.18.0-1 [615 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-traitlets all 5.1.1-1 [81.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-matplotlib-inline all 0.1.3-1 [8,070 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-ptyprocess all 0.7.0-3 [15.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pexpect all 4.8.0-2ubuntu1 [46.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-pickleshare all 0.7.5-5 [7,570 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-wcwidth all 0.2.5+dfsg1-1 [21.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-prompt-toolkit all 3.0.28-1 [251 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pygments all 2.11.2+dfsg-2 [750 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-ipython all 7.31.1-1 [534 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ipython3 all 7.31.1-1 [5,238 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimagequant0 amd64 2.17.0-1 [34.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblbfgsb0 amd64 3.0+dfsg.3-10 [29.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraqm0 amd64 0.7.0-4ubuntu1 [11.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxsimd-dev amd64 7.6.0-2 [108 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-matplotlib-data all 3.5.1-2build1 [2,942 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-appdirs all 1.4.4-2 [11.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-attr all 21.2.0-1 [44.0 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-gast all 0.5.2-2 [9,394 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-beniget all 0.4.1-2 [9,904 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-brotli amd64 1.0.9-2build6 [319 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-soupsieve all 2.3.1-1 [33.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-bs4 all 4.10.0-2 [79.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-chardet all 4.0.0-1 [98.0 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-cycler all 0.11.0-1 [8,156 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-dateutil all 2.8.1-6 [78.4 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-ply all 3.11-5 [47.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-pythran amd64 0.10.0+ds2-1 [423 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-scipy amd64 1.8.0-1exp2ubuntu1 [14.7 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-ufolib2 all 0.13.1+dfsg1-1 [32.2 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-mpmath all 1.2.1-2 [419 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-sympy all 1.9-1 [4,312 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-tz all 2022.1-1ubuntu0.22.04.1 [30.7 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-fs all 2.4.12-1 [84.9 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-lxml amd64 4.8.0-1build1 [1,150 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-lz4 amd64 3.1.3+dfsg-1build3 [33.3 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-unicodedata2 amd64 14.0.0+ds-8 [376 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 unicode-data all 14.0.0-1.1 [8,206 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-fonttools amd64 4.29.1-2build1 [810 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-webencodings all 0.5.1-4 [11.8 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-html5lib all 1.1-3 [87.0 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-kiwisolver amd64 1.3.2-1build1 [48.0 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-pil amd64 9.0.1-1ubuntu0.2 [419 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pil.imagetk amd64 9.0.1-1ubuntu0.2 [9,616 B]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-packaging all 21.3-1 [30.7 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-matplotlib amd64 3.5.1-2build1 [5,937 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-olefile all 0.46-3 [33.8 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.1 [339 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.4 [1,305 kB]
# Fetched 49.8 MB in 11s (4,609 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 56.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../01-fonts-lyx_2.3.6-1_all.deb ...
# Unpacking fonts-lyx (2.3.6-1) ...
# Selecting previously unselected package python3-backcall.
# Preparing to unpack .../02-python3-backcall_0.2.0-2_all.deb ...
# Unpacking python3-backcall (0.2.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../03-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../04-python3-parso_0.8.1-1_all.deb ...
# Unpacking python3-parso (0.8.1-1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../05-python3-jedi_0.18.0-1_all.deb ...
# Unpacking python3-jedi (0.18.0-1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../06-python3-traitlets_5.1.1-1_all.deb ...
# Unpacking python3-traitlets (5.1.1-1) ...
# Selecting previously unselected package python3-matplotlib-inline.
# Preparing to unpack .../07-python3-matplotlib-inline_0.1.3-1_all.deb ...
# Unpacking python3-matplotlib-inline (0.1.3-1) ...
# Selecting previously unselected package python3-ptyprocess.
# Preparing to unpack .../08-python3-ptyprocess_0.7.0-3_all.deb ...
# Unpacking python3-ptyprocess (0.7.0-3) ...
# Selecting previously unselected package python3-pexpect.
# Preparing to unpack .../09-python3-pexpect_4.8.0-2ubuntu1_all.deb ...
# Unpacking python3-pexpect (4.8.0-2ubuntu1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../10-python3-pickleshare_0.7.5-5_all.deb ...
# Unpacking python3-pickleshare (0.7.5-5) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../11-python3-wcwidth_0.2.5+dfsg1-1_all.deb ...
# Unpacking python3-wcwidth (0.2.5+dfsg1-1) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../12-python3-prompt-toolkit_3.0.28-1_all.deb ...
# Unpacking python3-prompt-toolkit (3.0.28-1) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../13-python3-pygments_2.11.2+dfsg-2_all.deb ...
# Unpacking python3-pygments (2.11.2+dfsg-2) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../14-python3-ipython_7.31.1-1_all.deb ...
# Unpacking python3-ipython (7.31.1-1) ...
# Selecting previously unselected package ipython3.
# Preparing to unpack .../15-ipython3_7.31.1-1_all.deb ...
# Unpacking ipython3 (7.31.1-1) ...
# Selecting previously unselected package libimagequant0:amd64.
# Preparing to unpack .../16-libimagequant0_2.17.0-1_amd64.deb ...
# Unpacking libimagequant0:amd64 (2.17.0-1) ...
# Selecting previously unselected package liblbfgsb0:amd64.
# Preparing to unpack .../17-liblbfgsb0_3.0+dfsg.3-10_amd64.deb ...
# Unpacking liblbfgsb0:amd64 (3.0+dfsg.3-10) ...
# Selecting previously unselected package libraqm0:amd64.
# Preparing to unpack .../18-libraqm0_0.7.0-4ubuntu1_amd64.deb ...
# Unpacking libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Selecting previously unselected package libxsimd-dev:amd64.
# Preparing to unpack .../19-libxsimd-dev_7.6.0-2_amd64.deb ...
# Unpacking libxsimd-dev:amd64 (7.6.0-2) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../20-python-matplotlib-data_3.5.1-2build1_all.deb ...
# Unpacking python-matplotlib-data (3.5.1-2build1) ...
# Selecting previously unselected package python3-appdirs.
# Preparing to unpack .../21-python3-appdirs_1.4.4-2_all.deb ...
# Unpacking python3-appdirs (1.4.4-2) ...
# Selecting previously unselected package python3-attr.
# Preparing to unpack .../22-python3-attr_21.2.0-1_all.deb ...
# Unpacking python3-attr (21.2.0-1) ...
# Selecting previously unselected package python3-gast.
# Preparing to unpack .../23-python3-gast_0.5.2-2_all.deb ...
# Unpacking python3-gast (0.5.2-2) ...
# Selecting previously unselected package python3-beniget.
# Preparing to unpack .../24-python3-beniget_0.4.1-2_all.deb ...
# Unpacking python3-beniget (0.4.1-2) ...
# Selecting previously unselected package python3-brotli.
# Preparing to unpack .../25-python3-brotli_1.0.9-2build6_amd64.deb ...
# Unpacking python3-brotli (1.0.9-2build6) ...
# Selecting previously unselected package python3-soupsieve.
# Preparing to unpack .../26-python3-soupsieve_2.3.1-1_all.deb ...
# Unpacking python3-soupsieve (2.3.1-1) ...
# Selecting previously unselected package python3-bs4.
# Preparing to unpack .../27-python3-bs4_4.10.0-2_all.deb ...
# Unpacking python3-bs4 (4.10.0-2) ...
# Selecting previously unselected package python3-chardet.
# Preparing to unpack .../28-python3-chardet_4.0.0-1_all.deb ...
# Unpacking python3-chardet (4.0.0-1) ...
# Selecting previously unselected package python3-cycler.
# Preparing to unpack .../29-python3-cycler_0.11.0-1_all.deb ...
# Unpacking python3-cycler (0.11.0-1) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../30-python3-dateutil_2.8.1-6_all.deb ...
# Unpacking python3-dateutil (2.8.1-6) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../31-python3-numpy_1%3a1.21.5-1ubuntu22.04.1_amd64.deb ...
# Unpacking python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Selecting previously unselected package python3-ply.
# Preparing to unpack .../32-python3-ply_3.11-5_all.deb ...
# Unpacking python3-ply (3.11-5) ...
# Selecting previously unselected package python3-pythran.
# Preparing to unpack .../33-python3-pythran_0.10.0+ds2-1_amd64.deb ...
# Unpacking python3-pythran (0.10.0+ds2-1) ...
# Selecting previously unselected package python3-scipy.
# Preparing to unpack .../34-python3-scipy_1.8.0-1exp2ubuntu1_amd64.deb ...
# Unpacking python3-scipy (1.8.0-1exp2ubuntu1) ...
# Selecting previously unselected package python3-ufolib2.
# Preparing to unpack .../35-python3-ufolib2_0.13.1+dfsg1-1_all.deb ...
# Unpacking python3-ufolib2 (0.13.1+dfsg1-1) ...
# Selecting previously unselected package python3-mpmath.
# Preparing to unpack .../36-python3-mpmath_1.2.1-2_all.deb ...
# Unpacking python3-mpmath (1.2.1-2) ...
# Selecting previously unselected package python3-sympy.
# Preparing to unpack .../37-python3-sympy_1.9-1_all.deb ...
# Unpacking python3-sympy (1.9-1) ...
# Selecting previously unselected package python3-tz.
# Preparing to unpack .../38-python3-tz_2022.1-1ubuntu0.22.04.1_all.deb ...
# Unpacking python3-tz (2022.1-1ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-fs.
# Preparing to unpack .../39-python3-fs_2.4.12-1_all.deb ...
# Unpacking python3-fs (2.4.12-1) ...
# Selecting previously unselected package python3-lxml:amd64.
# Preparing to unpack .../40-python3-lxml_4.8.0-1build1_amd64.deb ...
# Unpacking python3-lxml:amd64 (4.8.0-1build1) ...
# Selecting previously unselected package python3-lz4.
# Preparing to unpack .../41-python3-lz4_3.1.3+dfsg-1build3_amd64.deb ...
# Unpacking python3-lz4 (3.1.3+dfsg-1build3) ...
# Selecting previously unselected package python3-unicodedata2.
# Preparing to unpack .../42-python3-unicodedata2_14.0.0+ds-8_amd64.deb ...
# Unpacking python3-unicodedata2 (14.0.0+ds-8) ...
# Selecting previously unselected package unicode-data.
# Preparing to unpack .../43-unicode-data_14.0.0-1.1_all.deb ...
# Unpacking unicode-data (14.0.0-1.1) ...
# Selecting previously unselected package python3-fonttools.
# Preparing to unpack .../44-python3-fonttools_4.29.1-2build1_amd64.deb ...
# Unpacking python3-fonttools (4.29.1-2build1) ...
# Selecting previously unselected package python3-webencodings.
# Preparing to unpack .../45-python3-webencodings_0.5.1-4_all.deb ...
# Unpacking python3-webencodings (0.5.1-4) ...
# Selecting previously unselected package python3-html5lib.
# Preparing to unpack .../46-python3-html5lib_1.1-3_all.deb ...
# Unpacking python3-html5lib (1.1-3) ...
# Selecting previously unselected package python3-kiwisolver.
# Preparing to unpack .../47-python3-kiwisolver_1.3.2-1build1_amd64.deb ...
# Unpacking python3-kiwisolver (1.3.2-1build1) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../48-python3-pil_9.0.1-1ubuntu0.2_amd64.deb ...
# Unpacking python3-pil:amd64 (9.0.1-1ubuntu0.2) ...
# Selecting previously unselected package python3-pil.imagetk:amd64.
# Preparing to unpack .../49-python3-pil.imagetk_9.0.1-1ubuntu0.2_amd64.deb ...
# Unpacking python3-pil.imagetk:amd64 (9.0.1-1ubuntu0.2) ...
# Selecting previously unselected package python3-packaging.
# Preparing to unpack .../50-python3-packaging_21.3-1_all.deb ...
# Unpacking python3-packaging (21.3-1) ...
# Selecting previously unselected package python3-matplotlib.
# Preparing to unpack .../51-python3-matplotlib_3.5.1-2build1_amd64.deb ...
# Unpacking python3-matplotlib (3.5.1-2build1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../52-python3-olefile_0.46-3_all.deb ...
# Unpacking python3-olefile (0.46-3) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../53-python3-setuptools_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../54-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../55-python3-pip_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3-attr (21.2.0-1) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-backcall (0.2.0-2) ...
# Setting up python3-parso (0.8.1-1) ...
# Setting up python3-lz4 (3.1.3+dfsg-1build3) ...
# Setting up python3-unicodedata2 (14.0.0+ds-8) ...
# Setting up fonts-lyx (2.3.6-1) ...
# Setting up python3-olefile (0.46-3) ...
# Setting up python3-ply (3.11-5) ...
# Setting up python3-gast (0.5.2-2) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up python3-webencodings (0.5.1-4) ...
# Setting up python3-tz (2022.1-1ubuntu0.22.04.1) ...
# Setting up unicode-data (14.0.0-1.1) ...
# Setting up python3-beniget (0.4.1-2) ...
# Setting up libxsimd-dev:amd64 (7.6.0-2) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.11.2+dfsg-2) ...
# Setting up python3-packaging (21.3-1) ...
# Setting up python3-chardet (4.0.0-1) ...
# Setting up python3-wcwidth (0.2.5+dfsg1-1) ...
# Setting up python3-brotli (1.0.9-2build6) ...
# Setting up libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Setting up python3-cycler (0.11.0-1) ...
# Setting up libimagequant0:amd64 (2.17.0-1) ...
# Setting up python3-kiwisolver (1.3.2-1build1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3-html5lib (1.1-3) ...
# Setting up python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Setting up python3-pickleshare (0.7.5-5) ...
# Setting up python3-pythran (0.10.0+ds2-1) ...
# Setting up python3-lxml:amd64 (4.8.0-1build1) ...
# Setting up python3-traitlets (5.1.1-1) ...
# Setting up python3-dateutil (2.8.1-6) ...
# Setting up python3-mpmath (1.2.1-2) ...
# Setting up python-matplotlib-data (3.5.1-2build1) ...
# Setting up python3-appdirs (1.4.4-2) ...
# Setting up python3-soupsieve (2.3.1-1) ...
# Setting up liblbfgsb0:amd64 (3.0+dfsg.3-10) ...
# Setting up python3-ptyprocess (0.7.0-3) ...
# Setting up python3-prompt-toolkit (3.0.28-1) ...
# Setting up python3-sympy (1.9-1) ...
# Setting up python3-scipy (1.8.0-1exp2ubuntu1) ...
# Setting up python3-jedi (0.18.0-1) ...
# Setting up python3-bs4 (4.10.0-2) ...
# Setting up python3-matplotlib-inline (0.1.3-1) ...
# Setting up python3-fs (2.4.12-1) ...
# Setting up python3-pexpect (4.8.0-2ubuntu1) ...
# Setting up python3-ipython (7.31.1-1) ...
# Setting up ipython3 (7.31.1-1) ...
# Setting up python3-pil:amd64 (9.0.1-1ubuntu0.2) ...
# Setting up python3-pil.imagetk:amd64 (9.0.1-1ubuntu0.2) ...
# Setting up python3-ufolib2 (0.13.1+dfsg1-1) ...
# Setting up python3-fonttools (4.29.1-2build1) ...
# Setting up python3-matplotlib (3.5.1-2build1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
#only needed for colabfold
# !pip install pyrosettacolabsetup py3dmol git+https://github.com/RosettaCommons/pyrosetta_viewer3d.git
import pyrosettacolabsetup; pyrosettacolabsetup.install_pyrosetta()
# Out:
# Collecting git+https://github.com/RosettaCommons/pyrosetta_viewer3d.git
#   Cloning https://github.com/RosettaCommons/pyrosetta_viewer3d.git to /tmp/pip-req-build-sy5ub_xv
#   Running command git clone --filter=blob:none --quiet https://github.com/RosettaCommons/pyrosetta_viewer3d.git /tmp/pip-req-build-sy5ub_xv
#   Resolved https://github.com/RosettaCommons/pyrosetta_viewer3d.git to commit f467481e8c8cd567fbc2620173e008814b731d72
#   Preparing metadata (setup.py) ... done
# Collecting pyrosettacolabsetup
#   Downloading pyrosettacolabsetup-1.0.7-py3-none-any.whl (4.8 kB)
# Collecting py3dmol
#   Downloading py3Dmol-2.0.4-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (23.2.0)
# Requirement already satisfied: bokeh>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (3.3.4)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (7.7.1)
# Collecting jupyter>=1.0.0 (from viewer3d==1.0.0)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (3.7.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (3.1.3)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (1.25.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (23.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (2023.10.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (3.0.10)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->viewer3d==1.0.0) (6.5.5)
# Collecting qtconsole (from jupyter>=1.0.0->viewer3d==1.0.0)
#   Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->viewer3d==1.0.0) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->viewer3d==1.0.0) (6.5.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (2.8.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->viewer3d==1.0.0) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=2.4.2->viewer3d==1.0.0) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh>=2.4.2->viewer3d==1.0.0) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->viewer3d==1.0.0) (1.16.0)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (5.7.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (5.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (1.2.1)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter>=1.0.0->viewer3d==1.0.0)
#   Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.2.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (4.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.5.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.17.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (2.21)
# Building wheels for collected packages: viewer3d
#   Building wheel for viewer3d (setup.py) ... done
#   Created wheel for viewer3d: filename=viewer3d-1.0.0-py3-none-any.whl size=34766 sha256=f748f745664168ee1b96b252d1f18a18e1c3bb586c8c6513f014e4a6a5b0947e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u3lvku0p/wheels/b2/1d/4e/ab6446ec63fbf5af3d53b06df7a766ee7bd238e8544636c222
# Successfully built viewer3d
# Installing collected packages: pyrosettacolabsetup, py3dmol, qtpy, qtconsole, jupyter, viewer3d
# Successfully installed jupyter-1.0.0 py3dmol-2.0.4 pyrosettacolabsetup-1.0.7 qtconsole-5.5.1 qtpy-2.4.1 viewer3d-1.0.0
# Mounted at /content/google_drive
# Looking for compatible PyRosetta wheel file at google-drive/PyRosetta/colab.bin//wheels...
# Found compatible wheel: /content/google_drive/MyDrive/PyRosetta/colab.bin/wheels//content/google_drive/MyDrive/PyRosetta/colab.bin/wheels/pyrosetta-2024.1+release.00b79147e63-cp310-cp310-linux_x86_64.whl

# %%
import pyrosetta; # import the pyrosetta package to access functionality
import pyrosetta.distributed.io as io
pyrosetta.init() # must be called before any other pyrosetta functions. Can accept command line flags
# Out:
# PyRosetta-4 2023 [Rosetta PyRosetta4.MinSizeRel.python310.ubuntu 2024.01+release.00b79147e63be743438188f93a3f069ca75106d6 2023-12-25T16:35:48] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.MinSizeRel.python310.ubuntu r366 2024.01+release.00b79147e63 00b79147e63be743438188f93a3f069ca75106d6 http://www.pyrosetta.org 2023-12-25T16:35:48
# core.init: command: PyRosetta -ex1 -ex2aro -database /usr/local/lib/python3.10/dist-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-340773806 seed_offset=0 real_seed=-340773806
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-340773806 RG_type=mt19937

# %%
# !python -m pip install fragmenstein
# Out:
# Collecting fragmenstein
#   Downloading Fragmenstein-0.14.7.tar.gz (625 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.0/626.0 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (2.31.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (1.25.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (1.11.4)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (1.5.3)
# Collecting pebble>=4.6.3 (from fragmenstein)
#   Downloading Pebble-5.0.6-py3-none-any.whl (30 kB)
# Collecting rdkit>=2022.3.2.1 (from fragmenstein)
#   Downloading rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 8.9 MB/s eta 0:00:00
# Collecting rdkit-to-params>=1.2.3 (from fragmenstein)
#   Downloading rdkit_to_params-1.2.8.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting molecular-rectifier>=0.1.10 (from fragmenstein)
#   Downloading molecular_rectifier-0.1.10.2.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting singledispatchmethod>=1.0 (from fragmenstein)
#   Downloading singledispatchmethod-1.0-py2.py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (4.9.0)
# Requirement already satisfied: matplotlib>=3.5.2 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (3.7.1)
# Collecting smallworld-api>=1.1 (from fragmenstein)
#   Downloading smallworld-api-1.1.4.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sqlitedict>=2.0.0 (from fragmenstein)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pandera>=0.17.2 (from fragmenstein)
#   Downloading pandera-0.18.0-py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 16.8 MB/s eta 0:00:00
# Collecting pandarallel>=1.6.5 (from fragmenstein)
#   Downloading pandarallel-1.6.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (2.8.2)
# Collecting dill>=0.3.1 (from pandarallel>=1.6.5->fragmenstein)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from pandarallel>=1.6.5->fragmenstein) (5.9.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->fragmenstein) (2023.4)
# Collecting multimethod (from pandera>=0.17.2->fragmenstein)
#   Downloading multimethod-1.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from pandera>=0.17.2->fragmenstein) (2.6.1)
# Collecting typeguard>=3.0.2 (from pandera>=0.17.2->fragmenstein)
#   Downloading typeguard-4.1.5-py3-none-any.whl (34 kB)
# Collecting typing-inspect>=0.6.0 (from pandera>=0.17.2->fragmenstein)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from pandera>=0.17.2->fragmenstein) (1.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (2024.2.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from smallworld-api>=1.1->fragmenstein) (7.34.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->fragmenstein) (1.16.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.6.0->pandera>=0.17.2->fragmenstein)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera>=0.17.2->fragmenstein) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera>=0.17.2->fragmenstein) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->smallworld-api>=1.1->fragmenstein) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->smallworld-api>=1.1->fragmenstein) (0.2.13)
# Building wheels for collected packages: fragmenstein, molecular-rectifier, pandarallel, rdkit-to-params, smallworld-api, sqlitedict
#   Building wheel for fragmenstein (setup.py) ... done
#   Created wheel for fragmenstein: filename=Fragmenstein-0.14.7-py3-none-any.whl size=826970 sha256=9af00f218ea0a3614f30049405bb1d7f62e7b49be6bf2ae567c71cd608a77209
#   Stored in directory: /root/.cache/pip/wheels/91/0d/35/9b08d0c6889f9217681f844bc3e432c1f8e40d974d7c78297c
#   Building wheel for molecular-rectifier (setup.py) ... done
#   Created wheel for molecular-rectifier: filename=molecular_rectifier-0.1.10.2-py3-none-any.whl size=18943 sha256=9b902c6fb16ef2f27e05962c91337d56d60ef5cc244d79110463666f598519d7
#   Stored in directory: /root/.cache/pip/wheels/18/fa/51/8e66e548653a353dc8dbdbb3cebf9148be632f26a622bafae1
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.5-py3-none-any.whl size=16672 sha256=68735385ea6f1bbfbcfb5e41dd9ca7493cfa0ed3b8b4598dc734321702ed3ba0
#   Stored in directory: /root/.cache/pip/wheels/50/4f/1e/34e057bb868842209f1623f195b74fd7eda229308a7352d47f
#   Building wheel for rdkit-to-params (setup.py) ... done
#   Created wheel for rdkit-to-params: filename=rdkit_to_params-1.2.8-py3-none-any.whl size=49683 sha256=1096c81508a79535d986404e1ee1d2f9d596ed5f75b659840361f9d7a1d98e4b
#   Stored in directory: /root/.cache/pip/wheels/cc/7e/41/a6e2a1fc1d8b7c647dc335278d92e01062927ba57995b16bdc
#   Building wheel for smallworld-api (setup.py) ... done
#   Created wheel for smallworld-api: filename=smallworld_api-1.1.4-py3-none-any.whl size=16005 sha256=b46248288ba65b065163f3332c44f9d62feedf36f0e2aadb4dcd1b7b58b6ea96
#   Stored in directory: /root/.cache/pip/wheels/f5/bb/70/973633116417bca247c85f26191ee0678ed6c69840319b3bf2
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=5a60f56ccdb0fcc07957e763339177bcdaf800caf8c62a4707a1e788242d2984
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built fragmenstein molecular-rectifier pandarallel rdkit-to-params smallworld-api sqlitedict
# Installing collected packages: sqlitedict, singledispatchmethod, typeguard, rdkit-to-params, rdkit, pebble, mypy-extensions, multimethod, dill, typing-inspect, molecular-rectifier, smallworld-api, pandera, pandarallel, fragmenstein
# Successfully installed dill-0.3.8 fragmenstein-0.14.7 molecular-rectifier-0.1.10.2 multimethod-1.11 mypy-extensions-1.0.0 pandarallel-1.6.5 pandera-0.18.0 pebble-5.0.6 rdkit-2023.9.5 rdkit-to-params-1.2.8 singledispatchmethod-1.0 smallworld-api-1.1.4 sqlitedict-2.1.0 typeguard-4.1.5 typing-inspect-0.9.0

# %%
from fragmenstein import Victor, Igor, Monster

# %%
import sys
sys.setrecursionlimit(250000)

# %%
# Original recursive function
def factorial(n):
    if n < 2:
        return 1
    return n * factorial(n - 1)

# Step 1: Convert recursive calls into tail calls
def factorial1a(n, acc=1):
    if n < 2:
        return 1 * acc
    return factorial1a(n - 1, acc * n)

# Step 2: Introduce a one-shot loop around the function body
def factorial1b(n, acc=1):
    while True:
        if n < 2:
            return 1 * acc
        return factorial1b(n - 1, acc * n)
        break

# Step 3: Convert tail calls into continue statements
def factorial1c(n, acc=1):
    while True:
        if n < 2:
            return 1 * acc
        (n, acc) = (n - 1, acc * n)
        continue
        break

# Step 4: Tidy the code and make it more idiomatic
def factorial1d(n, acc=1):
    while n > 1:
        (n, acc) = (n - 1, acc * n)
    return acc

# Testing the iterative version
print(factorial1d(5))  # Output: 120
# Out:
# 120

# %%
import csv
import logging
from fragmenstein import Victor
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from rdkit.Chem.Draw import MolsToGridImage

# Initialize PyRosetta
pyrosetta.init(extra_options='-no_optH false -mute all -ignore_unrecognized_res false -load_PDB_components false')

# Setup logging
logging.basicConfig(filename='victor_log.log', level=logging.INFO)
Victor.enable_logfile('victor_log.log', logging.INFO)


# Initialize list to store minimized SMILES and molecule data
minimized_smiles_list = []
molecule_data = []

# Initialize list to store 2D structures
mol_2d_structures = []

# Load the protein PDB file
protein_pdb_path = 'chain_B.pdb'

# Process reference molecule
reference_smile = 'CNc1ncc2cc(-c3ccc(-c4ncccc4F)cc3Cl)c(=O)n(C[C@H]3OC[C@H](N)CO3)c2n1'
reference_mol = Chem.AddHs(AllChem.MolFromSmiles(reference_smile))
AllChem.EmbedMolecule(reference_mol, AllChem.ETKDG())

# Define two SMILES strings
smiles1 = 'O=C(Cn1c(N2CCOCC2)nc2cc(Nc3ccc(F)cc3)ncc2c1=O)Nc1ccc(F)cn1'  # Replace with your first SMILES string
smiles2 = 'Cc1cccc(-c2ncc3c(=O)n(CC(=O)Nc4ccc(Cl)cn4)c(N4CCOCC4)nc3n2)c1'  # Replace with your second SMILES string
smiles_list = [smiles1, smiles2]

# Process each SMILES string using Victor
for i, smile in enumerate(smiles_list):
    mol = Chem.AddHs(AllChem.MolFromSmiles(smile))
    AllChem.EmbedMolecule(mol, AllChem.ETKDG())
    victor = Victor(hits=[mol], pdb_filename=protein_pdb_path)
    try:
        victor.combine()
    except Chem.AtomValenceException:
        logging.info(f'Atom valence exception occurred for molecule {i+1}, trying to rectify...')
        victor.rectify(collapse_rings=True, joining_cutoff=3.0)
        victor.combine()

    minimized_molecule = victor.minimized_mol
    mol_2d_structures.append(minimized_molecule)
    minimized_smiles = Chem.MolToSmiles(minimized_molecule)
    minimized_smiles_list.append(minimized_smiles)

    # Calculate Lipinski's descriptors
    mw = Descriptors.ExactMolWt(minimized_molecule)
    logp = Descriptors.MolLogP(minimized_molecule)
    hba = Descriptors.NumHAcceptors(minimized_molecule)
    hbd = Descriptors.NumHDonors(minimized_molecule)

    # Save and display molecule data
    output_file = f'minimized_merged_molecule_{i}.mol'
    AllChem.MolToMolFile(minimized_molecule, output_file)
    molecule_data.append([minimized_smiles, mw, logp, hba, hbd, output_file])
# Out:
# PyRosetta-4 2023 [Rosetta PyRosetta4.MinSizeRel.python310.ubuntu 2024.01+release.00b79147e63be743438188f93a3f069ca75106d6 2023-12-25T16:35:48] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.MinSizeRel.python310.ubuntu r366 2024.01+release.00b79147e63 00b79147e63be743438188f93a3f069ca75106d6 http://www.pyrosetta.org 2023-12-25T16:35:48
# core.init: command: PyRosetta -ex1 -ex2aro -no_optH false -mute all -ignore_unrecognized_res false -load_PDB_components false -database /usr/local/lib/python3.10/dist-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-129833148 seed_offset=0 real_seed=-129833148
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-129833148 RG_type=mt19937
# DEBUG:Fragmenstein:hit0 - harmonising warheads on hits in "first" mode
# DEBUG:Fragmenstein:Merging: ['hit0']
# DEBUG:Fragmenstein:Merged
# DEBUG:Fragmenstein:Starting ring expansion
# DEBUG:Fragmenstein:42 (formerly 125 existed already: fused ring or similar.
# DEBUG:Fragmenstein:41 (formerly 112 existed already: fused ring or similar.
# DEBUG:Fragmenstein:Restoring original bonding if any.
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d7b3ca0>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'O', 'C', 'C', 'N'], 'neighbors': [[105, 107, 138, 139], [106, 108, 140, 141], [107, 109], [108, 110, 142, 143], [109, 105, 144, 145], [104, 106, 110]], 'ori_is': [106, 107, 108, 109, 110, 105], 'xs': [-2.258903870969933, -3.451662214040896, -3.0634218685445336, -1.927650122894719, -1.6638178664854806, -1.4429258175938904], 'ys': [-2.36120742755085, -3.2934350962076464, -4.586582004309712, -4.73724066545902, -3.5327014348315595, -2.422437406596169], 'zs': [1.1829737215347782, 1.037424531349442, 0.7779287683571079, 0.026737259396602903, -0.8927096316803401, 0.002672159134974635], 'bonds': [['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE']], 'current_is': [34, 35, 36, 37, 38, 39]}
# DEBUG:Fragmenstein:ring bond #0 between 34 39(<=106,105)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 34 35(<=106,107)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 34 10(<=106,138)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 34 11(<=106,139)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 35 34(<=107,106)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #1 between 35 36(<=107,108)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 35 12(<=107,140)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 35 13(<=107,141)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 36 35(<=108,107)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #2 between 36 37(<=108,109)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 37 36(<=109,108)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #3 between 37 38(<=109,110)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 37 14(<=109,142)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 37 15(<=109,143)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 38 37(<=110,109)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #4 between 38 39(<=110,105)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 38 16(<=110,144)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 38 17(<=110,145)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 39 45(<=105,104)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 39 34(<=105,106)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 39 38(<=105,110)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d7b36f0>, 'ori_name': 'hit0', 'elements': ['N', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[104, 112], [111, 113, 125], [124, 126, 112], [125, 127, 103], [102, 104, 126], [103, 105, 111]], 'ori_is': [111, 112, 125, 126, 103, 104], 'xs': [0.8091993356621451, 1.7497200641218529, 1.44862971701391, 0.16054427724711512, -0.7830264326502798, -0.45636056508325956], 'ys': [-1.6183884450457986, -0.681156886686147, 0.4284253247024414, 0.5646330168498672, -0.378706733861793, -1.4435594533740783], 'zs': [0.23301509005611806, -0.0414407147118336, -0.7960655502898177, -1.2682544890761152, -0.9907060547141747, -0.2559070549825733], 'bonds': [['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'DOUBLE', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'SINGLE', 'AROMATIC']], 'current_is': [40, 41, 42, 43, 44, 45]}
# DEBUG:Fragmenstein:ring bond #0 between 40 45(<=111,104)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 40 41(<=111,112)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 41 40(<=112,111)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 41 46(<=112,113)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 41 42(<=112,125)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 42 49(<=125,124)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 42 43(<=125,126)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 42 41(<=125,112)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 43 42(<=126,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 43 5(<=126,127)  added as DOUBLE
# DEBUG:Fragmenstein:ring bond #3 between 43 44(<=126,103)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 44 2(<=103,102)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 44 45(<=103,104)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 44 43(<=103,126)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 45 44(<=104,103)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 45 39(<=104,105)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 45 40(<=104,111)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d7b3840>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'N', 'C', 'C', 'C'], 'neighbors': [[112, 114, 146], [113, 115, 123], [114, 124], [123, 125, 152], [124, 126, 112], [111, 113, 125]], 'ori_is': [113, 114, 123, 124, 125, 112], 'xs': [3.0311505272603365, 3.994187743456096, 3.6337899911655684, 2.4088852235830953, 1.44862971701391, 1.7497200641218529], 'ys': [-0.8383281745631075, 0.1406650854424727, 1.1929140907360625, 1.4004545020420358, 0.4284253247024414, -0.681156886686147], 'zs': [0.44093593367360123, 0.14743691975613438, -0.5909253904376175, -1.0861748076800337, -0.7960655502898177, -0.0414407147118336], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC']], 'current_is': [46, 47, 48, 49]}
# DEBUG:Fragmenstein:ring bond #0 between 46 41(<=113,112)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #0 between 46 47(<=113,114)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 46 18(<=113,146)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 47 46(<=114,113)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 47 3(<=114,115)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 47 48(<=114,123)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 48 47(<=123,114)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 48 49(<=123,124)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 49 48(<=124,123)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 49 42(<=124,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 49 24(<=124,152)  added as SINGLE
# WARNING:Fragmenstein:(Ring expansion) One atom 4 lacks a current index! This is a fallback that should not happen  (list index out of range)
# DEBUG:Fragmenstein:ring bond #4 between 42 49(<=125,124)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 42 43(<=125,126)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 42 41(<=125,112)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 41 40(<=112,111)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 41 46(<=112,113)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 41 42(<=112,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d7b3df0>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'C', 'C', 'C', 'C'], 'neighbors': [[116, 118, 148], [117, 119, 149], [118, 120, 121], [119, 122, 150], [121, 116, 151], [115, 117, 122]], 'ori_is': [117, 118, 119, 121, 122, 116], 'xs': [7.672783619411732, 8.774592456918818, 8.63887537142434, 7.41020840608432, 6.30217380337657, 6.378609607720835], 'ys': [0.3810661935031221, 1.174842797663829, 2.4519855360641745, 2.922956980140852, 2.089510607286498, 0.8104870598221997], 'zs': [0.8221272033160809, 0.7011321902151868, 0.22580328786585505, -0.12248322965405874, 0.01218391699340827, 0.47892261647603435], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [50, 51, 52, 53, 54, 55]}
# DEBUG:Fragmenstein:ring bond #0 between 50 55(<=117,116)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 50 51(<=117,118)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 50 20(<=117,148)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 51 50(<=118,117)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 51 52(<=118,119)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 51 21(<=118,149)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 52 51(<=119,118)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 52 4(<=119,120)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 52 53(<=119,121)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 53 52(<=121,119)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 53 54(<=121,122)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 53 22(<=121,150)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 54 53(<=122,121)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 54 55(<=122,116)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 54 23(<=122,151)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 55 3(<=116,115)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 55 50(<=116,117)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 55 54(<=116,122)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d3dc4a0>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[129, 131, 154], [130, 132, 155], [131, 133, 134], [132, 135, 156], [134, 129], [128, 130, 135]], 'ori_is': [130, 131, 132, 134, 135, 129], 'xs': [-4.974121967881748, -5.9777569658502765, -7.2154483975463135, -7.434477179452182, -6.457430335876701, -5.190036008641744], 'ys': [2.324508973186798, 3.0625380956454706, 3.155495558650879, 2.5100369019669606, 1.8315180575696126, 1.6929849405495245], 'zs': [0.9873634867164469, 1.6346879103453495, 1.0523736673145154, -0.16874111755302884, -0.7312080800684564, -0.20827973373622202], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [56, 57, 58, 59, 60, 61]}
# DEBUG:Fragmenstein:ring bond #0 between 56 61(<=130,129)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 56 57(<=130,131)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 56 26(<=130,154)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 57 56(<=131,130)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 57 58(<=131,132)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 57 27(<=131,155)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 58 57(<=132,131)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 58 7(<=132,133)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 58 59(<=132,134)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 59 58(<=134,132)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 59 60(<=134,135)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 59 28(<=134,156)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 60 59(<=135,134)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 60 61(<=135,129)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 61 6(<=129,128)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 61 56(<=129,130)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 61 60(<=129,135)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Adding novel bonding (if any)...
# DEBUG:Fragmenstein:_get_novel_other_pairs - close_pairs @ 1.0: []
# DEBUG:Fragmenstein:_get_novel_other_pairs - bonded_pairs @ 1.0: []
# DEBUG:Fragmenstein:`_emergency_joining` called
# DEBUG:Fragmenstein:Expanded
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 21), ('N', 7), ('O', 3), ('F', 2)]
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 21), ('N', 7), ('O', 3), ('F', 2)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:This molecule (hit0) has a fused ring
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 21), ('N', 7), ('O', 3), ('F', 2)]
# DEBUG:Fragmenstein:------------ ring fixes done ------------
# DEBUG:Fragmenstein:Storing molecule #2 in `.modifications`
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 21), ('N', 7), ('O', 3), ('F', 2)]
# DEBUG:Fragmenstein:------------ oddity fixes done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 21), ('N', 7), ('O', 3), ('F', 2)]
# DEBUG:Fragmenstein:------------ hydrogens done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 21), ('N', 7), ('O', 3), ('F', 2)]
# DEBUG:Fragmenstein:------------ valence drama done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 21), ('N', 7), ('O', 3), ('F', 2)]
# DEBUG:Fragmenstein:------------ check against radicals done ------------
# DEBUG:Fragmenstein:Rectified
# DEBUG:Fragmenstein:hit0 - Starting parameterisation
# DEBUG:Fragmenstein:`from_mol` called...
# DEBUG:Fragmenstein:`load_mol` called...
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:... Adding Gasteiger
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing O at position 0
# DEBUG:Fragmenstein:Parsing C at position 1
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing N at position 6
# DEBUG:Fragmenstein:Parsing N at position 39
# DEBUG:Fragmenstein:Parsing C at position 56
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing N at position 55
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing N at position 34
# DEBUG:Fragmenstein:Parsing N at position 35
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 54
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 44
# DEBUG:Fragmenstein:Parsing C at position 53
# DEBUG:Fragmenstein:Parsing F at position 7
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing C at position 41
# DEBUG:Fragmenstein:Parsing N at position 43
# DEBUG:Fragmenstein:Parsing O at position 31
# DEBUG:Fragmenstein:Parsing C at position 42
# DEBUG:Fragmenstein:Parsing N at position 3
# DEBUG:Fragmenstein:Parsing C at position 50
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing C at position 49
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing C at position 47
# DEBUG:Fragmenstein:Parsing F at position 4
# DEBUG:Fragmenstein:Parsing H at position 8
# DEBUG:Fragmenstein:Parsing H at position 9
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 10
# DEBUG:Fragmenstein:Parsing H at position 11
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing O at position 0
# DEBUG:Fragmenstein:Parsing C at position 1
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing N at position 6
# DEBUG:Fragmenstein:Parsing N at position 39
# DEBUG:Fragmenstein:Parsing C at position 56
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing N at position 55
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing N at position 34
# DEBUG:Fragmenstein:Parsing N at position 35
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 54
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 44
# DEBUG:Fragmenstein:Parsing C at position 53
# DEBUG:Fragmenstein:Parsing F at position 7
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing C at position 41
# DEBUG:Fragmenstein:Parsing N at position 43
# DEBUG:Fragmenstein:Parsing O at position 31
# DEBUG:Fragmenstein:Parsing C at position 42
# DEBUG:Fragmenstein:Parsing N at position 3
# DEBUG:Fragmenstein:Parsing C at position 50
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing C at position 49
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing C at position 47
# DEBUG:Fragmenstein:Parsing F at position 4
# DEBUG:Fragmenstein:Parsing H at position 8
# DEBUG:Fragmenstein:Parsing H at position 9
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 10
# DEBUG:Fragmenstein:Parsing H at position 11
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0 - placing monster in structure
# DEBUG:Fragmenstein:hit0 - saving params
# DEBUG:Fragmenstein:hit0 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0 - saving mols from monster
# DEBUG:Fragmenstein:hit0 - Igor minimising
# DEBUG:Fragmenstein:hit0 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0 - calculating mRMSD
# INFO:Fragmenstein:hit0 - final score: -0.6683053388001969 kcal/mol, RMSD: 0.19651309247666068.
# DEBUG:Fragmenstein:hit0 - saving pose from igor
# DEBUG:Fragmenstein:hit0 - calculating Gibbs
# DEBUG:Fragmenstein:hit0 - Completed
# DEBUG:Fragmenstein:hit0 - Completed
# INFO:Fragmenstein:hit0 - Time taken: 35.79445958137512
# DEBUG:Fragmenstein:hit0 - harmonising warheads on hits in "first" mode
# DEBUG:Fragmenstein:Merging: ['hit0']
# DEBUG:Fragmenstein:Merged
# DEBUG:Fragmenstein:Starting ring expansion
# DEBUG:Fragmenstein:43 (formerly 132 existed already: fused ring or similar.
# DEBUG:Fragmenstein:42 (formerly 109 existed already: fused ring or similar.
# DEBUG:Fragmenstein:Restoring original bonding if any.
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d3dd850>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'C', 'C', 'C', 'C'], 'neighbors': [[100, 102, 134], [105, 101, 156], [104, 106, 134], [103, 105, 140], [102, 104, 139], [101, 103, 138]], 'ori_is': [101, 134, 105, 104, 103, 102], 'xs': [-7.392206956446631, -6.036156393561463, -5.216298815229626, -5.803520270710121, -7.160113855432725, -7.98151926349157], 'ys': [-1.803463270536237, -1.810828602130877, -0.7566888567715926, 0.3540764765847669, 0.3807085676121819, -0.6917034531725995], 'zs': [0.4301824248946129, 0.6812528390675204, 0.38375008891068946, -0.195144438571149, -0.454507285401055, -0.1494981197643308], 'bonds': [['SINGLE', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE']], 'current_is': [34, 35, 36, 37, 38, 39]}
# DEBUG:Fragmenstein:ring bond #0 between 34 0(<=101,100)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 34 39(<=101,102)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 34 35(<=101,134)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 35 36(<=134,105)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 35 34(<=134,101)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 35 28(<=134,156)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 36 37(<=105,104)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 36 45(<=105,106)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 36 35(<=105,134)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 37 38(<=104,103)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 37 36(<=104,105)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 37 12(<=104,140)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 38 39(<=103,102)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 38 37(<=103,104)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 38 11(<=103,139)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 39 34(<=102,101)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 39 38(<=102,103)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 39 10(<=102,138)  added as SINGLE
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d7b36f0>, 'ori_name': 'hit0', 'elements': ['N', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[106, 108], [107, 109, 141], [108, 110, 132], [131, 133, 109], [132, 106], [105, 107, 133]], 'ori_is': [107, 108, 109, 132, 133, 106], 'xs': [-3.2656167161626937, -1.954786290900334, -1.1233080194397782, -1.6623558400214293, -2.980406686851232, -3.7869014174699007], 'ys': [-1.9070670143973634, -1.9835034530330247, -0.9168237300960355, 0.2052938634703097, 0.22252202049910044, -0.8146026373234692], 'zs': [1.226482820446682, 1.5008651763733112, 1.2061229190571028, 0.6347215219059299, 0.38380571109161976, 0.6708238627241448], 'bonds': [['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [40, 41, 42, 43, 44, 45]}
# DEBUG:Fragmenstein:ring bond #0 between 40 45(<=107,106)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 40 41(<=107,108)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 41 40(<=108,107)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 41 42(<=108,109)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 41 13(<=108,141)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 42 41(<=109,108)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 42 46(<=109,110)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 42 43(<=109,132)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 43 49(<=132,131)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 43 44(<=132,133)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 43 42(<=132,109)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 44 43(<=133,132)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 44 45(<=133,106)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 45 36(<=106,105)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 45 40(<=106,107)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 45 44(<=106,133)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d3ddc40>, 'ori_name': 'hit0', 'elements': ['C', 'N', 'C', 'N', 'C', 'C'], 'neighbors': [[109, 111, 112], [110, 113, 124], [112, 125, 131], [124, 132], [131, 133, 109], [108, 110, 132]], 'ori_is': [110, 112, 124, 131, 132, 109], 'xs': [0.2209728487185147, 0.9792915052883759, 0.4644247524381293, -0.8667374907343082, -1.6623558400214293, -1.1233080194397782], 'ys': [-0.9440140863181691, 0.11706498992999903, 1.23146851373483, 1.2355689597365949, 0.2052938634703097, -0.9168237300960355], 'zs': [1.466854039728694, 1.1617073947006806, 0.5980347179466974, 0.34944913523970367, 0.6347215219059299, 1.2061229190571028], 'bonds': [['AROMATIC', 'DOUBLE', 'AROMATIC'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC']], 'current_is': [46, 47, 48, 49]}
# DEBUG:Fragmenstein:ring bond #0 between 46 42(<=110,109)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #0 between 46 1(<=110,111)  added as DOUBLE
# DEBUG:Fragmenstein:ring bond #0 between 46 47(<=110,112)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 47 46(<=112,110)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 47 2(<=112,113)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 47 48(<=112,124)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 48 47(<=124,112)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 48 61(<=124,125)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 48 49(<=124,131)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 49 48(<=131,124)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 49 43(<=131,132)  exists already (has AROMATIC as expected AROMATIC)
# WARNING:Fragmenstein:(Ring expansion) One atom 4 lacks a current index! This is a fallback that should not happen  (list index out of range)
# DEBUG:Fragmenstein:ring bond #4 between 43 49(<=132,131)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 43 44(<=132,133)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 43 42(<=132,109)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 42 41(<=109,108)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 42 46(<=109,110)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 42 43(<=109,132)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d3dec00>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[117, 119, 145], [118, 120, 146], [119, 121, 122], [120, 123, 147], [122, 117], [116, 118, 123]], 'ori_is': [118, 119, 120, 122, 123, 117], 'xs': [4.90036627254952, 5.809675043004354, 7.137554940993613, 7.558755530730918, 6.664391482707313, 5.327019776598019], 'ys': [-1.6929724932003813, -2.1939185992038817, -2.268234383492502, -1.8276363392459316, -1.353915328715041, -1.2642877010556879], 'zs': [-1.9233555696853535, -2.840977388303451, -2.549613738839074, -1.3047206118083075, -0.44941436761021547, -0.7062783661705672], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [50, 51, 52, 53, 54, 55]}
# DEBUG:Fragmenstein:ring bond #0 between 50 55(<=118,117)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 50 51(<=118,119)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 50 17(<=118,145)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 51 50(<=119,118)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 51 52(<=119,120)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 51 18(<=119,146)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 52 51(<=120,119)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 52 6(<=120,121)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 52 53(<=120,122)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 53 52(<=122,120)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 53 54(<=122,123)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 53 19(<=122,147)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 54 53(<=123,122)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 54 55(<=123,117)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 55 5(<=117,116)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 55 50(<=117,118)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 55 54(<=117,123)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d3dd7e0>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'O', 'C', 'C', 'N'], 'neighbors': [[125, 127, 148, 149], [126, 128, 150, 151], [127, 129], [128, 130, 152, 153], [129, 125, 154, 155], [124, 126, 130]], 'ori_is': [126, 127, 128, 129, 130, 125], 'xs': [1.8867929498013378, 1.892808232570627, 2.7033319098668125, 2.892886965686439, 1.5889841167671266, 1.288349039033391], 'ys': [2.4262008286208, 3.9020434488271833, 4.641218603559068, 4.04638543818382, 3.426270315037126, 2.340609352911592], 'zs': [-1.0317935302484271, -1.3856990545462906, -0.5614702899449739, 0.677291546334773, 1.1983169136750795, 0.2857190291276264], 'bonds': [['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE']], 'current_is': [56, 57, 58, 59, 60, 61]}
# DEBUG:Fragmenstein:ring bond #0 between 56 61(<=126,125)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 56 57(<=126,127)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 56 20(<=126,148)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 56 21(<=126,149)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 57 56(<=127,126)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #1 between 57 58(<=127,128)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 57 22(<=127,150)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 57 23(<=127,151)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 58 57(<=128,127)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #2 between 58 59(<=128,129)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 59 58(<=129,128)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #3 between 59 60(<=129,130)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 59 24(<=129,152)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 59 25(<=129,153)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 60 59(<=130,129)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #4 between 60 61(<=130,125)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 60 26(<=130,154)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 60 27(<=130,155)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 61 48(<=125,124)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 61 56(<=125,126)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 61 60(<=125,130)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:Adding novel bonding (if any)...
# DEBUG:Fragmenstein:_get_novel_other_pairs - close_pairs @ 1.0: []
# DEBUG:Fragmenstein:_get_novel_other_pairs - bonded_pairs @ 1.0: []
# DEBUG:Fragmenstein:`_emergency_joining` called
# DEBUG:Fragmenstein:Expanded
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 22), ('N', 7), ('O', 3), ('Cl', 1)]
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 22), ('N', 7), ('O', 3), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:This molecule (hit0) has a fused ring
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 22), ('N', 7), ('O', 3), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ ring fixes done ------------
# DEBUG:Fragmenstein:Storing molecule #2 in `.modifications`
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 22), ('N', 7), ('O', 3), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ oddity fixes done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 22), ('N', 7), ('O', 3), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ hydrogens done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 22), ('N', 7), ('O', 3), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ valence drama done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 36), ('AROMATIC', 23), ('DOUBLE', 2)]; Atoms: [('C', 24), ('H', 22), ('N', 7), ('O', 3), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ check against radicals done ------------
# DEBUG:Fragmenstein:Rectified
# WARNING:Fragmenstein:hit0 - Folder output/hit0 exists.
# DEBUG:Fragmenstein:hit0 - Starting parameterisation
# DEBUG:Fragmenstein:`from_mol` called...
# DEBUG:Fragmenstein:`load_mol` called...
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:... Adding Gasteiger
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing C at position 0
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 34
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing C at position 31
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing N at position 35
# DEBUG:Fragmenstein:Parsing N at position 39
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing N at position 44
# DEBUG:Fragmenstein:Parsing C at position 41
# DEBUG:Fragmenstein:Parsing C at position 43
# DEBUG:Fragmenstein:Parsing O at position 1
# DEBUG:Fragmenstein:Parsing N at position 42
# DEBUG:Fragmenstein:Parsing N at position 56
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing C at position 55
# DEBUG:Fragmenstein:Parsing C at position 3
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 54
# DEBUG:Fragmenstein:Parsing O at position 4
# DEBUG:Fragmenstein:Parsing N at position 5
# DEBUG:Fragmenstein:Parsing O at position 53
# DEBUG:Fragmenstein:Parsing C at position 50
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing N at position 49
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing C at position 47
# DEBUG:Fragmenstein:Parsing Cl at position 6
# DEBUG:Fragmenstein:Parsing H at position 7
# DEBUG:Fragmenstein:Parsing H at position 8
# DEBUG:Fragmenstein:Parsing H at position 9
# DEBUG:Fragmenstein:Parsing H at position 10
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 11
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing C at position 0
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 34
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing C at position 31
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing N at position 35
# DEBUG:Fragmenstein:Parsing N at position 39
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing N at position 44
# DEBUG:Fragmenstein:Parsing C at position 41
# DEBUG:Fragmenstein:Parsing C at position 43
# DEBUG:Fragmenstein:Parsing O at position 1
# DEBUG:Fragmenstein:Parsing N at position 42
# DEBUG:Fragmenstein:Parsing N at position 56
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing C at position 55
# DEBUG:Fragmenstein:Parsing C at position 3
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 54
# DEBUG:Fragmenstein:Parsing O at position 4
# DEBUG:Fragmenstein:Parsing N at position 5
# DEBUG:Fragmenstein:Parsing O at position 53
# DEBUG:Fragmenstein:Parsing C at position 50
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing N at position 49
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing C at position 47
# DEBUG:Fragmenstein:Parsing Cl at position 6
# DEBUG:Fragmenstein:Parsing H at position 7
# DEBUG:Fragmenstein:Parsing H at position 8
# DEBUG:Fragmenstein:Parsing H at position 9
# DEBUG:Fragmenstein:Parsing H at position 10
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 11
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0 - placing monster in structure
# DEBUG:Fragmenstein:hit0 - saving params
# DEBUG:Fragmenstein:hit0 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0 - saving mols from monster
# DEBUG:Fragmenstein:hit0 - Igor minimising
# DEBUG:Fragmenstein:hit0 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0 - calculating mRMSD
# INFO:Fragmenstein:hit0 - final score: -0.34145349824667504 kcal/mol, RMSD: 0.18771719904633408.
# DEBUG:Fragmenstein:hit0 - saving pose from igor
# DEBUG:Fragmenstein:hit0 - calculating Gibbs
# DEBUG:Fragmenstein:hit0 - Completed
# DEBUG:Fragmenstein:hit0 - Completed
# INFO:Fragmenstein:hit0 - Time taken: 28.707429885864258

# %%
# Combined processing of both SMILES strings
logging.info("Combining both SMILES for joint processing.")

mol1 = Chem.AddHs(AllChem.MolFromSmiles(smiles1))
AllChem.EmbedMolecule(mol1, AllChem.ETKDG())

mol2 = Chem.AddHs(AllChem.MolFromSmiles(smiles2))
AllChem.EmbedMolecule(mol2, AllChem.ETKDG())

combined_victor = Victor(hits=[mol1, mol2], pdb_filename=protein_pdb_path)
try:
    combined_victor.combine()
except Chem.AtomValenceException:
    logging.info("Atom valence exception occurred during combined processing, trying to rectify...")
    combined_victor.rectify(collapse_rings=True, joining_cutoff=3.0)
    combined_victor.combine()

combined_molecule = combined_victor.minimized_mol
mol_2d_structures.append(combined_molecule)
combined_smiles = Chem.MolToSmiles(combined_molecule)
minimized_smiles_list.append(combined_smiles)
combined_mw = Descriptors.ExactMolWt(combined_molecule)
combined_logp = Descriptors.MolLogP(combined_molecule)
combined_hba = Descriptors.NumHAcceptors(combined_molecule)
combined_hbd = Descriptors.NumHDonors(combined_molecule)

# Visualize and save 2D structure of each resulting molecule
all_molecules = [Chem.AddHs(AllChem.MolFromSmiles(smiles1)), Chem.AddHs(AllChem.MolFromSmiles(smiles2)), combined_molecule]
display(MolsToGridImage(all_molecules, molsPerRow=3, subImgSize=(300, 300)))

# Append combined molecule data
molecule_data.append([combined_smiles, combined_mw, combined_logp, combined_hba, combined_hbd, 'combined_optimized_molecule.mol'])
# Out:
# DEBUG:Fragmenstein:hit0-hit1 - harmonising warheads on hits in "first" mode
# DEBUG:Fragmenstein:Merging: ['hit0', 'hit1']
# DEBUG:Fragmenstein:Merged
# DEBUG:Fragmenstein:Starting ring expansion
# DEBUG:Fragmenstein:76 (formerly 125 existed already: fused ring or similar.
# DEBUG:Fragmenstein:75 (formerly 112 existed already: fused ring or similar.
# DEBUG:Fragmenstein:Restoring original bonding if any.
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d459000>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'O', 'C', 'C', 'N'], 'neighbors': [[105, 107, 138, 139], [106, 108, 140, 141], [107, 109], [108, 110, 142, 143], [109, 105, 144, 145], [104, 106, 110]], 'ori_is': [106, 107, 108, 109, 110, 105], 'xs': [2.014859414270312, 2.301746502319177, 1.477482901974378, 1.9428415650731845, 1.5567981289766095, 1.4507457765340008], 'ys': [-2.130420426871848, -3.22871131891804, -4.314918909488483, -4.9246329668341975, -4.0632151532588665, -2.6642392440627467], 'zs': [-2.7648408494410495, -3.7779143790628513, -3.509994821359155, -2.3587552191326977, -1.181357467100985, -1.5575180643757955], 'bonds': [['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE']], 'current_is': [68, 69, 70, 71, 72, 73]}
# DEBUG:Fragmenstein:ring bond #0 between 68 73(<=106,105)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 68 69(<=106,107)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 68 10(<=106,138)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 68 11(<=106,139)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 69 68(<=107,106)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #1 between 69 70(<=107,108)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 69 12(<=107,140)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 69 13(<=107,141)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 70 69(<=108,107)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #2 between 70 71(<=108,109)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 71 70(<=109,108)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #3 between 71 72(<=109,110)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 71 14(<=109,142)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 71 15(<=109,143)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 72 71(<=110,109)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #4 between 72 73(<=110,105)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 72 16(<=110,144)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 72 17(<=110,145)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 73 79(<=105,104)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 73 68(<=105,106)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 73 72(<=105,110)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d459e70>, 'ori_name': 'hit0', 'elements': ['N', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[104, 112], [111, 113, 125], [124, 126, 112], [125, 127, 103], [102, 104, 126], [103, 105, 111]], 'ori_is': [111, 112, 125, 126, 103, 104], 'xs': [-0.5606243948514159, -1.3904818583655494, -0.8995571966728024, 0.3985845639526441, 1.2012762459940303, 0.7348427190170095], 'ys': [-1.5603387636937867, -0.817578068591269, -0.2999677321631439, -0.5706871009156272, -1.3242115042009868, -1.8198553763309862], 'zs': [-1.046188393078967, -0.30985047307567865, 0.8661283308727531, 1.213366350684564, 0.4357612412247239, -0.6824993094967475], 'bonds': [['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'DOUBLE', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'SINGLE', 'AROMATIC']], 'current_is': [74, 75, 76, 77, 78, 79]}
# DEBUG:Fragmenstein:ring bond #0 between 74 79(<=111,104)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 74 75(<=111,112)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 75 74(<=112,111)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 75 80(<=112,113)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 75 76(<=112,125)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 76 83(<=125,124)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 76 77(<=125,126)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 76 75(<=125,112)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 77 76(<=126,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 77 5(<=126,127)  added as DOUBLE
# DEBUG:Fragmenstein:ring bond #3 between 77 78(<=126,103)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 78 2(<=103,102)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 78 79(<=103,104)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 78 77(<=103,126)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 79 78(<=104,103)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 79 73(<=104,105)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 79 74(<=104,111)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d45af10>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'N', 'C', 'C', 'C'], 'neighbors': [[112, 114, 146], [113, 115, 123], [114, 124], [123, 125, 152], [124, 126, 112], [111, 113, 125]], 'ori_is': [113, 114, 123, 124, 125, 112], 'xs': [-2.687462399582403, -3.521059858864825, -3.0150319972654276, -1.7540818360030108, -0.8995571966728024, -1.3904818583655494], 'ys': [-0.5462414126085448, 0.23187683343772644, 0.7207385269782229, 0.47693010168227606, -0.2999677321631439, -0.817578068591269], 'zs': [-0.679393615028245, 0.09470844448585979, 1.230735266675621, 1.6232322268500183, 0.8661283308727531, -0.30985047307567865], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC']], 'current_is': [80, 81, 82, 83]}
# DEBUG:Fragmenstein:ring bond #0 between 80 75(<=113,112)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #0 between 80 81(<=113,114)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 80 18(<=113,146)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 81 80(<=114,113)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 81 3(<=114,115)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 81 82(<=114,123)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 82 81(<=123,114)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 82 83(<=123,124)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 83 82(<=124,123)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 83 76(<=124,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 83 24(<=124,152)  added as SINGLE
# WARNING:Fragmenstein:(Ring expansion) One atom 4 lacks a current index! This is a fallback that should not happen  (list index out of range)
# DEBUG:Fragmenstein:ring bond #4 between 76 83(<=125,124)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 76 77(<=125,126)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 76 75(<=125,112)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 75 74(<=112,111)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 75 80(<=112,113)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 75 76(<=112,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d458f90>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'C', 'C', 'C', 'C'], 'neighbors': [[116, 118, 148], [117, 119, 149], [118, 120, 121], [119, 122, 150], [121, 116, 151], [115, 117, 122]], 'ori_is': [117, 118, 119, 121, 122, 116], 'xs': [-5.67078425007575, -6.589480292973599, -7.595540704631708, -7.69442031079688, -6.796429696099929, -5.767597596985974], 'ys': [1.3511451535603476, 2.118768524943779, 2.7775449309065787, 2.674527651187059, 1.9214781353335593, 1.2521484985253315], 'zs': [1.8023045266538056, 2.5160404219797865, 1.8565159868633687, 0.4736687581149496, -0.2437810553464086, 0.4503080153984716], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [84, 85, 86, 87, 88, 89]}
# DEBUG:Fragmenstein:ring bond #0 between 84 89(<=117,116)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 84 85(<=117,118)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 84 20(<=117,148)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 85 84(<=118,117)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 85 86(<=118,119)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 85 21(<=118,149)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 86 85(<=119,118)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 86 4(<=119,120)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 86 87(<=119,121)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 87 86(<=121,119)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 87 88(<=121,122)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 87 22(<=121,150)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 88 87(<=122,121)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 88 89(<=122,116)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 88 23(<=122,151)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 89 3(<=116,115)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 89 84(<=116,117)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 89 88(<=116,122)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d45ac70>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[129, 131, 154], [130, 132, 155], [131, 133, 134], [132, 135, 156], [134, 129], [128, 130, 135]], 'ori_is': [130, 131, 132, 134, 135, 129], 'xs': [4.525756719993028, 5.126478357603099, 5.505810335415241, 5.269479173459301, 4.689374256285664, 4.2949059550645545], 'ys': [2.6049623885668964, 3.8521126589995083, 4.47992289244171, 3.8337460674574775, 2.6398171845730607, 1.9734817681040033], 'zs': [0.10741787443763876, 0.045912383139790694, 1.2172527252067367, 2.4307175857645276, 2.4118393194406567, 1.2878463246025242], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [90, 91, 92, 93, 94, 95]}
# DEBUG:Fragmenstein:ring bond #0 between 90 95(<=130,129)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 90 91(<=130,131)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 90 26(<=130,154)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 91 90(<=131,130)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 91 92(<=131,132)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 91 27(<=131,155)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 92 91(<=132,131)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 92 7(<=132,133)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 92 93(<=132,134)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 93 92(<=134,132)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 93 94(<=134,135)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 93 28(<=134,156)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 94 93(<=135,134)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 94 95(<=135,129)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 95 6(<=129,128)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 95 90(<=129,130)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 95 94(<=129,135)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d459380>, 'ori_name': 'hit1', 'elements': ['C', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[617, 619, 645], [618, 620, 646], [619, 621, 622], [620, 623, 647], [622, 617], [616, 618, 623]], 'ori_is': [618, 619, 620, 622, 623, 617], 'xs': [-4.910112436970266, -5.879155811244359, -6.601106702844596, -6.348801968211283, -5.38357100110839, -4.646845670886359], 'ys': [3.668879942742262, 4.35399211169332, 3.654815673866295, 2.3151163283835, 1.7108321564045648, 2.33703631925874], 'zs': [0.6464498183097572, -0.04954995766025142, -0.9925634126366808, -1.218880331982186, -0.49756621515361354, 0.434108617926783], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [96, 97, 98, 99, 100, 101]}
# DEBUG:Fragmenstein:ring bond #0 between 96 101(<=618,617)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 96 97(<=618,619)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 96 41(<=618,645)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 97 96(<=619,618)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 97 98(<=619,620)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 97 42(<=619,646)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 98 97(<=620,619)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 98 38(<=620,621)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 98 99(<=620,622)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 99 98(<=622,620)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 99 100(<=622,623)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 99 43(<=622,647)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 100 99(<=623,622)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 100 101(<=623,617)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 101 37(<=617,616)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 101 96(<=617,618)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 101 100(<=617,623)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d458740>, 'ori_name': 'hit1', 'elements': ['C', 'C', 'C', 'C', 'C', 'C'], 'neighbors': [[800, 802, 834], [805, 801], [804, 806, 834], [803, 805, 840], [802, 804, 839], [801, 803, 838]], 'ori_is': [801, 834, 805, 804, 803, 802], 'xs': [7.207622685982503, 5.926505094483112, 5.011168213262029, 5.387030709642963, 6.669669160611781, 7.56024438593178], 'ys': [1.40958119722054, 1.4682062567781824, 0.4652735191329187, -0.6502667749423827, -0.759400783354214, 0.2847637730921654], 'zs': [-1.0761354908836402, -0.5534392654187003, -0.7178691882499042, -1.4372269867310288, -1.9868282163351063, -1.7913529113629225], 'bonds': [['SINGLE', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE']], 'current_is': [102, 103, 104, 105, 106, 107]}
# DEBUG:Fragmenstein:ring bond #0 between 102 46(<=801,800)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 102 107(<=801,802)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 102 103(<=801,834)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 103 104(<=834,805)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 103 102(<=834,801)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 104 105(<=805,804)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 104 113(<=805,806)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 104 103(<=805,834)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 105 106(<=804,803)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 105 104(<=804,805)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 105 52(<=804,840)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 106 107(<=803,802)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 106 105(<=803,804)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 106 51(<=803,839)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 107 102(<=802,801)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 107 106(<=802,803)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 107 50(<=802,838)  added as SINGLE
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d458580>, 'ori_name': 'hit1', 'elements': ['N', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[806, 808], [807, 809, 841], [808, 832], [833, 809], [832, 806], [805, 807, 833]], 'ori_is': [807, 808, 809, 832, 833, 806], 'xs': [3.2607384230742222, 2.013614917927484, 1.147143274387745, 1.5391831492234642, 2.787912573449646, 3.656404108449948], 'ys': [1.6083946072791278, 1.6789801674133153, 0.6221603030442314, -0.4919292292334987, -0.49372234971816986, 0.5176988112840509], 'zs': [0.5387491465563914, 1.070589199054154, 0.8895518303537882, 0.17848292715552883, -0.31987309670874603, -0.16192485681424112], 'bonds': [['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [108, 109, 110, 111, 112, 113]}
# DEBUG:Fragmenstein:ring bond #0 between 108 113(<=807,806)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 108 109(<=807,808)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 109 108(<=808,807)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 109 110(<=808,809)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 109 53(<=808,841)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 110 109(<=809,808)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 110 111(<=809,832)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 111 112(<=832,833)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 111 110(<=832,809)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 112 111(<=833,832)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 112 113(<=833,806)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 113 104(<=806,805)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 113 108(<=806,807)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 113 112(<=806,833)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d458d60>, 'ori_name': 'hit1', 'elements': ['C', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[917, 919, 945], [918, 920, 946], [919, 921, 922], [920, 923], [922, 917], [918, 923]], 'ori_is': [918, 919, 920, 922, 923, 917], 'xs': [-4.910112436970266, -5.879155811244359, -6.601106702844596, -6.348801968211283, -5.38357100110839, -4.646845670886359], 'ys': [3.668879942742262, 4.35399211169332, 3.654815673866295, 2.3151163283835, 1.7108321564045648, 2.33703631925874], 'zs': [0.6464498183097572, -0.04954995766025142, -0.9925634126366808, -1.218880331982186, -0.49756621515361354, 0.434108617926783], 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [114, 115, 116, 117, 118, 119]}
# DEBUG:Fragmenstein:ring bond #0 between 114 119(<=918,917)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 114 115(<=918,919)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 114 57(<=918,945)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 115 114(<=919,918)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 115 116(<=919,920)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 115 58(<=919,946)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 116 115(<=920,919)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 116 56(<=920,921)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 116 117(<=920,922)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 117 116(<=922,920)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 117 118(<=922,923)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 118 117(<=923,922)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 118 119(<=923,917)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 119 114(<=917,918)  exists already but has AROMATIC as is better thanthe expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 119 118(<=917,923)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d45a490>, 'ori_name': 'hit1', 'elements': ['C', 'C', 'O', 'C', 'C', 'N'], 'neighbors': [[1025, 1027, 1049], [1026, 1028, 1050, 1051], [1027, 1029], [1028, 1030, 1052, 1053], [1029, 1025, 1054, 1055], [1026, 1030]], 'ori_is': [1026, 1027, 1028, 1029, 1030, 1025], 'xs': [-2.2477709311264986, -3.497511594160506, -3.2575449389294913, -1.9590015153783844, -1.3659465077210577, -1.3919372963769068], 'ys': [-2.9006614726693827, -3.594273781659606, -4.83844903950592, -5.002057090536786, -3.7923210518395476, -2.684117761256578], 'zs': [-0.8293102058897629, -0.4024747221315069, 0.17650936999435796, 0.5874778874070135, 1.2743382023075749, 0.3081702680512062], 'bonds': [['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE']], 'current_is': [120, 121, 122, 123, 124, 125]}
# DEBUG:Fragmenstein:ring bond #0 between 120 125(<=1026,1025)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 120 121(<=1026,1027)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 120 60(<=1026,1049)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 121 120(<=1027,1026)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #1 between 121 122(<=1027,1028)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 121 61(<=1027,1050)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 121 62(<=1027,1051)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 122 121(<=1028,1027)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #2 between 122 123(<=1028,1029)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 123 122(<=1029,1028)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #3 between 123 124(<=1029,1030)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 123 63(<=1029,1052)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 123 64(<=1029,1053)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 124 123(<=1030,1029)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #4 between 124 125(<=1030,1025)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 124 65(<=1030,1054)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 124 66(<=1030,1055)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 125 120(<=1025,1026)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 125 124(<=1025,1030)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:Adding novel bonding (if any)...
# DEBUG:Fragmenstein:determining novel bond between ring markers 30 and 55
# DEBUG:Fragmenstein:Copying atom bonding from 111 to 78, force=True
# DEBUG:Fragmenstein:... Forcing bond between 78 and 110 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 78 and 112 during bond copying
# INFO:Fragmenstein:A novel spiro ring pair was found
# DEBUG:Fragmenstein:determining novel bond between ring markers 32 and 44
# INFO:Fragmenstein:A novel bond-connected ring pair was found
# DEBUG:Fragmenstein:Copying atom bonding from 100 to 89, force=True
# DEBUG:Fragmenstein:... Forcing bond between 89 and 99 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 89 and 101 during bond copying
# DEBUG:Fragmenstein:determining novel bond between ring markers 32 and 59
# INFO:Fragmenstein:A novel bond-connected ring pair was found
# DEBUG:Fragmenstein:Copying atom bonding from 118 to 89, force=True
# DEBUG:Fragmenstein:... Forcing bond between 89 and 117 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 89 and 119 during bond copying
# DEBUG:Fragmenstein:determining novel bond between ring markers 33 and 55
# INFO:Fragmenstein:A novel bond-connected ring pair was found
# DEBUG:Fragmenstein:Copying atom bonding from 108 to 95, force=True
# DEBUG:Fragmenstein:... Forcing bond between 95 and 113 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 95 and 109 during bond copying
# DEBUG:Fragmenstein:determining novel bond between ring markers 30 and 67
# INFO:Fragmenstein:A novel bond-connected ring pair was found
# DEBUG:Fragmenstein:Copying atom bonding from 125 to 74, force=True
# DEBUG:Fragmenstein:... Forcing bond between 74 and 120 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 74 and 124 during bond copying
# DEBUG:Fragmenstein:_get_novel_other_pairs - close_pairs @ 1.0: [(0, 55), (1, 55), (1, 55), (23, 43), (23, 44), (23, 59), (36, 31), (36, 31), (38, 56), (40, 45), (41, 57), (42, 58), (43, 23), (44, 59), (45, 40), (56, 38), (57, 41), (58, 42), (59, 44), (31, 36), (31, 36), (44, 23), (55, 1), (55, 0), (55, 1), (59, 23), (0, 55), (1, 55), (1, 55), (23, 43), (23, 44), (23, 59), (36, 31), (36, 31), (38, 56), (40, 45), (41, 57), (42, 58), (43, 23), (44, 59), (45, 40), (56, 38), (57, 41), (58, 42), (59, 44), (31, 36), (31, 36), (44, 23), (55, 1), (55, 0), (55, 1), (59, 23)]
# DEBUG:Fragmenstein:_get_novel_other_pairs - bonded_pairs @ 1.0: [(30, 34), (30, 35), (54, 26), (59, 23), (59, 20), (67, 18)]
# DEBUG:Fragmenstein:determining novel bond between ring marker 55 and non-ring 0
# INFO:Fragmenstein:(DetMergeNovOther: 0, 112). A novel bonding to ring may be added. d: 1.0117494911685596 p: 0.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 55 and non-ring 1
# DEBUG:Fragmenstein:(DetMergeNovOther *55, 1). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 1, 112). An atom was absorbed to ring. d: 0.9691700417731002 p: 2.0
# DEBUG:Fragmenstein:Copying atom bonding from 1 to 112, force=None
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 0 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 0 already exists
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 2 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 2 would make a triangle, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 6 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 6 would make a square, skipping
# DEBUG:Fragmenstein:determining novel bond between ring marker 44 and non-ring 23
# INFO:Fragmenstein:(DetMergeNovOther: 23, 100). A novel bonding to ring may be added. d: 1.7055418610721071 p: 0.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 59 and non-ring 23
# INFO:Fragmenstein:(DetMergeNovOther: 23, 117). An atom was absorbed to ring. d: 0.7137768145470791 p: 0.0
# DEBUG:Fragmenstein:Copying atom bonding from 23 to 117, force=None
# DEBUG:Fragmenstein:... Potentially adding bond between 117 and 32 during bond copying
# DEBUG:Fragmenstein:Bond between 117 and 32 would make a square, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 117 and 59 during bond copying
# DEBUG:Fragmenstein:Bond between 117 and 59 would make a square, skipping
# DEBUG:Fragmenstein:... Forcing bond between 117 and 88 during bond copying
# DEBUG:Fragmenstein:... Potentially adding bond between 117 and 100 during bond copying
# DEBUG:Fragmenstein:Bond between 117 and 100 would make a square, skipping
# DEBUG:Fragmenstein:determining novel bond between ring marker 31 and non-ring 36
# DEBUG:Fragmenstein:(DetMergeNovOther *31, 36). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 36, 82). An atom was absorbed to ring. d: 0.5322608046606236 p: 0.0
# DEBUG:Fragmenstein:Copying atom bonding from 36 to 82, force=None
# DEBUG:Fragmenstein:... Potentially adding bond between 82 and 35 during bond copying
# DEBUG:Fragmenstein:Bond between 82 and 35 would make a square, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 82 and 37 during bond copying
# DEBUG:Fragmenstein:... Potentially adding bond between 82 and 3 during bond copying
# DEBUG:Fragmenstein:Bond between 82 and 3 would make a triangle, skipping
# DEBUG:Fragmenstein:determining novel bond between ring marker 44 and non-ring 59
# DEBUG:Fragmenstein:(DetMergeNovOther *44, 59). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 59, 100). An atom was absorbed to ring. d: 1.3367247806062503 p: 0.0
# DEBUG:Fragmenstein:Copying atom bonding from 100 to 59, force=None
# DEBUG:Fragmenstein:... Forcing bond between 59 and 99 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 59 and 101 during bond copying
# DEBUG:Fragmenstein:... Potentially adding bond between 59 and 23 during bond copying
# DEBUG:Fragmenstein:Bond between 59 and 23 already exists
# DEBUG:Fragmenstein:determining novel bond between ring marker 30 and non-ring 34
# INFO:Fragmenstein:(DetMergeNovOther: 34, 76). A novel bonding to ring may be added. d: 2.296713691191422 p: 2.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 30 and non-ring 35
# INFO:Fragmenstein:(DetMergeNovOther: 35, 76). A novel bonding to ring may be added. d: 1.690319720230577 p: 2.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 54 and non-ring 26
# INFO:Fragmenstein:(DetMergeNovOther: 26, 103). A novel bonding to ring may be added. d: 1.8480895699355202 p: 0.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 59 and non-ring 20
# INFO:Fragmenstein:(DetMergeNovOther: 20, 119). A novel bonding to ring may be added. d: 2.440496080905131 p: 0.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 67 and non-ring 18
# INFO:Fragmenstein:(DetMergeNovOther: 18, 120). A novel bonding to ring may be added. d: 2.2430648916560805 p: 1.0
# DEBUG:Fragmenstein:Square present (19, 71, 76, 102).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 76 and 102
# DEBUG:Fragmenstein:Square present (22, 28, 63, 70).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 28 and 63
# DEBUG:Fragmenstein:Triangle present (75, 76, 101).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 76 and 101
# DEBUG:Fragmenstein:`_emergency_joining` called
# DEBUG:Fragmenstein:Expanded
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 73), ('AROMATIC', 45), ('DOUBLE', 2)]; Atoms: [('C', 48), ('H', 42), ('N', 9), ('O', 5), ('F', 2), ('Cl', 2)]
# CRITICAL:Fragmenstein:Absorption required for the atom pairs: [[36, 32], [45, 30], [46, 33], [47, 34], [97, 0], [98, 83], [99, 84], [100, 85], [86, 101], [87, 102]]
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 69), ('AROMATIC', 41), ('DOUBLE', 2)]; Atoms: [('C', 43), ('H', 39), ('N', 9), ('O', 4), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 94), ('AROMATIC', 16), ('DOUBLE', 2)]; Atoms: [('C', 43), ('H', 39), ('N', 9), ('O', 4), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ Aromatic correction done ------------
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:Fragments: 3; Bonds: [('SINGLE', 78), ('AROMATIC', 22), ('DOUBLE', 1)]; Atoms: [('C', 43), ('H', 39), ('N', 9), ('O', 4), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ ring fixes done ------------
# DEBUG:Fragmenstein:Storing molecule #3 in `.modifications`
# DEBUG:Fragmenstein:Fragments: 3; Bonds: [('SINGLE', 78), ('AROMATIC', 22), ('DOUBLE', 1)]; Atoms: [('C', 43), ('H', 39), ('N', 9), ('O', 4), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ oddity fixes done ------------
# DEBUG:Fragmenstein:Fragments: 3; Bonds: [('SINGLE', 110), ('AROMATIC', 22), ('DOUBLE', 1)]; Atoms: [('H', 71), ('C', 43), ('N', 9), ('O', 4), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ hydrogens done ------------
# DEBUG:Fragmenstein:(Iteration: 0) N problems 7
# DEBUG:Fragmenstein:(Iteration: 0) Issue AtomValenceException: Explicit valence for atom # 16 H, 2, is greater than permitted
# DEBUG:Fragmenstein:16 H: 2 bonds 2.0
# INFO:Fragmenstein:Shifting atom from H to O
# DEBUG:Fragmenstein:1 appears successful.
# DEBUG:Fragmenstein:(Iteration: 1) N problems 6
# DEBUG:Fragmenstein:(Iteration: 1) Issue AtomValenceException: Explicit valence for atom # 18 H, 2, is greater than permitted
# DEBUG:Fragmenstein:18 H: 2 bonds 2.0
# INFO:Fragmenstein:Shifting atom from H to O
# DEBUG:Fragmenstein:2 appears successful.
# DEBUG:Fragmenstein:(Iteration: 2) N problems 5
# DEBUG:Fragmenstein:(Iteration: 2) Issue AtomValenceException: Explicit valence for atom # 21 H, 2, is greater than permitted
# DEBUG:Fragmenstein:21 H: 2 bonds 2.0
# INFO:Fragmenstein:Shifting atom from H to O
# DEBUG:Fragmenstein:3 appears successful.
# DEBUG:Fragmenstein:(Iteration: 3) N problems 4
# DEBUG:Fragmenstein:(Iteration: 3) Issue AtomValenceException: Explicit valence for atom # 23 H, 3, is greater than permitted
# DEBUG:Fragmenstein:23 H: 2 bonds 3.0
# INFO:Fragmenstein:Shifting atom from H to O
# DEBUG:Fragmenstein:4 appears successful.
# DEBUG:Fragmenstein:(Iteration: 4) N problems 3
# DEBUG:Fragmenstein:(Iteration: 4) Issue AtomValenceException: Explicit valence for atom # 31 H, 2, is greater than permitted
# DEBUG:Fragmenstein:31 H: 2 bonds 2.0
# INFO:Fragmenstein:Shifting atom from H to O
# DEBUG:Fragmenstein:5 appears successful.
# DEBUG:Fragmenstein:(Iteration: 5) N problems 2
# DEBUG:Fragmenstein:(Iteration: 5) Issue AtomValenceException: Explicit valence for atom # 60 N, 5, is greater than permitted
# DEBUG:Fragmenstein:60 N: 5 bonds 5.0
# WARNING:Fragmenstein:In molecule (hit0-hit1) breaking bond to atom 60
# INFO:Fragmenstein:Shifting atom from N to N
# DEBUG:Fragmenstein:6 appears successful.
# DEBUG:Fragmenstein:(Iteration: 6) N problems 1
# DEBUG:Fragmenstein:(Iteration: 6) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 83 84 85
# INFO:Fragmenstein:Ring triages seems to have failed. Is it a valence thing?
# WARNING:Fragmenstein:Attempting default valency (not max)
# DEBUG:Fragmenstein:72 C: 3 bonds 3.5
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:77 C: 3 bonds 4.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:80 C: 3 bonds 4.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:81 C: 3 bonds 4.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:83 C: 3 bonds 4.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:84 C: 3 bonds 4.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:85 C: 3 bonds 4.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:7 appears successful.
# DEBUG:Fragmenstein:(Iteration: 7) N problems 1
# DEBUG:Fragmenstein:(Iteration: 7) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 83 84 85
# INFO:Fragmenstein:downgrading whole ring due to C atom i=72
# INFO:Fragmenstein:downgrading whole ring due to C atom i=77
# INFO:Fragmenstein:downgrading whole ring due to C atom i=80
# INFO:Fragmenstein:downgrading whole ring due to C atom i=81
# INFO:Fragmenstein:downgrading whole ring due to C atom i=83
# INFO:Fragmenstein:downgrading whole ring due to C atom i=84
# INFO:Fragmenstein:downgrading whole ring due to C atom i=85
# DEBUG:Fragmenstein:8 appears unsuccessful.
# DEBUG:Fragmenstein:(Iteration: 8) N problems 1
# DEBUG:Fragmenstein:(Iteration: 8) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 82 83 84 85 89
# INFO:Fragmenstein:Ring triages seems to have failed. Is it a valence thing?
# WARNING:Fragmenstein:Attempting default valency (not max)
# DEBUG:Fragmenstein:72 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:77 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:80 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:81 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:82 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:83 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:84 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:85 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:89 C: 3 bonds 3.0
# DEBUG:Fragmenstein:	Valence seems correct
# DEBUG:Fragmenstein:9 appears successful.
# DEBUG:Fragmenstein:(Iteration: 9) N problems 1
# DEBUG:Fragmenstein:(Iteration: 9) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 82 83 84 85 89
# INFO:Fragmenstein:downgrading whole ring due to C atom i=72
# INFO:Fragmenstein:downgrading whole ring due to C atom i=77
# INFO:Fragmenstein:downgrading whole ring due to C atom i=80
# INFO:Fragmenstein:downgrading whole ring due to C atom i=81
# INFO:Fragmenstein:downgrading whole ring due to C atom i=82
# INFO:Fragmenstein:downgrading whole ring due to C atom i=83
# INFO:Fragmenstein:downgrading whole ring due to C atom i=84
# INFO:Fragmenstein:downgrading whole ring due to C atom i=85
# INFO:Fragmenstein:downgrading whole ring due to C atom i=89
# DEBUG:Fragmenstein:10 appears unsuccessful.
# DEBUG:Fragmenstein:(Iteration: 10) N problems 1
# DEBUG:Fragmenstein:(Iteration: 10) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 82 83 84 85 89
# INFO:Fragmenstein:downgrading whole ring due to C atom i=72
# INFO:Fragmenstein:downgrading whole ring due to C atom i=77
# INFO:Fragmenstein:downgrading whole ring due to C atom i=80
# INFO:Fragmenstein:downgrading whole ring due to C atom i=81
# INFO:Fragmenstein:downgrading whole ring due to C atom i=82
# INFO:Fragmenstein:downgrading whole ring due to C atom i=83
# INFO:Fragmenstein:downgrading whole ring due to C atom i=84
# INFO:Fragmenstein:downgrading whole ring due to C atom i=85
# INFO:Fragmenstein:downgrading whole ring due to C atom i=89
# DEBUG:Fragmenstein:11 appears unsuccessful.
# DEBUG:Fragmenstein:(Iteration: 11) N problems 1
# DEBUG:Fragmenstein:(Iteration: 11) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 82 83 84 85 89
# INFO:Fragmenstein:downgrading whole ring due to C atom i=72
# INFO:Fragmenstein:downgrading whole ring due to C atom i=77
# INFO:Fragmenstein:downgrading whole ring due to C atom i=80
# INFO:Fragmenstein:downgrading whole ring due to C atom i=81
# INFO:Fragmenstein:downgrading whole ring due to C atom i=82
# INFO:Fragmenstein:downgrading whole ring due to C atom i=83
# INFO:Fragmenstein:downgrading whole ring due to C atom i=84
# INFO:Fragmenstein:downgrading whole ring due to C atom i=85
# INFO:Fragmenstein:downgrading whole ring due to C atom i=89
# DEBUG:Fragmenstein:12 appears unsuccessful.
# DEBUG:Fragmenstein:(Iteration: 12) N problems 1
# DEBUG:Fragmenstein:(Iteration: 12) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 82 83 84 85 89
# INFO:Fragmenstein:downgrading whole ring due to C atom i=72
# INFO:Fragmenstein:downgrading whole ring due to C atom i=77
# INFO:Fragmenstein:downgrading whole ring due to C atom i=80
# INFO:Fragmenstein:downgrading whole ring due to C atom i=81
# INFO:Fragmenstein:downgrading whole ring due to C atom i=82
# INFO:Fragmenstein:downgrading whole ring due to C atom i=83
# INFO:Fragmenstein:downgrading whole ring due to C atom i=84
# INFO:Fragmenstein:downgrading whole ring due to C atom i=85
# INFO:Fragmenstein:downgrading whole ring due to C atom i=89
# DEBUG:Fragmenstein:13 appears unsuccessful.
# DEBUG:Fragmenstein:(Iteration: 13) N problems 1
# DEBUG:Fragmenstein:(Iteration: 13) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 82 83 84 85 89
# INFO:Fragmenstein:downgrading whole ring due to C atom i=72
# INFO:Fragmenstein:downgrading whole ring due to C atom i=77
# INFO:Fragmenstein:downgrading whole ring due to C atom i=80
# INFO:Fragmenstein:downgrading whole ring due to C atom i=81
# INFO:Fragmenstein:downgrading whole ring due to C atom i=82
# INFO:Fragmenstein:downgrading whole ring due to C atom i=83
# INFO:Fragmenstein:downgrading whole ring due to C atom i=84
# INFO:Fragmenstein:downgrading whole ring due to C atom i=85
# INFO:Fragmenstein:downgrading whole ring due to C atom i=89
# DEBUG:Fragmenstein:14 appears unsuccessful.
# DEBUG:Fragmenstein:(Iteration: 14) N problems 1
# DEBUG:Fragmenstein:(Iteration: 14) Issue KekulizeException: Can't kekulize mol.  Unkekulized atoms: 72 77 80 81 82 83 84 85 89
# INFO:Fragmenstein:downgrading whole ring due to C atom i=72
# INFO:Fragmenstein:downgrading whole ring due to C atom i=77
# INFO:Fragmenstein:downgrading whole ring due to C atom i=80
# INFO:Fragmenstein:downgrading whole ring due to C atom i=81
# INFO:Fragmenstein:downgrading whole ring due to C atom i=82
# INFO:Fragmenstein:downgrading whole ring due to C atom i=83
# INFO:Fragmenstein:downgrading whole ring due to C atom i=84
# INFO:Fragmenstein:downgrading whole ring due to C atom i=85
# INFO:Fragmenstein:downgrading whole ring due to C atom i=89
# DEBUG:Fragmenstein:15 appears unsuccessful.
# ERROR:Fragmenstein:Unfixable
# DEBUG:Fragmenstein:Fragments: 8; Bonds: [('SINGLE', 116), ('AROMATIC', 11), ('DOUBLE', 1)]; Atoms: [('H', 66), ('C', 43), ('N', 9), ('O', 9), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ valence drama done ------------
# DEBUG:Fragmenstein:Some issues remain.
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# DEBUG:Fragmenstein:Fragments: 8; Bonds: [('SINGLE', 121), ('AROMATIC', 4), ('DOUBLE', 3)]; Atoms: [('H', 66), ('C', 43), ('N', 9), ('O', 9), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ check against radicals done ------------
# DEBUG:Fragmenstein:Some issues remain... Trying again!
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 8; Bonds: [('SINGLE', 121), ('AROMATIC', 4), ('DOUBLE', 3)]; Atoms: [('H', 66), ('C', 43), ('N', 9), ('O', 9), ('F', 2), ('Cl', 1)]
# CRITICAL:Fragmenstein:Absorption required for the atom pairs: [[56, 102], [71, 104], [79, 125], [126, 119], [128, 108], [117, 76], [117, 115]]
# DEBUG:Fragmenstein:Fragments: 7; Bonds: [('SINGLE', 120), ('AROMATIC', 4), ('DOUBLE', 3)]; Atoms: [('H', 60), ('C', 43), ('O', 9), ('N', 8), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Fragments: 7; Bonds: [('SINGLE', 123), ('DOUBLE', 3), ('AROMATIC', 1)]; Atoms: [('H', 60), ('C', 43), ('O', 9), ('N', 8), ('F', 2), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ Aromatic correction done ------------
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# INFO:Fragmenstein:Radical in aromatic structure present
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Shriking the smaller ring to change from bridged to fused.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# ...
# DEBUG:Fragmenstein:Current deque rotation count -61
# DEBUG:Fragmenstein:Current deque rotation count -62
# DEBUG:Fragmenstein:Current deque rotation count -63
# DEBUG:Fragmenstein:Current deque rotation count -64
# DEBUG:Fragmenstein:Current deque rotation count -65
# DEBUG:Fragmenstein:Current deque rotation count -66
# DEBUG:Fragmenstein:Current deque rotation count -67
# DEBUG:Fragmenstein:Current deque rotation count -68
# DEBUG:Fragmenstein:Current deque rotation count -69
# DEBUG:Fragmenstein:Current deque rotation count -70
# DEBUG:Fragmenstein:Current deque rotation count -71
# DEBUG:Fragmenstein:Current deque rotation count -72
# DEBUG:Fragmenstein:Current deque rotation count -73
# DEBUG:Fragmenstein:Current deque rotation count -74
# DEBUG:Fragmenstein:Current deque rotation count -75
# DEBUG:Fragmenstein:Current deque rotation count -76
# DEBUG:Fragmenstein:Current deque rotation count -77
# DEBUG:Fragmenstein:Current deque rotation count -78
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing N at position 0
# DEBUG:Fragmenstein:Parsing C at position 22
# DEBUG:Fragmenstein:Parsing C at position 21
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing N at position 23
# DEBUG:Fragmenstein:Parsing C at position 25
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing O at position 4
# DEBUG:Fragmenstein:Parsing N at position 7
# DEBUG:Fragmenstein:Parsing C at position 17
# DEBUG:Fragmenstein:Parsing C at position 24
# DEBUG:Fragmenstein:Parsing C at position 26
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing O at position 8
# DEBUG:Fragmenstein:Parsing N at position 16
# DEBUG:Fragmenstein:Parsing C at position 18
# DEBUG:Fragmenstein:Parsing C at position 27
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing F at position 1
# DEBUG:Fragmenstein:Parsing C at position 6
# DEBUG:Fragmenstein:Parsing C at position 19
# DEBUG:Fragmenstein:Parsing C at position 20
# DEBUG:Fragmenstein:Parsing C at position 28
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing O at position 2
# DEBUG:Fragmenstein:Parsing N at position 15
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing O at position 38
# DEBUG:Fragmenstein:Parsing C at position 10
# DEBUG:Fragmenstein:Parsing C at position 14
# DEBUG:Fragmenstein:Parsing C at position 31
# DEBUG:Fragmenstein:Parsing C at position 39
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing C at position 13
# DEBUG:Fragmenstein:Parsing C at position 35
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing Cl at position 9
# DEBUG:Fragmenstein:Parsing O at position 12
# DEBUG:Fragmenstein:Parsing C at position 34
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing H at position 41
# DEBUG:Fragmenstein:Parsing H at position 57
# DEBUG:Fragmenstein:Parsing H at position 58
# DEBUG:Fragmenstein:Parsing H at position 45
# DEBUG:Fragmenstein:Parsing H at position 59
# DEBUG:Fragmenstein:Parsing H at position 60
# DEBUG:Fragmenstein:Parsing H at position 61
# DEBUG:Fragmenstein:Parsing H at position 74
# DEBUG:Fragmenstein:Parsing H at position 42
# DEBUG:Fragmenstein:Parsing H at position 43
# DEBUG:Fragmenstein:Parsing H at position 44
# DEBUG:Fragmenstein:Parsing H at position 54
# DEBUG:Fragmenstein:Parsing H at position 55
# DEBUG:Fragmenstein:Parsing H at position 56
# DEBUG:Fragmenstein:Parsing H at position 62
# DEBUG:Fragmenstein:Parsing H at position 63
# DEBUG:Fragmenstein:Parsing H at position 75
# DEBUG:Fragmenstein:Parsing H at position 76
# DEBUG:Fragmenstein:Parsing H at position 64
# DEBUG:Fragmenstein:Parsing H at position 65
# DEBUG:Fragmenstein:Parsing H at position 46
# DEBUG:Fragmenstein:Parsing H at position 47
# DEBUG:Fragmenstein:Parsing H at position 52
# DEBUG:Fragmenstein:Parsing H at position 53
# DEBUG:Fragmenstein:Parsing H at position 66
# DEBUG:Fragmenstein:Parsing H at position 67
# DEBUG:Fragmenstein:Parsing H at position 77
# DEBUG:Fragmenstein:Parsing H at position 78
# DEBUG:Fragmenstein:Parsing H at position 48
# DEBUG:Fragmenstein:Parsing H at position 49
# DEBUG:Fragmenstein:Parsing H at position 50
# DEBUG:Fragmenstein:Parsing H at position 51
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 79
# DEBUG:Fragmenstein:Parsing H at position 80
# DEBUG:Fragmenstein:Parsing H at position 81
# DEBUG:Fragmenstein:Parsing H at position 71
# DEBUG:Fragmenstein:Parsing H at position 72
# DEBUG:Fragmenstein:Parsing H at position 68
# DEBUG:Fragmenstein:Parsing H at position 69
# DEBUG:Fragmenstein:Parsing H at position 70
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0-hit1 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Current deque rotation count -54
# DEBUG:Fragmenstein:Current deque rotation count -55
# DEBUG:Fragmenstein:Current deque rotation count -56
# DEBUG:Fragmenstein:Current deque rotation count -57
# DEBUG:Fragmenstein:Current deque rotation count -58
# DEBUG:Fragmenstein:Current deque rotation count -59
# DEBUG:Fragmenstein:Current deque rotation count -60
# DEBUG:Fragmenstein:Current deque rotation count -61
# DEBUG:Fragmenstein:Current deque rotation count -62
# DEBUG:Fragmenstein:Current deque rotation count -63
# DEBUG:Fragmenstein:Current deque rotation count -64
# DEBUG:Fragmenstein:Current deque rotation count -65
# DEBUG:Fragmenstein:Current deque rotation count -66
# DEBUG:Fragmenstein:Current deque rotation count -67
# DEBUG:Fragmenstein:Current deque rotation count -68
# DEBUG:Fragmenstein:Current deque rotation count -69
# DEBUG:Fragmenstein:Current deque rotation count -70
# DEBUG:Fragmenstein:Current deque rotation count -71
# DEBUG:Fragmenstein:Current deque rotation count -72
# DEBUG:Fragmenstein:Current deque rotation count -73
# DEBUG:Fragmenstein:Current deque rotation count -74
# DEBUG:Fragmenstein:Current deque rotation count -75
# DEBUG:Fragmenstein:Current deque rotation count -76
# DEBUG:Fragmenstein:Current deque rotation count -77
# DEBUG:Fragmenstein:Current deque rotation count -78
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing N at position 0
# DEBUG:Fragmenstein:Parsing C at position 22
# DEBUG:Fragmenstein:Parsing C at position 21
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing N at position 23
# DEBUG:Fragmenstein:Parsing C at position 25
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing O at position 4
# DEBUG:Fragmenstein:Parsing N at position 7
# DEBUG:Fragmenstein:Parsing C at position 17
# DEBUG:Fragmenstein:Parsing C at position 24
# DEBUG:Fragmenstein:Parsing C at position 26
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing O at position 8
# DEBUG:Fragmenstein:Parsing N at position 16
# DEBUG:Fragmenstein:Parsing C at position 18
# DEBUG:Fragmenstein:Parsing C at position 27
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing F at position 1
# DEBUG:Fragmenstein:Parsing C at position 6
# DEBUG:Fragmenstein:Parsing C at position 19
# DEBUG:Fragmenstein:Parsing C at position 20
# DEBUG:Fragmenstein:Parsing C at position 28
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing O at position 2
# DEBUG:Fragmenstein:Parsing N at position 15
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing O at position 38
# DEBUG:Fragmenstein:Parsing C at position 10
# DEBUG:Fragmenstein:Parsing C at position 14
# DEBUG:Fragmenstein:Parsing C at position 31
# DEBUG:Fragmenstein:Parsing C at position 39
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing C at position 13
# DEBUG:Fragmenstein:Parsing C at position 35
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing Cl at position 9
# DEBUG:Fragmenstein:Parsing O at position 12
# DEBUG:Fragmenstein:Parsing C at position 34
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing H at position 41
# DEBUG:Fragmenstein:Parsing H at position 57
# DEBUG:Fragmenstein:Parsing H at position 58
# DEBUG:Fragmenstein:Parsing H at position 45
# DEBUG:Fragmenstein:Parsing H at position 59
# DEBUG:Fragmenstein:Parsing H at position 60
# DEBUG:Fragmenstein:Parsing H at position 61
# DEBUG:Fragmenstein:Parsing H at position 74
# DEBUG:Fragmenstein:Parsing H at position 42
# DEBUG:Fragmenstein:Parsing H at position 43
# DEBUG:Fragmenstein:Parsing H at position 44
# DEBUG:Fragmenstein:Parsing H at position 54
# DEBUG:Fragmenstein:Parsing H at position 55
# DEBUG:Fragmenstein:Parsing H at position 56
# DEBUG:Fragmenstein:Parsing H at position 62
# DEBUG:Fragmenstein:Parsing H at position 63
# DEBUG:Fragmenstein:Parsing H at position 75
# DEBUG:Fragmenstein:Parsing H at position 76
# DEBUG:Fragmenstein:Parsing H at position 64
# DEBUG:Fragmenstein:Parsing H at position 65
# DEBUG:Fragmenstein:Parsing H at position 46
# DEBUG:Fragmenstein:Parsing H at position 47
# DEBUG:Fragmenstein:Parsing H at position 52
# DEBUG:Fragmenstein:Parsing H at position 53
# DEBUG:Fragmenstein:Parsing H at position 66
# DEBUG:Fragmenstein:Parsing H at position 67
# DEBUG:Fragmenstein:Parsing H at position 77
# DEBUG:Fragmenstein:Parsing H at position 78
# DEBUG:Fragmenstein:Parsing H at position 48
# DEBUG:Fragmenstein:Parsing H at position 49
# DEBUG:Fragmenstein:Parsing H at position 50
# DEBUG:Fragmenstein:Parsing H at position 51
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 79
# DEBUG:Fragmenstein:Parsing H at position 80
# DEBUG:Fragmenstein:Parsing H at position 81
# DEBUG:Fragmenstein:Parsing H at position 71
# DEBUG:Fragmenstein:Parsing H at position 72
# DEBUG:Fragmenstein:Parsing H at position 68
# DEBUG:Fragmenstein:Parsing H at position 69
# DEBUG:Fragmenstein:Parsing H at position 70
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0-hit1 - placing monster in structure
# DEBUG:Fragmenstein:hit0-hit1 - saving params
# DEBUG:Fragmenstein:hit0-hit1 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0-hit1 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0-hit1 - saving mols from monster
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.5:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.25:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.125:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.0625:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.03125:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.015625:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.0078125:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.00390625:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.0:  0.3170935259824743 kcal/mol.
# WARNING:Fragmenstein:hit0-hit1 - failed to minimise without constraints:  0.3170935259824743 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0-hit1 - calculating mRMSD
# INFO:Fragmenstein:hit0-hit1 - final score: 0.3170935259824743 kcal/mol, RMSD: 1.47176750792618.
# DEBUG:Fragmenstein:hit0-hit1 - saving pose from igor
# DEBUG:Fragmenstein:hit0-hit1 - calculating Gibbs
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# INFO:Fragmenstein:hit0-hit1 - Time taken: 64.87794184684753

# %%
# Process each SMILES string with the reference molecule using Victor
for i, smile in enumerate(smiles_list):
    hit_mol = Chem.AddHs(AllChem.MolFromSmiles(smile))
    AllChem.EmbedMolecule(hit_mol, AllChem.ETKDG())
    victor_with_ref = Victor(hits=[reference_mol, hit_mol], pdb_filename=protein_pdb_path)
    try:
        victor_with_ref.combine()
    except Chem.AtomValenceException:
        logging.info(f'Atom valence exception occurred for molecule {i+1} with reference, trying to rectify...')
        victor_with_ref.rectify(collapse_rings=True, joining_cutoff=3.0)
        victor_with_ref.combine()

    optimized_with_ref_molecule = victor_with_ref.minimized_mol

    # Append 2D structure to the list
    mol_2d_structures.append(optimized_with_ref_molecule)

    optimized_with_ref_smiles = Chem.MolToSmiles(optimized_with_ref_molecule)
    minimized_smiles_list.append(optimized_with_ref_smiles)

    # Calculate Lipinski's descriptors for the molecule combined with the reference
    mw_ref = Descriptors.ExactMolWt(optimized_with_ref_molecule)
    logp_ref = Descriptors.MolLogP(optimized_with_ref_molecule)
    hba_ref = Descriptors.NumHAcceptors(optimized_with_ref_molecule)
    hbd_ref = Descriptors.NumHDonors(optimized_with_ref_molecule)

    # Append data to molecule_data list
    molecule_data.append([optimized_with_ref_smiles, mw_ref, logp_ref, hba_ref, hbd_ref, f'optimized_with_ref_molecule_{i}.mol'])
# Out:
# Streaming output truncated to the last 5000 lines.
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:mysterious ring system 9 + 6
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a benzo-azetine–kind-of-thing: expanding to indole
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (15, 23, 24, 33, 99), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [] with [] in the inside and [] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a spiro bicycle
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(34, 25, 96, 16, 100), (91, 92, 93, 94, 95, 96), (16, 96, 25, 24, 23, 72)] share [96] with [] in the inside and [96] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(32, 88, 87, 69), (67, 68, 69, 70, 71, 72), (86, 90, 89, 88, 87, 69, 68), (86, 90, 89, 88, 32, 69, 68)] share [69] with [] in the inside and [69] on the edge?
# WARNING:Fragmenstein:Too many trials to remove bridge.
# ...
# DEBUG:Fragmenstein:Current deque rotation count -57
# DEBUG:Fragmenstein:Current deque rotation count -58
# DEBUG:Fragmenstein:Current deque rotation count -59
# DEBUG:Fragmenstein:Current deque rotation count -60
# DEBUG:Fragmenstein:Current deque rotation count -61
# DEBUG:Fragmenstein:Current deque rotation count -62
# DEBUG:Fragmenstein:Current deque rotation count -63
# DEBUG:Fragmenstein:Current deque rotation count -64
# DEBUG:Fragmenstein:Current deque rotation count -65
# DEBUG:Fragmenstein:Current deque rotation count -66
# DEBUG:Fragmenstein:Current deque rotation count -67
# DEBUG:Fragmenstein:Current deque rotation count -68
# DEBUG:Fragmenstein:Current deque rotation count -69
# DEBUG:Fragmenstein:Current deque rotation count -70
# DEBUG:Fragmenstein:Current deque rotation count -71
# DEBUG:Fragmenstein:Current deque rotation count -72
# DEBUG:Fragmenstein:Current deque rotation count -73
# DEBUG:Fragmenstein:Current deque rotation count -74
# DEBUG:Fragmenstein:Current deque rotation count -75
# DEBUG:Fragmenstein:Current deque rotation count -76
# DEBUG:Fragmenstein:Current deque rotation count -77
# DEBUG:Fragmenstein:Current deque rotation count -78
# DEBUG:Fragmenstein:Current deque rotation count -79
# DEBUG:Fragmenstein:Current deque rotation count -80
# DEBUG:Fragmenstein:Current deque rotation count -81
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing N at position 0
# DEBUG:Fragmenstein:Parsing C at position 16
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 23
# DEBUG:Fragmenstein:Parsing O at position 28
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 27
# DEBUG:Fragmenstein:Parsing N at position 30
# DEBUG:Fragmenstein:Parsing C at position 24
# DEBUG:Fragmenstein:Parsing C at position 26
# DEBUG:Fragmenstein:Parsing N at position 25
# DEBUG:Fragmenstein:Parsing N at position 31
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing C at position 5
# DEBUG:Fragmenstein:Parsing C at position 9
# DEBUG:Fragmenstein:Parsing C at position 4
# DEBUG:Fragmenstein:Parsing C at position 6
# DEBUG:Fragmenstein:Parsing C at position 7
# DEBUG:Fragmenstein:Parsing C at position 8
# DEBUG:Fragmenstein:Parsing C at position 15
# DEBUG:Fragmenstein:Parsing N at position 10
# DEBUG:Fragmenstein:Parsing C at position 14
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing O at position 32
# DEBUG:Fragmenstein:Parsing S at position 1
# DEBUG:Fragmenstein:Parsing C at position 12
# DEBUG:Fragmenstein:Parsing C at position 13
# DEBUG:Fragmenstein:Parsing C at position 17
# DEBUG:Fragmenstein:Parsing C at position 18
# DEBUG:Fragmenstein:Parsing C at position 22
# DEBUG:Fragmenstein:Parsing C at position 19
# DEBUG:Fragmenstein:Parsing C at position 21
# DEBUG:Fragmenstein:Parsing C at position 20
# DEBUG:Fragmenstein:Parsing H at position 34
# DEBUG:Fragmenstein:Parsing H at position 35
# DEBUG:Fragmenstein:Parsing H at position 61
# DEBUG:Fragmenstein:Parsing H at position 82
# DEBUG:Fragmenstein:Parsing H at position 83
# DEBUG:Fragmenstein:Parsing H at position 84
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 80
# DEBUG:Fragmenstein:Parsing H at position 81
# DEBUG:Fragmenstein:Parsing H at position 78
# DEBUG:Fragmenstein:Parsing H at position 79
# DEBUG:Fragmenstein:Parsing H at position 74
# DEBUG:Fragmenstein:Parsing H at position 76
# DEBUG:Fragmenstein:Parsing H at position 77
# DEBUG:Fragmenstein:Parsing H at position 75
# DEBUG:Fragmenstein:Parsing H at position 37
# DEBUG:Fragmenstein:Parsing H at position 38
# DEBUG:Fragmenstein:Parsing H at position 39
# DEBUG:Fragmenstein:Parsing H at position 42
# DEBUG:Fragmenstein:Parsing H at position 43
# DEBUG:Fragmenstein:Parsing H at position 50
# DEBUG:Fragmenstein:Parsing H at position 40
# DEBUG:Fragmenstein:Parsing H at position 41
# DEBUG:Fragmenstein:Parsing H at position 44
# DEBUG:Fragmenstein:Parsing H at position 45
# DEBUG:Fragmenstein:Parsing H at position 46
# DEBUG:Fragmenstein:Parsing H at position 47
# DEBUG:Fragmenstein:Parsing H at position 48
# DEBUG:Fragmenstein:Parsing H at position 49
# DEBUG:Fragmenstein:Parsing H at position 60
# DEBUG:Fragmenstein:Parsing H at position 51
# DEBUG:Fragmenstein:Parsing H at position 58
# DEBUG:Fragmenstein:Parsing H at position 59
# DEBUG:Fragmenstein:Parsing H at position 52
# DEBUG:Fragmenstein:Parsing H at position 53
# DEBUG:Fragmenstein:Parsing H at position 36
# DEBUG:Fragmenstein:Parsing H at position 54
# DEBUG:Fragmenstein:Parsing H at position 55
# DEBUG:Fragmenstein:Parsing H at position 56
# DEBUG:Fragmenstein:Parsing H at position 57
# DEBUG:Fragmenstein:Parsing H at position 62
# DEBUG:Fragmenstein:Parsing H at position 63
# DEBUG:Fragmenstein:Parsing H at position 64
# DEBUG:Fragmenstein:Parsing H at position 71
# DEBUG:Fragmenstein:Parsing H at position 72
# DEBUG:Fragmenstein:Parsing H at position 65
# DEBUG:Fragmenstein:Parsing H at position 66
# DEBUG:Fragmenstein:Parsing H at position 69
# DEBUG:Fragmenstein:Parsing H at position 70
# DEBUG:Fragmenstein:Parsing H at position 67
# DEBUG:Fragmenstein:Parsing H at position 68
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0-hit1 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Current deque rotation count -54
# DEBUG:Fragmenstein:Current deque rotation count -55
# DEBUG:Fragmenstein:Current deque rotation count -56
# DEBUG:Fragmenstein:Current deque rotation count -57
# DEBUG:Fragmenstein:Current deque rotation count -58
# DEBUG:Fragmenstein:Current deque rotation count -59
# DEBUG:Fragmenstein:Current deque rotation count -60
# DEBUG:Fragmenstein:Current deque rotation count -61
# DEBUG:Fragmenstein:Current deque rotation count -62
# DEBUG:Fragmenstein:Current deque rotation count -63
# DEBUG:Fragmenstein:Current deque rotation count -64
# DEBUG:Fragmenstein:Current deque rotation count -65
# DEBUG:Fragmenstein:Current deque rotation count -66
# DEBUG:Fragmenstein:Current deque rotation count -67
# DEBUG:Fragmenstein:Current deque rotation count -68
# DEBUG:Fragmenstein:Current deque rotation count -69
# DEBUG:Fragmenstein:Current deque rotation count -70
# DEBUG:Fragmenstein:Current deque rotation count -71
# DEBUG:Fragmenstein:Current deque rotation count -72
# DEBUG:Fragmenstein:Current deque rotation count -73
# DEBUG:Fragmenstein:Current deque rotation count -74
# DEBUG:Fragmenstein:Current deque rotation count -75
# DEBUG:Fragmenstein:Current deque rotation count -76
# DEBUG:Fragmenstein:Current deque rotation count -77
# DEBUG:Fragmenstein:Current deque rotation count -78
# DEBUG:Fragmenstein:Current deque rotation count -79
# DEBUG:Fragmenstein:Current deque rotation count -80
# DEBUG:Fragmenstein:Current deque rotation count -81
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing N at position 0
# DEBUG:Fragmenstein:Parsing C at position 16
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 23
# DEBUG:Fragmenstein:Parsing O at position 28
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 27
# DEBUG:Fragmenstein:Parsing N at position 30
# DEBUG:Fragmenstein:Parsing C at position 24
# DEBUG:Fragmenstein:Parsing C at position 26
# DEBUG:Fragmenstein:Parsing N at position 25
# DEBUG:Fragmenstein:Parsing N at position 31
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing C at position 5
# DEBUG:Fragmenstein:Parsing C at position 9
# DEBUG:Fragmenstein:Parsing C at position 4
# DEBUG:Fragmenstein:Parsing C at position 6
# DEBUG:Fragmenstein:Parsing C at position 7
# DEBUG:Fragmenstein:Parsing C at position 8
# DEBUG:Fragmenstein:Parsing C at position 15
# DEBUG:Fragmenstein:Parsing N at position 10
# DEBUG:Fragmenstein:Parsing C at position 14
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing O at position 32
# DEBUG:Fragmenstein:Parsing S at position 1
# DEBUG:Fragmenstein:Parsing C at position 12
# DEBUG:Fragmenstein:Parsing C at position 13
# DEBUG:Fragmenstein:Parsing C at position 17
# DEBUG:Fragmenstein:Parsing C at position 18
# DEBUG:Fragmenstein:Parsing C at position 22
# DEBUG:Fragmenstein:Parsing C at position 19
# DEBUG:Fragmenstein:Parsing C at position 21
# DEBUG:Fragmenstein:Parsing C at position 20
# DEBUG:Fragmenstein:Parsing H at position 34
# DEBUG:Fragmenstein:Parsing H at position 35
# DEBUG:Fragmenstein:Parsing H at position 61
# DEBUG:Fragmenstein:Parsing H at position 82
# DEBUG:Fragmenstein:Parsing H at position 83
# DEBUG:Fragmenstein:Parsing H at position 84
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 80
# DEBUG:Fragmenstein:Parsing H at position 81
# DEBUG:Fragmenstein:Parsing H at position 78
# DEBUG:Fragmenstein:Parsing H at position 79
# DEBUG:Fragmenstein:Parsing H at position 74
# DEBUG:Fragmenstein:Parsing H at position 76
# DEBUG:Fragmenstein:Parsing H at position 77
# DEBUG:Fragmenstein:Parsing H at position 75
# DEBUG:Fragmenstein:Parsing H at position 37
# DEBUG:Fragmenstein:Parsing H at position 38
# DEBUG:Fragmenstein:Parsing H at position 39
# DEBUG:Fragmenstein:Parsing H at position 42
# DEBUG:Fragmenstein:Parsing H at position 43
# DEBUG:Fragmenstein:Parsing H at position 50
# DEBUG:Fragmenstein:Parsing H at position 40
# DEBUG:Fragmenstein:Parsing H at position 41
# DEBUG:Fragmenstein:Parsing H at position 44
# DEBUG:Fragmenstein:Parsing H at position 45
# DEBUG:Fragmenstein:Parsing H at position 46
# DEBUG:Fragmenstein:Parsing H at position 47
# DEBUG:Fragmenstein:Parsing H at position 48
# DEBUG:Fragmenstein:Parsing H at position 49
# DEBUG:Fragmenstein:Parsing H at position 60
# DEBUG:Fragmenstein:Parsing H at position 51
# DEBUG:Fragmenstein:Parsing H at position 58
# DEBUG:Fragmenstein:Parsing H at position 59
# DEBUG:Fragmenstein:Parsing H at position 52
# DEBUG:Fragmenstein:Parsing H at position 53
# DEBUG:Fragmenstein:Parsing H at position 36
# DEBUG:Fragmenstein:Parsing H at position 54
# DEBUG:Fragmenstein:Parsing H at position 55
# DEBUG:Fragmenstein:Parsing H at position 56
# DEBUG:Fragmenstein:Parsing H at position 57
# DEBUG:Fragmenstein:Parsing H at position 62
# DEBUG:Fragmenstein:Parsing H at position 63
# DEBUG:Fragmenstein:Parsing H at position 64
# DEBUG:Fragmenstein:Parsing H at position 71
# DEBUG:Fragmenstein:Parsing H at position 72
# DEBUG:Fragmenstein:Parsing H at position 65
# DEBUG:Fragmenstein:Parsing H at position 66
# DEBUG:Fragmenstein:Parsing H at position 69
# DEBUG:Fragmenstein:Parsing H at position 70
# DEBUG:Fragmenstein:Parsing H at position 67
# DEBUG:Fragmenstein:Parsing H at position 68
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0-hit1 - placing monster in structure
# DEBUG:Fragmenstein:hit0-hit1 - saving params
# DEBUG:Fragmenstein:hit0-hit1 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0-hit1 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0-hit1 - saving mols from monster
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.5:  4.140984237997712 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.25:  2.827491718733052 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.125:  1.8235131799056417 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.0625:  0.9472560002323673 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.03125:  0.4137727509623965 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0-hit1 - calculating mRMSD
# INFO:Fragmenstein:hit0-hit1 - final score: -0.005584873560953163 kcal/mol, RMSD: 1.0860453614792933.
# DEBUG:Fragmenstein:hit0-hit1 - saving pose from igor
# DEBUG:Fragmenstein:hit0-hit1 - calculating Gibbs
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# INFO:Fragmenstein:hit0-hit1 - Time taken: 105.60743021965027

# %%
# Assuming each list has the same length and corresponding indices
for i in range(len(minimized_smiles_list)):
    smile = minimized_smiles_list[i]
    mol_2d = mol_2d_structures[i]
    # Correctly unpack all six items from each entry in molecule_data
    mw, logp, hba, hbd, file_name = molecule_data[i][1:]  # Skipping the first item (SMILES string)

    # Print the SMILES string and Lipinski's descriptors
    print(f"Molecule {i+1}:")
    print(f"SMILES: {smile}")
    print(f"Lipinski's Descriptors: MW={mw}, LogP={logp}, HBA={hba}, HBD={hbd}")

    # Display the 2D structure
    display(MolsToGridImage([mol_2d], molsPerRow=1, subImgSize=(300, 300)))

    print("\n-----\n")

# Print the original input SMILES and their 2D structures for comparison
original_smiles = [smiles1, smiles2]  # Replace with your original SMILES strings
for smile in original_smiles:
    mol = Chem.MolFromSmiles(smile)
    print(f"Original SMILES: {smile}")
    display(MolsToGridImage([mol], molsPerRow=1, subImgSize=(300, 300)))
# Out:
# Molecule 1:
# SMILES: [H]c1nc(N([H])C(=O)C([H])([H])N2C(=O)c3c([H])nc(N([H])c4c([H])c([H])c(F)c([H])c4[H])c([H])c3N=C2N2C([H])([H])C([H])([H])OC([H])([H])C2([H])[H])c([H])c([H])c1F
# Lipinski's Descriptors: MW=493.16739397200007, LogP=2.9125999999999994, HBA=8, HBD=2
# -----
#
# Molecule 2:
# SMILES: [H]c1nc(N([H])C(=O)C([H])([H])N2C(=O)c3c([H])nc(-c4c([H])c([H])c([H])c(C([H])([H])[H])c4[H])nc3N=C2N2C([H])([H])C([H])([H])OC([H])([H])C2([H])[H])c([H])c([H])c1Cl
# Lipinski's Descriptors: MW=491.1472652440001, LogP=2.914620000000003, HBA=8, HBD=1
# -----
#
# Molecule 3:
# SMILES: [H]C(=O)C1=C(OC([H])([H])[H])N2C3=C(N([H])C2([H])C2=C1N(C([H])([H])N1C([H])([H])C([H])([H])OC([H])([H])C1([H])[H])[C@@]([H])(C([H])([H])OC([H])([H])C([H])([H])[H])O2)C([H])(C([H])([H])C([H])(F)C([H])([H])C([H])([H])C([H])([H])C([H])(Cl)C([H])([H])C([H])([H])[H])OON3[H]
# Lipinski's Descriptors: MW=601.2678545520013, LogP=2.404300000000002, HBA=12, HBD=2
# -----
#
# Molecule 4:
# SMILES: [H]O[C@]12O[C@@]([H])(ON3C([H])([H])C([H])([H])C(N([H])[H])(N([H])[H])C([H])([H])C3([H])[H])[C@]([H])(N([H])[H])[C@@]1([H])C([H])([H])[S@TB12]([H])(C([H])([H])N([H])[S@SP1]1([H])OC([H])([H])C([H])([H])C([H])([H])N([H])C([H])([H])C([H])([H])/C(C([H])([H])C([H])([H])C([H])([H])F)=C3\C4=C(C([H])([H])C([H])([H])C4([H])C([H])([H])C([H])([H])C(=C([H])[H])/C([H])=N\C([H])=C(OC([H])([H])[H])\C([H])=C([H])/N=C/1N([H])[H])C1([H])N([H])C([H])([H])C([H])([H])C([H])([H])[C@]31[H])C2([H])[H]
# Lipinski's Descriptors: MW=892.519085656002, LogP=3.267100000000008, HBA=15, HBD=10
# -----
#
# Molecule 5:
# SMILES: [H]N1C([H])([H])C([H])([H])C([H])([H])[S@]([H])(C2([H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])C2([H])[H])OC([H])([H])C1([H])C([H])([H])C([H])([H])C([H])([H])[C@]1([H])N([H])[C@@]([H])(N2C([H])([H])C([H])([H])O[C@]([H])(O[C@]([H])(N([H])[H])C([H])([H])[H])C2([H])[H])N(C([H])([H])[H])C([H])([H])C1([H])[H]
# Lipinski's Descriptors: MW=501.37126149200145, LogP=2.341000000000002, HBA=8, HBD=4
# -----
#
# Original SMILES: O=C(Cn1c(N2CCOCC2)nc2cc(Nc3ccc(F)cc3)ncc2c1=O)Nc1ccc(F)cn1
# Original SMILES: Cc1cccc(-c2ncc3c(=O)n(CC(=O)Nc4ccc(Cl)cn4)c(N4CCOCC4)nc3n2)c1

# %%
# Output all data to a CSV file
with open('all_molecule_data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['SMILES', 'Molecular Weight', 'LogP', 'HBA', 'HBD', '2D Structure File'])
    writer.writerows(molecule_data)

logging.info("All molecule data has been saved to all_molecule_data.csv")

# %%
Victor.enable_logfile('victor_log.log', logging.INFO)
