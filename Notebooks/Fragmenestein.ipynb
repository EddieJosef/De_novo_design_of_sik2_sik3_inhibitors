# %%
# Update the package lists for upgrades and new package installations.
# !sudo apt-get update

# Install IPython, setuptools, and pip for Python 3.
# !sudo apt-get install ipython3 python3-setuptools python3-pip
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,463 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [50.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [1,834 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,070 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,796 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,343 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,742 kB]
# Fetched 9,532 kB in 3s (3,783 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-lyx libimagequant0 liblbfgsb0 libraqm0 libxsimd-dev
#   python-matplotlib-data python3-appdirs python3-attr python3-backcall
#   python3-beniget python3-brotli python3-bs4 python3-chardet python3-cycler
#   python3-dateutil python3-decorator python3-fonttools python3-fs python3-gast
#   python3-html5lib python3-ipython python3-jedi python3-kiwisolver
#   python3-lxml python3-lz4 python3-matplotlib python3-matplotlib-inline
#   python3-mpmath python3-numpy python3-olefile python3-packaging python3-parso
#   python3-pexpect python3-pickleshare python3-pil python3-pil.imagetk
#   python3-ply python3-prompt-toolkit python3-ptyprocess python3-pygments
#   python3-pythran python3-scipy python3-soupsieve python3-sympy
#   python3-traitlets python3-tz python3-ufolib2 python3-unicodedata2
#   python3-wcwidth python3-webencodings python3-wheel unicode-data
# Suggested packages:
#   libxsimd-doc python-attr-doc python-cycler-doc python3-genshi
#   python-ipython-doc python-lxml-doc dvipng fonts-staypuft ghostscript
#   gir1.2-gtk-3.0 inkscape librsvg2-common python-matplotlib-doc
#   python3-cairocffi python3-gi-cairo python3-gobject python3-pyqt5 python3-sip
#   python3-tornado texlive-extra-utils texlive-latex-extra python-mpmath-doc
#   python3-gmpy2 python-numpy-doc python3-pytest python-pexpect-doc
#   python-pil-doc python-ply-doc python-pygments-doc ttf-bitstream-vera
#   python-scipy-doc python-setuptools-doc texlive-fonts-extra python-sympy-doc
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-lyx ipython3 libimagequant0 liblbfgsb0 libraqm0
#   libxsimd-dev python-matplotlib-data python3-appdirs python3-attr
#   python3-backcall python3-beniget python3-brotli python3-bs4 python3-chardet
#   python3-cycler python3-dateutil python3-decorator python3-fonttools
#   python3-fs python3-gast python3-html5lib python3-ipython python3-jedi
#   python3-kiwisolver python3-lxml python3-lz4 python3-matplotlib
#   python3-matplotlib-inline python3-mpmath python3-numpy python3-olefile
#   python3-packaging python3-parso python3-pexpect python3-pickleshare
#   python3-pil python3-pil.imagetk python3-pip python3-ply
#   python3-prompt-toolkit python3-ptyprocess python3-pygments python3-pythran
#   python3-scipy python3-setuptools python3-soupsieve python3-sympy
#   python3-traitlets python3-tz python3-ufolib2 python3-unicodedata2
#   python3-wcwidth python3-webencodings python3-wheel unicode-data
# 0 upgraded, 56 newly installed, 0 to remove and 43 not upgraded.
# Need to get 49.8 MB of archives.
# After this operation, 226 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lyx all 2.3.6-1 [159 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-backcall all 0.2.0-2 [11.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-decorator all 4.4.2-0ubuntu1 [10.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-parso all 0.8.1-1 [64.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-jedi all 0.18.0-1 [615 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-traitlets all 5.1.1-1 [81.2 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-matplotlib-inline all 0.1.3-1 [8,070 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-ptyprocess all 0.7.0-3 [15.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pexpect all 4.8.0-2ubuntu1 [46.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-pickleshare all 0.7.5-5 [7,570 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-wcwidth all 0.2.5+dfsg1-1 [21.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-prompt-toolkit all 3.0.28-1 [251 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-pygments all 2.11.2+dfsg-2 [750 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-ipython all 7.31.1-1 [534 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ipython3 all 7.31.1-1 [5,238 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimagequant0 amd64 2.17.0-1 [34.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblbfgsb0 amd64 3.0+dfsg.3-10 [29.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraqm0 amd64 0.7.0-4ubuntu1 [11.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxsimd-dev amd64 7.6.0-2 [108 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python-matplotlib-data all 3.5.1-2build1 [2,942 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-appdirs all 1.4.4-2 [11.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-attr all 21.2.0-1 [44.0 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-gast all 0.5.2-2 [9,394 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-beniget all 0.4.1-2 [9,904 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-brotli amd64 1.0.9-2build6 [319 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-soupsieve all 2.3.1-1 [33.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-bs4 all 4.10.0-2 [79.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-chardet all 4.0.0-1 [98.0 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-cycler all 0.11.0-1 [8,156 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-dateutil all 2.8.1-6 [78.4 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-numpy amd64 1:1.21.5-1ubuntu22.04.1 [3,467 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-ply all 3.11-5 [47.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-pythran amd64 0.10.0+ds2-1 [423 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-scipy amd64 1.8.0-1exp2ubuntu1 [14.7 MB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-ufolib2 all 0.13.1+dfsg1-1 [32.2 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-mpmath all 1.2.1-2 [419 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-sympy all 1.9-1 [4,312 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-tz all 2022.1-1ubuntu0.22.04.1 [30.7 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-fs all 2.4.12-1 [84.9 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-lxml amd64 4.8.0-1build1 [1,150 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-lz4 amd64 3.1.3+dfsg-1build3 [33.3 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-unicodedata2 amd64 14.0.0+ds-8 [376 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 unicode-data all 14.0.0-1.1 [8,206 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-fonttools amd64 4.29.1-2build1 [810 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-webencodings all 0.5.1-4 [11.8 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-html5lib all 1.1-3 [87.0 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-kiwisolver amd64 1.3.2-1build1 [48.0 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-pil amd64 9.0.1-1ubuntu0.2 [419 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pil.imagetk amd64 9.0.1-1ubuntu0.2 [9,616 B]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-packaging all 21.3-1 [30.7 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 python3-matplotlib amd64 3.5.1-2build1 [5,937 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-olefile all 0.46-3 [33.8 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-setuptools all 59.6.0-1.2ubuntu0.22.04.1 [339 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-wheel all 0.37.1-2ubuntu0.22.04.1 [32.0 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 python3-pip all 22.0.2+dfsg-1ubuntu0.4 [1,305 kB]
# Fetched 49.8 MB in 11s (4,609 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 56.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-dejavu-core.
# (Reading database ... 121749 files and directories currently installed.)
# Preparing to unpack .../00-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../01-fonts-lyx_2.3.6-1_all.deb ...
# Unpacking fonts-lyx (2.3.6-1) ...
# Selecting previously unselected package python3-backcall.
# Preparing to unpack .../02-python3-backcall_0.2.0-2_all.deb ...
# Unpacking python3-backcall (0.2.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../03-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../04-python3-parso_0.8.1-1_all.deb ...
# Unpacking python3-parso (0.8.1-1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../05-python3-jedi_0.18.0-1_all.deb ...
# Unpacking python3-jedi (0.18.0-1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../06-python3-traitlets_5.1.1-1_all.deb ...
# Unpacking python3-traitlets (5.1.1-1) ...
# Selecting previously unselected package python3-matplotlib-inline.
# Preparing to unpack .../07-python3-matplotlib-inline_0.1.3-1_all.deb ...
# Unpacking python3-matplotlib-inline (0.1.3-1) ...
# Selecting previously unselected package python3-ptyprocess.
# Preparing to unpack .../08-python3-ptyprocess_0.7.0-3_all.deb ...
# Unpacking python3-ptyprocess (0.7.0-3) ...
# Selecting previously unselected package python3-pexpect.
# Preparing to unpack .../09-python3-pexpect_4.8.0-2ubuntu1_all.deb ...
# Unpacking python3-pexpect (4.8.0-2ubuntu1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../10-python3-pickleshare_0.7.5-5_all.deb ...
# Unpacking python3-pickleshare (0.7.5-5) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../11-python3-wcwidth_0.2.5+dfsg1-1_all.deb ...
# Unpacking python3-wcwidth (0.2.5+dfsg1-1) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../12-python3-prompt-toolkit_3.0.28-1_all.deb ...
# Unpacking python3-prompt-toolkit (3.0.28-1) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../13-python3-pygments_2.11.2+dfsg-2_all.deb ...
# Unpacking python3-pygments (2.11.2+dfsg-2) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../14-python3-ipython_7.31.1-1_all.deb ...
# Unpacking python3-ipython (7.31.1-1) ...
# Selecting previously unselected package ipython3.
# Preparing to unpack .../15-ipython3_7.31.1-1_all.deb ...
# Unpacking ipython3 (7.31.1-1) ...
# Selecting previously unselected package libimagequant0:amd64.
# Preparing to unpack .../16-libimagequant0_2.17.0-1_amd64.deb ...
# Unpacking libimagequant0:amd64 (2.17.0-1) ...
# Selecting previously unselected package liblbfgsb0:amd64.
# Preparing to unpack .../17-liblbfgsb0_3.0+dfsg.3-10_amd64.deb ...
# Unpacking liblbfgsb0:amd64 (3.0+dfsg.3-10) ...
# Selecting previously unselected package libraqm0:amd64.
# Preparing to unpack .../18-libraqm0_0.7.0-4ubuntu1_amd64.deb ...
# Unpacking libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Selecting previously unselected package libxsimd-dev:amd64.
# Preparing to unpack .../19-libxsimd-dev_7.6.0-2_amd64.deb ...
# Unpacking libxsimd-dev:amd64 (7.6.0-2) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../20-python-matplotlib-data_3.5.1-2build1_all.deb ...
# Unpacking python-matplotlib-data (3.5.1-2build1) ...
# Selecting previously unselected package python3-appdirs.
# Preparing to unpack .../21-python3-appdirs_1.4.4-2_all.deb ...
# Unpacking python3-appdirs (1.4.4-2) ...
# Selecting previously unselected package python3-attr.
# Preparing to unpack .../22-python3-attr_21.2.0-1_all.deb ...
# Unpacking python3-attr (21.2.0-1) ...
# Selecting previously unselected package python3-gast.
# Preparing to unpack .../23-python3-gast_0.5.2-2_all.deb ...
# Unpacking python3-gast (0.5.2-2) ...
# Selecting previously unselected package python3-beniget.
# Preparing to unpack .../24-python3-beniget_0.4.1-2_all.deb ...
# Unpacking python3-beniget (0.4.1-2) ...
# Selecting previously unselected package python3-brotli.
# Preparing to unpack .../25-python3-brotli_1.0.9-2build6_amd64.deb ...
# Unpacking python3-brotli (1.0.9-2build6) ...
# Selecting previously unselected package python3-soupsieve.
# Preparing to unpack .../26-python3-soupsieve_2.3.1-1_all.deb ...
# Unpacking python3-soupsieve (2.3.1-1) ...
# Selecting previously unselected package python3-bs4.
# Preparing to unpack .../27-python3-bs4_4.10.0-2_all.deb ...
# Unpacking python3-bs4 (4.10.0-2) ...
# Selecting previously unselected package python3-chardet.
# Preparing to unpack .../28-python3-chardet_4.0.0-1_all.deb ...
# Unpacking python3-chardet (4.0.0-1) ...
# Selecting previously unselected package python3-cycler.
# Preparing to unpack .../29-python3-cycler_0.11.0-1_all.deb ...
# Unpacking python3-cycler (0.11.0-1) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../30-python3-dateutil_2.8.1-6_all.deb ...
# Unpacking python3-dateutil (2.8.1-6) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../31-python3-numpy_1%3a1.21.5-1ubuntu22.04.1_amd64.deb ...
# Unpacking python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Selecting previously unselected package python3-ply.
# Preparing to unpack .../32-python3-ply_3.11-5_all.deb ...
# Unpacking python3-ply (3.11-5) ...
# Selecting previously unselected package python3-pythran.
# Preparing to unpack .../33-python3-pythran_0.10.0+ds2-1_amd64.deb ...
# Unpacking python3-pythran (0.10.0+ds2-1) ...
# Selecting previously unselected package python3-scipy.
# Preparing to unpack .../34-python3-scipy_1.8.0-1exp2ubuntu1_amd64.deb ...
# Unpacking python3-scipy (1.8.0-1exp2ubuntu1) ...
# Selecting previously unselected package python3-ufolib2.
# Preparing to unpack .../35-python3-ufolib2_0.13.1+dfsg1-1_all.deb ...
# Unpacking python3-ufolib2 (0.13.1+dfsg1-1) ...
# Selecting previously unselected package python3-mpmath.
# Preparing to unpack .../36-python3-mpmath_1.2.1-2_all.deb ...
# Unpacking python3-mpmath (1.2.1-2) ...
# Selecting previously unselected package python3-sympy.
# Preparing to unpack .../37-python3-sympy_1.9-1_all.deb ...
# Unpacking python3-sympy (1.9-1) ...
# Selecting previously unselected package python3-tz.
# Preparing to unpack .../38-python3-tz_2022.1-1ubuntu0.22.04.1_all.deb ...
# Unpacking python3-tz (2022.1-1ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-fs.
# Preparing to unpack .../39-python3-fs_2.4.12-1_all.deb ...
# Unpacking python3-fs (2.4.12-1) ...
# Selecting previously unselected package python3-lxml:amd64.
# Preparing to unpack .../40-python3-lxml_4.8.0-1build1_amd64.deb ...
# Unpacking python3-lxml:amd64 (4.8.0-1build1) ...
# Selecting previously unselected package python3-lz4.
# Preparing to unpack .../41-python3-lz4_3.1.3+dfsg-1build3_amd64.deb ...
# Unpacking python3-lz4 (3.1.3+dfsg-1build3) ...
# Selecting previously unselected package python3-unicodedata2.
# Preparing to unpack .../42-python3-unicodedata2_14.0.0+ds-8_amd64.deb ...
# Unpacking python3-unicodedata2 (14.0.0+ds-8) ...
# Selecting previously unselected package unicode-data.
# Preparing to unpack .../43-unicode-data_14.0.0-1.1_all.deb ...
# Unpacking unicode-data (14.0.0-1.1) ...
# Selecting previously unselected package python3-fonttools.
# Preparing to unpack .../44-python3-fonttools_4.29.1-2build1_amd64.deb ...
# Unpacking python3-fonttools (4.29.1-2build1) ...
# Selecting previously unselected package python3-webencodings.
# Preparing to unpack .../45-python3-webencodings_0.5.1-4_all.deb ...
# Unpacking python3-webencodings (0.5.1-4) ...
# Selecting previously unselected package python3-html5lib.
# Preparing to unpack .../46-python3-html5lib_1.1-3_all.deb ...
# Unpacking python3-html5lib (1.1-3) ...
# Selecting previously unselected package python3-kiwisolver.
# Preparing to unpack .../47-python3-kiwisolver_1.3.2-1build1_amd64.deb ...
# Unpacking python3-kiwisolver (1.3.2-1build1) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../48-python3-pil_9.0.1-1ubuntu0.2_amd64.deb ...
# Unpacking python3-pil:amd64 (9.0.1-1ubuntu0.2) ...
# Selecting previously unselected package python3-pil.imagetk:amd64.
# Preparing to unpack .../49-python3-pil.imagetk_9.0.1-1ubuntu0.2_amd64.deb ...
# Unpacking python3-pil.imagetk:amd64 (9.0.1-1ubuntu0.2) ...
# Selecting previously unselected package python3-packaging.
# Preparing to unpack .../50-python3-packaging_21.3-1_all.deb ...
# Unpacking python3-packaging (21.3-1) ...
# Selecting previously unselected package python3-matplotlib.
# Preparing to unpack .../51-python3-matplotlib_3.5.1-2build1_amd64.deb ...
# Unpacking python3-matplotlib (3.5.1-2build1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../52-python3-olefile_0.46-3_all.deb ...
# Unpacking python3-olefile (0.46-3) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../53-python3-setuptools_59.6.0-1.2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../54-python3-wheel_0.37.1-2ubuntu0.22.04.1_all.deb ...
# Unpacking python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../55-python3-pip_22.0.2+dfsg-1ubuntu0.4_all.deb ...
# Unpacking python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3-attr (21.2.0-1) ...
# Setting up python3-setuptools (59.6.0-1.2ubuntu0.22.04.1) ...
# Setting up python3-backcall (0.2.0-2) ...
# Setting up python3-parso (0.8.1-1) ...
# Setting up python3-lz4 (3.1.3+dfsg-1build3) ...
# Setting up python3-unicodedata2 (14.0.0+ds-8) ...
# Setting up fonts-lyx (2.3.6-1) ...
# Setting up python3-olefile (0.46-3) ...
# Setting up python3-ply (3.11-5) ...
# Setting up python3-gast (0.5.2-2) ...
# Setting up python3-wheel (0.37.1-2ubuntu0.22.04.1) ...
# Setting up python3-webencodings (0.5.1-4) ...
# Setting up python3-tz (2022.1-1ubuntu0.22.04.1) ...
# Setting up unicode-data (14.0.0-1.1) ...
# Setting up python3-beniget (0.4.1-2) ...
# Setting up libxsimd-dev:amd64 (7.6.0-2) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.11.2+dfsg-2) ...
# Setting up python3-packaging (21.3-1) ...
# Setting up python3-chardet (4.0.0-1) ...
# Setting up python3-wcwidth (0.2.5+dfsg1-1) ...
# Setting up python3-brotli (1.0.9-2build6) ...
# Setting up libraqm0:amd64 (0.7.0-4ubuntu1) ...
# Setting up python3-cycler (0.11.0-1) ...
# Setting up libimagequant0:amd64 (2.17.0-1) ...
# Setting up python3-kiwisolver (1.3.2-1build1) ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up python3-pip (22.0.2+dfsg-1ubuntu0.4) ...
# Setting up python3-html5lib (1.1-3) ...
# Setting up python3-numpy (1:1.21.5-1ubuntu22.04.1) ...
# Setting up python3-pickleshare (0.7.5-5) ...
# Setting up python3-pythran (0.10.0+ds2-1) ...
# Setting up python3-lxml:amd64 (4.8.0-1build1) ...
# Setting up python3-traitlets (5.1.1-1) ...
# Setting up python3-dateutil (2.8.1-6) ...
# Setting up python3-mpmath (1.2.1-2) ...
# Setting up python-matplotlib-data (3.5.1-2build1) ...
# Setting up python3-appdirs (1.4.4-2) ...
# Setting up python3-soupsieve (2.3.1-1) ...
# Setting up liblbfgsb0:amd64 (3.0+dfsg.3-10) ...
# Setting up python3-ptyprocess (0.7.0-3) ...
# Setting up python3-prompt-toolkit (3.0.28-1) ...
# Setting up python3-sympy (1.9-1) ...
# Setting up python3-scipy (1.8.0-1exp2ubuntu1) ...
# Setting up python3-jedi (0.18.0-1) ...
# Setting up python3-bs4 (4.10.0-2) ...
# Setting up python3-matplotlib-inline (0.1.3-1) ...
# Setting up python3-fs (2.4.12-1) ...
# Setting up python3-pexpect (4.8.0-2ubuntu1) ...
# Setting up python3-ipython (7.31.1-1) ...
# Setting up ipython3 (7.31.1-1) ...
# Setting up python3-pil:amd64 (9.0.1-1ubuntu0.2) ...
# Setting up python3-pil.imagetk:amd64 (9.0.1-1ubuntu0.2) ...
# Setting up python3-ufolib2 (0.13.1+dfsg1-1) ...
# Setting up python3-fonttools (4.29.1-2build1) ...
# Setting up python3-matplotlib (3.5.1-2build1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
# Install necessary libraries for ColabFold using pip.
# !pip install pyrosettacolabsetup py3dmol git+https://github.com/RosettaCommons/pyrosetta_viewer3d.git

# Setup PyRosetta environment specifically for Google Colab.
import pyrosettacolabsetup; pyrosettacolabsetup.install_pyrosetta()
# Out:
# Collecting git+https://github.com/RosettaCommons/pyrosetta_viewer3d.git
#   Cloning https://github.com/RosettaCommons/pyrosetta_viewer3d.git to /tmp/pip-req-build-sy5ub_xv
#   Running command git clone --filter=blob:none --quiet https://github.com/RosettaCommons/pyrosetta_viewer3d.git /tmp/pip-req-build-sy5ub_xv
#   Resolved https://github.com/RosettaCommons/pyrosetta_viewer3d.git to commit f467481e8c8cd567fbc2620173e008814b731d72
#   Preparing metadata (setup.py) ... done
# Collecting pyrosettacolabsetup
#   Downloading pyrosettacolabsetup-1.0.7-py3-none-any.whl (4.8 kB)
# Collecting py3dmol
#   Downloading py3Dmol-2.0.4-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (23.2.0)
# Requirement already satisfied: bokeh>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (3.3.4)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (7.7.1)
# Collecting jupyter>=1.0.0 (from viewer3d==1.0.0)
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.10/dist-packages (from viewer3d==1.0.0) (3.7.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (3.1.3)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (1.25.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (23.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (1.5.3)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from bokeh>=2.4.2->viewer3d==1.0.0) (2023.10.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.5.1->viewer3d==1.0.0) (3.0.10)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->viewer3d==1.0.0) (6.5.5)
# Collecting qtconsole (from jupyter>=1.0.0->viewer3d==1.0.0)
#   Downloading qtconsole-5.5.1-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->viewer3d==1.0.0) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter>=1.0.0->viewer3d==1.0.0) (6.5.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5->viewer3d==1.0.0) (2.8.2)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->viewer3d==1.0.0) (6.1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=2.4.2->viewer3d==1.0.0) (2.1.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->bokeh>=2.4.2->viewer3d==1.0.0) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->viewer3d==1.0.0) (1.16.0)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (5.7.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (5.9.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.18.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.0.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.9.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (1.2.1)
# Collecting qtpy>=2.4.0 (from qtconsole->jupyter>=1.0.0->viewer3d==1.0.0)
#   Downloading QtPy-2.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (4.2.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.2.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (4.19.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.1->viewer3d==1.0.0) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter>=1.0.0->viewer3d==1.0.0) (0.5.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (0.17.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter>=1.0.0->viewer3d==1.0.0) (2.21)
# Building wheels for collected packages: viewer3d
#   Building wheel for viewer3d (setup.py) ... done
#   Created wheel for viewer3d: filename=viewer3d-1.0.0-py3-none-any.whl size=34766 sha256=f748f745664168ee1b96b252d1f18a18e1c3bb586c8c6513f014e4a6a5b0947e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u3lvku0p/wheels/b2/1d/4e/ab6446ec63fbf5af3d53b06df7a766ee7bd238e8544636c222
# Successfully built viewer3d
# Installing collected packages: pyrosettacolabsetup, py3dmol, qtpy, qtconsole, jupyter, viewer3d
# Successfully installed jupyter-1.0.0 py3dmol-2.0.4 pyrosettacolabsetup-1.0.7 qtconsole-5.5.1 qtpy-2.4.1 viewer3d-1.0.0
# Mounted at /content/google_drive
# Looking for compatible PyRosetta wheel file at google-drive/PyRosetta/colab.bin//wheels...
# Found compatible wheel: /content/google_drive/MyDrive/PyRosetta/colab.bin/wheels//content/google_drive/MyDrive/PyRosetta/colab.bin/wheels/pyrosetta-2024.1+release.00b79147e63-cp310-cp310-linux_x86_64.whl

# %%
import pyrosetta; # import the pyrosetta package to access functionality
import pyrosetta.distributed.io as io
pyrosetta.init() # must be called before any other pyrosetta functions. Can accept command line flags
# Out:
# PyRosetta-4 2023 [Rosetta PyRosetta4.MinSizeRel.python310.ubuntu 2024.01+release.00b79147e63be743438188f93a3f069ca75106d6 2023-12-25T16:35:48] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.MinSizeRel.python310.ubuntu r366 2024.01+release.00b79147e63 00b79147e63be743438188f93a3f069ca75106d6 http://www.pyrosetta.org 2023-12-25T16:35:48
# core.init: command: PyRosetta -ex1 -ex2aro -database /usr/local/lib/python3.10/dist-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-340773806 seed_offset=0 real_seed=-340773806
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-340773806 RG_type=mt19937

# %%
# Install the Fragmenstein library for molecular merging operations.
# !python -m pip install fragmenstein
# Out:
# Collecting fragmenstein
#   Downloading Fragmenstein-0.14.7.tar.gz (625 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.0/626.0 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.27.1 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (2.31.0)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (1.25.2)
# Requirement already satisfied: scipy>=1.7.3 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (1.11.4)
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (1.5.3)
# Collecting pebble>=4.6.3 (from fragmenstein)
#   Downloading Pebble-5.0.6-py3-none-any.whl (30 kB)
# Collecting rdkit>=2022.3.2.1 (from fragmenstein)
#   Downloading rdkit-2023.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 8.9 MB/s eta 0:00:00
# Collecting rdkit-to-params>=1.2.3 (from fragmenstein)
#   Downloading rdkit_to_params-1.2.8.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting molecular-rectifier>=0.1.10 (from fragmenstein)
#   Downloading molecular_rectifier-0.1.10.2.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Collecting singledispatchmethod>=1.0 (from fragmenstein)
#   Downloading singledispatchmethod-1.0-py2.py3-none-any.whl (4.7 kB)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (4.9.0)
# Requirement already satisfied: matplotlib>=3.5.2 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (3.7.1)
# Collecting smallworld-api>=1.1 (from fragmenstein)
#   Downloading smallworld-api-1.1.4.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sqlitedict>=2.0.0 (from fragmenstein)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pandera>=0.17.2 (from fragmenstein)
#   Downloading pandera-0.18.0-py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 16.8 MB/s eta 0:00:00
# Collecting pandarallel>=1.6.5 (from fragmenstein)
#   Downloading pandarallel-1.6.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.10/dist-packages (from fragmenstein) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.2->fragmenstein) (2.8.2)
# Collecting dill>=0.3.1 (from pandarallel>=1.6.5->fragmenstein)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from pandarallel>=1.6.5->fragmenstein) (5.9.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->fragmenstein) (2023.4)
# Collecting multimethod (from pandera>=0.17.2->fragmenstein)
#   Downloading multimethod-1.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from pandera>=0.17.2->fragmenstein) (2.6.1)
# Collecting typeguard>=3.0.2 (from pandera>=0.17.2->fragmenstein)
#   Downloading typeguard-4.1.5-py3-none-any.whl (34 kB)
# Collecting typing-inspect>=0.6.0 (from pandera>=0.17.2->fragmenstein)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from pandera>=0.17.2->fragmenstein) (1.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.1->fragmenstein) (2024.2.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from smallworld-api>=1.1->fragmenstein) (7.34.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.2->fragmenstein) (1.16.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.6.0->pandera>=0.17.2->fragmenstein)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.18.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->smallworld-api>=1.1->fragmenstein) (4.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera>=0.17.2->fragmenstein) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera>=0.17.2->fragmenstein) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->smallworld-api>=1.1->fragmenstein) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->smallworld-api>=1.1->fragmenstein) (0.2.13)
# Building wheels for collected packages: fragmenstein, molecular-rectifier, pandarallel, rdkit-to-params, smallworld-api, sqlitedict
#   Building wheel for fragmenstein (setup.py) ... done
#   Created wheel for fragmenstein: filename=Fragmenstein-0.14.7-py3-none-any.whl size=826970 sha256=9af00f218ea0a3614f30049405bb1d7f62e7b49be6bf2ae567c71cd608a77209
#   Stored in directory: /root/.cache/pip/wheels/91/0d/35/9b08d0c6889f9217681f844bc3e432c1f8e40d974d7c78297c
#   Building wheel for molecular-rectifier (setup.py) ... done
#   Created wheel for molecular-rectifier: filename=molecular_rectifier-0.1.10.2-py3-none-any.whl size=18943 sha256=9b902c6fb16ef2f27e05962c91337d56d60ef5cc244d79110463666f598519d7
#   Stored in directory: /root/.cache/pip/wheels/18/fa/51/8e66e548653a353dc8dbdbb3cebf9148be632f26a622bafae1
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.5-py3-none-any.whl size=16672 sha256=68735385ea6f1bbfbcfb5e41dd9ca7493cfa0ed3b8b4598dc734321702ed3ba0
#   Stored in directory: /root/.cache/pip/wheels/50/4f/1e/34e057bb868842209f1623f195b74fd7eda229308a7352d47f
#   Building wheel for rdkit-to-params (setup.py) ... done
#   Created wheel for rdkit-to-params: filename=rdkit_to_params-1.2.8-py3-none-any.whl size=49683 sha256=1096c81508a79535d986404e1ee1d2f9d596ed5f75b659840361f9d7a1d98e4b
#   Stored in directory: /root/.cache/pip/wheels/cc/7e/41/a6e2a1fc1d8b7c647dc335278d92e01062927ba57995b16bdc
#   Building wheel for smallworld-api (setup.py) ... done
#   Created wheel for smallworld-api: filename=smallworld_api-1.1.4-py3-none-any.whl size=16005 sha256=b46248288ba65b065163f3332c44f9d62feedf36f0e2aadb4dcd1b7b58b6ea96
#   Stored in directory: /root/.cache/pip/wheels/f5/bb/70/973633116417bca247c85f26191ee0678ed6c69840319b3bf2
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=5a60f56ccdb0fcc07957e763339177bcdaf800caf8c62a4707a1e788242d2984
#   Stored in directory: /root/.cache/pip/wheels/79/d6/e7/304e0e6cb2221022c26d8161f7c23cd4f259a9e41e8bbcfabd
# Successfully built fragmenstein molecular-rectifier pandarallel rdkit-to-params smallworld-api sqlitedict
# Installing collected packages: sqlitedict, singledispatchmethod, typeguard, rdkit-to-params, rdkit, pebble, mypy-extensions, multimethod, dill, typing-inspect, molecular-rectifier, smallworld-api, pandera, pandarallel, fragmenstein
# Successfully installed dill-0.3.8 fragmenstein-0.14.7 molecular-rectifier-0.1.10.2 multimethod-1.11 mypy-extensions-1.0.0 pandarallel-1.6.5 pandera-0.18.0 pebble-5.0.6 rdkit-2023.9.5 rdkit-to-params-1.2.8 singledispatchmethod-1.0 smallworld-api-1.1.4 sqlitedict-2.1.0 typeguard-4.1.5 typing-inspect-0.9.0

# %%
# Import classes for molecular operations from Fragmenstein.
from fragmenstein import Victor, Igor, Monster

# %%
# Increase the recursion limit to allow deeper recursive function executions.
import sys
sys.setrecursionlimit(250000)

# %%
# Original recursive function
def factorial(n):
    if n < 2:
        return 1
    return n * factorial(n - 1)

# Step 1: Convert recursive calls into tail calls
def factorial1a(n, acc=1):
    if n < 2:
        return 1 * acc
    return factorial1a(n - 1, acc * n)

# Step 2: Introduce a one-shot loop around the function body
def factorial1b(n, acc=1):
    while True:
        if n < 2:
            return 1 * acc
        return factorial1b(n - 1, acc * n)
        break

# Step 3: Convert tail calls into continue statements
def factorial1c(n, acc=1):
    while True:
        if n < 2:
            return 1 * acc
        (n, acc) = (n - 1, acc * n)
        continue
        break

# Step 4: Tidy the code and make it more idiomatic
def factorial1d(n, acc=1):
    while n > 1:
        (n, acc) = (n - 1, acc * n)
    return acc

# Testing the iterative version
print(factorial1d(5))  # Output: 120
# Out:
# 120

# %%
# Import necessary libraries for molecule manipulation.
import csv
import logging
from fragmenstein import Victor
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from rdkit.Chem.Draw import MolsToGridImage

# Initialize PyRosetta
pyrosetta.init(extra_options='-no_optH false -mute all -ignore_unrecognized_res false -load_PDB_components false')

# Setup logging
logging.basicConfig(filename='victor_log.log', level=logging.INFO)
Victor.enable_logfile('victor_log.log', logging.INFO)


# Initialize list to store minimized SMILES and molecule data
minimized_smiles_list = []
molecule_data = []

# Initialize list to store 2D structures
mol_2d_structures = []

# Load the protein PDB file
protein_pdb_path = 'chain_A.pdb'

# Process reference molecule
reference_smile = 'CNc1ncc2cc(-c3ccc(-c4ncccc4F)cc3Cl)c(=O)n(C[C@H]3OC[C@H](N)CO3)c2n1'
reference_mol = Chem.AddHs(AllChem.MolFromSmiles(reference_smile))
AllChem.EmbedMolecule(reference_mol, AllChem.ETKDG())

# Define two SMILES strings
smiles1 = 'O=C(Cn1c(N2CCOCC2)nc2nc(N3CCOCC3)ncc2c1=O)Nc1ccc(Cl)cn1'  # Replace with your first SMILES string
smiles2 = 'Cc1ccc(NC(=O)Cn2c(=O)n(Cc3ccc(Br)cc3)c(=O)c3c2ncn3C(C)C)cc1'  # Replace with your second SMILES string
smiles_list = [smiles1, smiles2]

# Process each SMILES string using Victor
for i, smile in enumerate(smiles_list):
    mol = Chem.AddHs(AllChem.MolFromSmiles(smile))
    AllChem.EmbedMolecule(mol, AllChem.ETKDG())
    victor = Victor(hits=[mol], pdb_filename=protein_pdb_path)
    try:
        victor.combine()
    except Chem.AtomValenceException:
        logging.info(f'Atom valence exception occurred for molecule {i+1}, trying to rectify...')
        victor.rectify(collapse_rings=True, joining_cutoff=3.0)
        victor.combine()

    minimized_molecule = victor.minimized_mol
    mol_2d_structures.append(minimized_molecule)
    minimized_smiles = Chem.MolToSmiles(minimized_molecule)
    minimized_smiles_list.append(minimized_smiles)

    # Calculate Lipinski's descriptors
    mw = Descriptors.ExactMolWt(minimized_molecule)
    logp = Descriptors.MolLogP(minimized_molecule)
    hba = Descriptors.NumHAcceptors(minimized_molecule)
    hbd = Descriptors.NumHDonors(minimized_molecule)

    # Save and display molecule data
    output_file = f'minimized_merged_molecule_{i}.mol'
    AllChem.MolToMolFile(minimized_molecule, output_file)
    molecule_data.append([minimized_smiles, mw, logp, hba, hbd, output_file])
# Out:
# PyRosetta-4 2023 [Rosetta PyRosetta4.MinSizeRel.python310.ubuntu 2024.01+release.00b79147e63be743438188f93a3f069ca75106d6 2023-12-25T16:35:48] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# DEBUG:Fragmenstein:hit0 - harmonising warheads on hits in "first" mode
# DEBUG:Fragmenstein:Merging: ['hit0']
# DEBUG:Fragmenstein:Merged
# DEBUG:Fragmenstein:Starting ring expansion
# DEBUG:Fragmenstein:42 (formerly 123 existed already: fused ring or similar.
# DEBUG:Fragmenstein:41 (formerly 112 existed already: fused ring or similar.
# DEBUG:Fragmenstein:Restoring original bonding if any.
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d380d60>, 'ori_name': 'hit0', 'elements': ['C', 'C', 'O', 'C', 'C', 'N'], 'neighbors': [[105, 107, 136, 137], [106, 108, 138, 139], [107, 109], [108, 110, 140, 141], [109, 105, 142, 143], [104, 106, 110]], 'ori_is': [106, 107, 108, 109, 110, 105], 'xs': [1.0663838688205423, 2.315748961368142, 2.373564967739463, 1.8122058521146025, 1.9095127112638333, 1.0068703297392945], 'ys': [-3.5038129919401437, -4.131978614991001, -4.162312479981898, -3.039602566887776, -1.8222520056961218, -2.1242773197084235], 'zs': [-0.007578083007144443, -0.5332217904378158, -1.9118072158685813, -2.516203187885262, -1.5995837269846918, -0.47733768285556527], 'bonds': [['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE']], 'current_is': [34, 35, 36, 37, 38, 39]}
# DEBUG:Fragmenstein:ring bond #0 between 34 39(<=106,105)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 34 35(<=106,107)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 34 8(<=106,136)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 34 9(<=106,137)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 35 34(<=107,106)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #1 between 35 36(<=107,108)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 35 10(<=107,138)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 35 11(<=107,139)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 36 35(<=108,107)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #2 between 36 37(<=108,109)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 37 36(<=109,108)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #3 between 37 38(<=109,110)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 37 12(<=109,140)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 37 13(<=109,141)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 38 37(<=110,109)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #4 between 38 39(<=110,105)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 38 14(<=110,142)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 38 15(<=110,143)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 39 45(<=105,104)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 39 34(<=105,106)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 39 38(<=105,110)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d380c80>, 'ori_name': 'hit0', 'elements': ['N', 'C', 'C', 'C', 'N', 'C'], 'neighbors': [[104, 112], [111, 113, 123], [122, 124, 112], [123, 125, 103], [102, 104, 124], [103, 105, 111]], 'ori_is': [111, 112, 123, 124, 103, 104], 'xs': [-1.1042534161901159, -1.924925617785912, -1.4391586305869246, -0.1558602774975772, 0.5927044375688043, 0.15003030488983737], 'ys': [-0.9368697429535173, 0.002268893388133331, 0.7591049917240985, 0.5420207499288853, -0.3964605607568882, -1.1490976704667006], 'zs': [-0.33278910139926915, 0.224338115348927, 1.2679331098892646, 1.7059520229466698, 1.1120880865976057, 0.09534389921860947], 'bonds': [['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'DOUBLE', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'SINGLE', 'AROMATIC']], 'current_is': [40, 41, 42, 43, 44, 45]}
# DEBUG:Fragmenstein:ring bond #0 between 40 45(<=111,104)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 40 41(<=111,112)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 41
 'bonds': [['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC'], ['SINGLE', 'AROMATIC', 'AROMATIC']], 'current_is': [56, 57, 58, 59, 60, 61]}
# DEBUG:Fragmenstein:ring bond #0 between 56 61(<=128,127)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 56 57(<=128,129)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 56 26(<=128,154)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 57 56(<=129,128)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 57 58(<=129,130)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 57 27(<=129,155)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 58 57(<=130,129)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 58 5(<=130,131)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 58 59(<=130,132)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 59 58(<=132,130)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 59 60(<=132,133)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 59 28(<=132,156)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 60 59(<=133,132)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 60 61(<=133,127)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 61 4(<=127,126)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 61 56(<=127,128)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 61 60(<=127,133)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Adding novel bonding (if any)...
# DEBUG:Fragmenstein:_get_novel_other_pairs - close_pairs @ 1.0: []
# DEBUG:Fragmenstein:_get_novel_other_pairs - bonded_pairs @ 1.0: []
# DEBUG:Fragmenstein:`_emergency_joining` called
# DEBUG:Fragmenstein:Expanded
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 42), ('AROMATIC', 17), ('DOUBLE', 2)]; Atoms: [('H', 23), ('C', 21), ('N', 8), ('O', 4), ('Cl', 1)]
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 42), ('AROMATIC', 17), ('DOUBLE', 2)]; Atoms: [('H', 23), ('C', 21), ('N', 8), ('O', 4), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:This molecule (hit0) has a fused ring
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 42), ('AROMATIC', 17), ('DOUBLE', 2)]; Atoms: [('H', 23), ('C', 21), ('N', 8), ('O', 4), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ ring fixes done ------------
# DEBUG:Fragmenstein:Storing molecule #2 in `.modifications`
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 42), ('AROMATIC', 17), ('DOUBLE', 2)]; Atoms: [('H', 23), ('C', 21), ('N', 8), ('O', 4), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ oddity fixes done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 42), ('AROMATIC', 17), ('DOUBLE', 2)]; Atoms: [('H', 23), ('C', 21), ('N', 8), ('O', 4), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ hydrogens done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 42), ('AROMATIC', 17), ('DOUBLE', 2)]; Atoms: [('H', 23), ('C', 21), ('N', 8), ('O', 4), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ valence drama done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 42), ('AROMATIC', 17), ('DOUBLE', 2)]; Atoms: [('H', 23), ('C', 21), ('N', 8), ('O', 4), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ check against radicals done ------------
# DEBUG:Fragmenstein:Rectified
# WARNING:Fragmenstein:hit0 - Folder output/hit0 exists.
# DEBUG:Fragmenstein:hit0 - Starting parameterisation
# DEBUG:Fragmenstein:`from_mol` called...
# DEBUG:Fragmenstein:`load_mol` called...
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:... Adding Gasteiger
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing O at position 0
# DEBUG:Fragmenstein:Parsing C at position 1
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing N at position 4
# DEBUG:Fragmenstein:Parsing N at position 39
# DEBUG:Fragmenstein:Parsing C at position 56
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing N at position 55
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing N at position 34
# DEBUG:Fragmenstein:Parsing N at position 35
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 54
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 44
# DEBUG:Fragmenstein:Parsing C at position 53
# DEBUG:Fragmenstein:Parsing Cl at position 5
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing N at position 41
# DEBUG:Fragmenstein:Parsing N at position 43
# DEBUG:Fragmenstein:Parsing O at position 31
# DEBUG:Fragmenstein:Parsing C at position 42
# DEBUG:Fragmenstein:Parsing N at position 50
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing C at position 49
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing O at position 47
# DEBUG:Fragmenstein:Parsing H at position 6
# DEBUG:Fragmenstein:Parsing H at position 7
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 8
# DEBUG:Fragmenstein:Parsing H at position 9
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Parsing H at position 10
# DEBUG:Fragmenstein:Parsing H at position 11
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing O at position 0
# DEBUG:Fragmenstein:Parsing C at position 1
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing N at position 4
# DEBUG:Fragmenstein:Parsing N at position 39
# DEBUG:Fragmenstein:Parsing C at position 56
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing N at position 55
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing N at position 34
# DEBUG:Fragmenstein:Parsing N at position 35
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 54
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 44
# DEBUG:Fragmenstein:Parsing C at position 53
# DEBUG:Fragmenstein:Parsing Cl at position 5
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing N at position 41
# DEBUG:Fragmenstein:Parsing N at position 43
# DEBUG:Fragmenstein:Parsing O at position 31
# DEBUG:Fragmenstein:Parsing C at position 42
# DEBUG:Fragmenstein:Parsing N at position 50
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing C at position 49
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing O at position 47
# DEBUG:Fragmenstein:Parsing H at position 6
# DEBUG:Fragmenstein:Parsing H at position 7
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 8
# DEBUG:Fragmenstein:Parsing H at position 9
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Parsing H at position 10
# DEBUG:Fragmenstein:Parsing H at position 11
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0 - placing monster in structure
# DEBUG:Fragmenstein:hit0 - saving params
# DEBUG:Fragmenstein:hit0 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0 - saving mols from monster
# DEBUG:Fragmenstein:hit0 - Igor minimising
# DEBUG:Fragmenstein:hit0 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0 - calculating mRMSD
# INFO:Fragmenstein:hit0 - final score: -0.3764399056256438 kcal/mol, RMSD: 0.21783737648219914.
# DEBUG:Fragmenstein:hit0 - saving pose from igor
# DEBUG:Fragmenstein:hit0 - calculating Gibbs
# DEBUG:Fragmenstein:hit0 - Completed
# DEBUG:Fragmenstein:hit0 - Completed
# INFO:Fragmenstein:hit0 - Time taken: 29.15505051612854
# DEBUG:Fragmenstein:hit0 - harmonising warheads on hits in "first" mode
# DEBUG:Fragmenstein:Merging: ['hit0']
# DEBUG:Fragmenstein:Merged
# DEBUG:Fragmenstein:Starting ring expansion
# DEBUG:Fragmenstein
114)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 52 53(<=115,116)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 52 22(<=115,143)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 53 52(<=116,115)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 53 54(<=116,117)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 53 23(<=116,144)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 54 53(<=117,116)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 54 7(<=117,118)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 54 55(<=117,119)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 55 54(<=119,117)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 55 56(<=119,120)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 55 24(<=119,145)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 56 55(<=120,119)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 56 57(<=120,114)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #4 between 56 25(<=120,146)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 57 6(<=114,113)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 57 52(<=114,115)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 57 56(<=114,120)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d2bc580>, 'ori_name': 'hit0', 'elements': ['N', 'C', 'C', 'N', 'C'], 'neighbors': [[124, 126], [123, 125, 109], [121, 124, 127], [126, 128, 123], [125, 127, 147]], 'ori_is': [125, 124, 123, 127, 126], 'xs': [0.13450099738555132, -0.49201407709984013, -1.6543361741358298, -1.729992931236414, -0.6269813010520091], 'ys': [3.1016446006089997, 1.923278629624685, 1.9823964644453884, 3.1835154227148093, 3.852236064351346], 'zs': [1.4521987737240265, 1.6140035653116105, 0.8746544406582608, 0.27219936016360874, 0.6382375342495846], 'bonds': [['AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'SINGLE', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE']], 'current_is': [58, 59, 60]}
# DEBUG:Fragmenstein:ring bond #0 between 58 50(<=125,124)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #0 between 58 60(<=125,126)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 50 49(<=124,123)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 50 58(<=124,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 50 51(<=124,109)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 49 48(<=123,121)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 49 50(<=123,124)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 49 59(<=123,127)  exists already (has AROMATIC as expected AROMATIC)
# WARNING:Fragmenstein:(Ring expansion) One atom 3 lacks a current index! This is a fallback that should not happen  (list index out of range)
# DEBUG:Fragmenstein:ring bond #3 between 59 60(<=127,126)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 59 9(<=127,128)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 59 49(<=127,123)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 60 58(<=126,125)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 60 59(<=126,127)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 60 26(<=126,147)  added as SINGLE
# DEBUG:Fragmenstein:Adding novel bonding (if any)...
# DEBUG:Fragmenstein:_get_novel_other_pairs - close_pairs @ 1.0: []
# DEBUG:Fragmenstein:_get_novel_other_pairs - bonded_pairs @ 1.0: []
# DEBUG:Fragmenstein:`_emergency_joining` called
# DEBUG:Fragmenstein:Expanded
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 35), ('AROMATIC', 22), ('DOUBLE', 3)]; Atoms: [('C', 24), ('H', 24), ('N', 5), ('O', 3), ('Br', 1)]
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 35), ('AROMATIC', 22), ('DOUBLE', 3)]; Atoms: [('C', 24), ('H', 24), ('N', 5), ('O', 3), ('Br', 1)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:This molecule (hit0) has a fused ring
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 35), ('AROMATIC', 22), ('DOUBLE', 3)]; Atoms: [('C', 24), ('H', 24), ('N', 5), ('O', 3), ('Br', 1)]
# DEBUG:Fragmenstein:------------ ring fixes done ------------
# DEBUG:Fragmenstein:Storing molecule #2 in `.modifications`
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 35), ('AROMATIC', 22), ('DOUBLE', 3)]; Atoms: [('C', 24), ('H', 24), ('N', 5), ('O', 3), ('Br', 1)]
# DEBUG:Fragmenstein:------------ oddity fixes done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 35), ('AROMATIC', 22), ('DOUBLE', 3)]; Atoms: [('C', 24), ('H', 24), ('N', 5), ('O', 3), ('Br', 1)]
# DEBUG:Fragmenstein:------------ hydrogens done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 35), ('AROMATIC', 22), ('DOUBLE', 3)]; Atoms: [('C', 24), ('H', 24), ('N', 5), ('O', 3), ('Br', 1)]
# DEBUG:Fragmenstein:------------ valence drama done ------------
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 35), ('AROMATIC', 22), ('DOUBLE', 3)]; Atoms: [('C', 24), ('H', 24), ('N', 5), ('O', 3), ('Br', 1)]
# DEBUG:Fragmenstein:------------ check against radicals done ------------
# DEBUG:Fragmenstein:Rectified
# WARNING:Fragmenstein:hit0 - Folder output/hit0 exists.
# DEBUG:Fragmenstein:hit0 - Starting parameterisation
# DEBUG:Fragmenstein:`from_mol` called...
# DEBUG:Fragmenstein:`load_mol` called...
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:... Adding Gasteiger
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing C at position 0
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 41
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing C at position 39
# DEBUG:Fragmenstein:Parsing N at position 1
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing C at position 4
# DEBUG:Fragmenstein:Parsing N at position 47
# DEBUG:Fragmenstein:Parsing C at position 42
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing N at position 43
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing N at position 54
# DEBUG:Fragmenstein:Parsing C at position 6
# DEBUG:Fragmenstein:Parsing C at position 44
# DEBUG:Fragmenstein:Parsing N at position 55
# DEBUG:Fragmenstein:Parsing C at position 56
# DEBUG:Fragmenstein:Parsing O at position 8
# DEBUG:Fragmenstein:Parsing C at position 9
# DEBUG:Fragmenstein:Parsing C at position 53
# DEBUG:Fragmenstein:Parsing C at position 10
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 49
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing C at position 50
# DEBUG:Fragmenstein:Parsing Br at position 7
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 35
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 34
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 29
# DEBUG:Fragmenstein:Parsing H at position 30
# DEBUG:Fragmenstein:Parsing H at position 31
# DEBUG:Fragmenstein:Parsing H at position 32
# DEBUG:Fragmenstein:Parsing H at position 33
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing C at position 0
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 41
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing C at position 39
# DEBUG:Fragmenstein:Parsing N at position 1
# DEBUG:Fragmenstein:Parsing C at position 2
# DEBUG:Fragmenstein:Parsing O at position 3
# DEBUG:Fragmenstein:Parsing C at position 4
# DEBUG:Fragmenstein:Parsing N at position 47
# DEBUG:Fragmenstein:Parsing C at position 42
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing N at position 43
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing N at position 54
# DEBUG:Fragmenstein:Parsing C at position 6
# DEBUG:Fragmenstein:Parsing C at position 44
# DEBUG:Fragmenstein:Parsing N at position 55
# DEBUG:Fragmenstein:Parsing C at position 56
# DEBUG:Fragmenstein:Parsing O at position 8
# DEBUG:Fragmenstein:Parsing C at position 9
# DEBUG:Fragmenstein:Parsing C at position 53
# DEBUG:Fragmenstein:Parsing C at position 10
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing C at position 48
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 49
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing C at position 50
# DEBUG:Fragmenstein:Parsing Br at position 7
# DEBUG:Fragmenstein:Parsing H at position 12
# DEBUG:Fragmenstein:Parsing H at position 13
# DEBUG:Fragmenstein:Parsing H at position 14
# DEBUG:Fragmenstein:Parsing H at position 15
# DEBUG:Fragmenstein:Parsing H at position 35
# DEBUG:Fragmenstein:Parsing H at position 16
# DEBUG:Fragmenstein:Parsing H at position 34
# DEBUG:Fragmenstein:Parsing H at position 17
# DEBUG:Fragmenstein:Parsing H at position 18
# DEBUG:Fragmenstein:Parsing H at position 19
# DEBUG:Fragmenstein:Parsing H at position 20
# DEBUG:Fragmenstein:Parsing H at position 21
# DEBUG:Fragmenstein:Parsing H at position 26
# DEBUG:Fragmenstein:Parsing H at position 27
# DEBUG:Fragmenstein:Parsing H at position 22
# DEBUG:Fragmenstein:Parsing H at position 25
# DEBUG:Fragmenstein:Parsing H at position 28
# DEBUG:Fragmenstein:Parsing H at position 29
# DEBUG:Fragmenstein:Parsing H at position 30
# DEBUG:Fragmenstein:Parsing H at position 31
# DEBUG:Fragmenstein:Parsing H at position 32
# DEBUG:Fragmenstein:Parsing H at position 33
# DEBUG:Fragmenstein:Parsing H at position 23
# DEBUG:Fragmenstein:Parsing H at position 24
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0 - placing monster in structure
# DEBUG:Fragmenstein:hit0 - saving params
# DEBUG:Fragmenstein:hit0 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0 - saving mols from monster
# DEBUG:Fragmenstein:hit0 - Igor minimising
# DEBUG:Fragmenstein:hit0 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0 - calculating mRMSD
# INFO:Fragmenstein:hit0 - final score: -0.528936341801042 kcal/mol, RMSD: 0.12245489955472545.
# DEBUG:Fragmenstein:hit0 - saving pose from igor
# DEBUG:Fragmenstein:hit0 - calculating Gibbs
# DEBUG:Fragmenstein:hit0 - Completed
# DEBUG:Fragmenstein:hit0 - Completed
# INFO:Fragmenstein:hit0 - Time taken: 26.120939254760742

# %%
# Combined processing of both SMILES strings
logging.info("Combining both SMILES for joint processing.")

mol1 = Chem.AddHs(AllChem.MolFromSmiles(smiles1))
AllChem.EmbedMolecule(mol1, AllChem.ETKDG())

mol2 = Chem.AddHs(AllChem.MolFromSmiles(smiles2))
AllChem.EmbedMolecule(mol2, AllChem.ETKDG())

combined_victor = Victor(hits=[mol1, mol2], pdb_filename=protein_pdb_path)
try:
    combined_victor.combine()
except Chem.AtomValenceException:
    logging.info("Atom valence exception occurred during combined processing, trying to rectify...")
    combined_victor.rectify(collapse_rings=True, joining_cutoff=3.0)
    combined_victor.combine()

combined_molecule = combined_victor.minimized_mol
mol_2d_structures.append(combined_molecule)
combined_smiles = Chem.MolToSmiles(combined_molecule)
minimized_smiles_list.append(combined_smiles)
combined_mw = Descriptors.ExactMolWt(combined_molecule)
combined_logp = Descriptors.MolLogP(combined_molecule)
combined_hba = Descriptors.NumHAcceptors(combined_molecule)
combined_hbd = Descriptors.NumHDonors(combined_molecule)

# Visualize and save 2D structure of each resulting molecule
all_molecules = [Chem.AddHs(AllChem.MolFromSmiles(smiles1)), Chem.AddHs(AllChem.MolFromSmiles(smiles2)), combined_molecule]
display(MolsToGridImage(all_molecules, molsPerRow=3, subImgSize=(300, 300)))

# Append combined molecule data
molecule_data.append([combined_smiles, combined_mw, combined_logp, combined_hba, combined_hbd, 'combined_optimized_molecule.mol'])
# Out:
# DEBUG:Fragmenstein:hit0-hit1 - harmonising warheads on hits in "first" mode
# DEBUG:Fragmenstein:Merging: ['hit
# DEBUG:Fragmenstein:_get_novel_other_pairs - bonded_pairs @ 1.0: [(30, 74), (30, 77), (30, 78), (30, 85), (68, 26), (84, 18)]
# DEBUG:Fragmenstein:determining novel bond between ring marker 31 and non-ring 40
# DEBUG:Fragmenstein:(DetMergeNovOther *31, 40). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 40, 112). An atom was absorbed to ring. d: 0.5761535389764219 p: 2.0
# DEBUG:Fragmenstein:Copying atom bonding from 40 to 112, force=None
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 52 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 52 would make a square, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 53 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 53 would make a square, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 69 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 69 would make a square, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 70 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 70 would make a square, skipping
# DEBUG:Fragmenstein:... Forcing bond between 112 and 132 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 112 and 142 during bond copying
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 111 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 111 already exists
# DEBUG:Fragmenstein:determining novel bond between ring marker 70 and non-ring 84
# DEBUG:Fragmenstein:(DetMergeNovOther *70, 84). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 84, 137). An atom was absorbed to ring. d: 1.352707460352894 p: 2.0
# DEBUG:Fragmenstein:Copying atom bonding from 137 to 84, force=None
# DEBUG:Fragmenstein:... Forcing bond between 84 and 142 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 84 and 138 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 84 and 54 during bond copying
# DEBUG:Fragmenstein:... Potentially adding bond between 84 and 111 during bond copying
# DEBUG:Fragmenstein:Bond between 84 and 111 would make a triangle, skipping
# DEBUG:Fragmenstein:determining novel bond between ring marker 71 and non-ring 96
# DEBUG:Fragmenstein:(DetMergeNovOther *71, 96). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 96, 144). An atom was absorbed to ring. d: 1.1272801373934267 p: 2.0
# DEBUG:Fragmenstein:Copying atom bonding from 144 to 96, force=None
# DEBUG:Fragmenstein:... Forcing bond between 96 and 134 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 96 and 145 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 96 and 43 during bond copying
# DEBUG:Fragmenstein:determining novel bond between ring marker 31 and non-ring 78
# DEBUG:Fragmenstein:(DetMergeNovOther *31, 78). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 78, 112). An atom was absorbed to ring. d: 0.5761535389764219 p: 2.0
# DEBUG:Fragmenstein:Copying atom bonding from 78 to 112, force=None
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 80 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 80 would make a square, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 84 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 84 would make a square, skipping
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 30 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 30 would make a square, skipping
# DEBUG:Fragmenstein:... Forcing bond between 112 and 151 during bond copying
# DEBUG:Fragmenstein:... Potentially adding bond between 112 and 111 during bond copying
# DEBUG:Fragmenstein:Bond between 112 and 111 already exists
# DEBUG:Fragmenstein:determining novel bond between ring marker 30 and non-ring 74
# INFO:Fragmenstein:(DetMergeNovOther: 74, 103). A novel bonding to ring may be added. d: 3.77450625089972 p: 2.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 30 and non-ring 77
# INFO:Fragmenstein:(DetMergeNovOther: 77, 105). A novel bonding to ring may be added. d: 2.3053721213946865 p: 2.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 30 and non-ring 78
# INFO:Fragmenstein:(DetMergeNovOther: 78, 105). A novel bonding to ring may be added. d: 1.1767461545246096 p: 2.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 30 and non-ring 85
# INFO:Fragmenstein:(DetMergeNovOther: 85, 104). A novel bonding to ring may be added. d: 1.621979291219265 p: 2.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 68 and non-ring 26
# INFO:Fragmenstein:(DetMergeNovOther: 26, 129). A novel bonding to ring may be added. d: 1.3077101886058318 p: 0.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 84 and non-ring 18
# INFO:Fragmenstein:(DetMergeNovOther: 18, 149). A novel bonding to ring may be added. d: 1.101791573252355 p: 0.0
# DEBUG:Fragmenstein:Triangle present (36, 91, 96).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 96 and 36
# DEBUG:Fragmenstein:Triangle present (91, 96, 92).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 96 and 92
# DEBUG:Fragmenstein:Triangle present (91, 96, 118).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 96 and 118
# DEBUG:Fragmenstein:`_emergency_joining` called
# INFO:Fragmenstein:Molecule disconnected in 6 parts. Please inspect final product!
# DEBUG:Fragmenstein:Connecting 64 with 125 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 65 with 126 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 66 with 127 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 67 with 129 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 68 with 130 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 69 with 131 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 60 with 122 would have a 1.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 24 with 122 would have a 0.0 penalised distance of 0.7033386633069642
# DEBUG:Fragmenstein:Connecting 24 with 122 would have a 0.0 penalised distance of 2.0774809376288164
# DEBUG:Fragmenstein:Connecting 56 with 122 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 24 with 122 would have a 0.0 penalised distance of 2.0774809376288164
# DEBUG:Fragmenstein:Connecting 3 with 10 would have a 0.0 penalised distance of 5.99518901116868
# DEBUG:Fragmenstein:Connecting 3 with 10 would have a 0.0 penalised distance of 4.779060978987665
# DEBUG:Fragmenstein:Connecting 3 with 10 would have a 0.0 penalised distance of 7.195564925853028
# DEBUG:Fragmenstein:Connecting 3 with 10 would have a 0.0 penalised distance of 4.779060978987665
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 2.4203294758555067
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 3.6083809260692457
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 3.6083809260692457
# DEBUG:Fragmenstein:Connecting 64 with 125 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 65 with 126 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 66 with 127 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 67 with 129 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 68 with 130 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 69 with 131 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 60 with 122 would have a 1.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Molecules will be joined via atoms 64+125 (0.0 Å) via the addition of -1 atoms.
# DEBUG:Fragmenstein:Molecules will be joined via atoms 65+126 (0.0 Å) via the addition of -1 atoms.
# DEBUG:Fragmenstein:Molecules will be joined via atoms 66+127 (0.0 Å) via the addition of -1 atoms.
# DEBUG:Fragmenstein:Molecules will be joined via atoms 67+129 (0.0 Å) via the addition of -1 atoms.
# DEBUG:Fragmenstein:Molecules will be joined via atoms 68+130 (0.0 Å) via the addition of -1 atoms.
# DEBUG:Fragmenstein:Molecules will be joined via atoms 69+131 (0.0 Å) via the addition of -1 atoms.
# DEBUG:Fragmenstein:Molecules will be joined via atoms 60+122 (0.0 Å) via the addition of -1 atoms.
# INFO:Fragmenstein:Molecule disconnected in 5 parts. Please inspect final product!
# DEBUG:Fragmenstein:Connecting 24 with 132 would have a 0.0 penalised distance of 0.7033386633069642
# DEBUG:Fragmenstein:Connecting 24 with 132 would have a 0.0 penalised distance of 2.0774809376288164
# DEBUG:Fragmenstein:Connecting 56 with 132 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 24 with 132 would have a 0.0 penalised distance of 2.0774809376288164
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 2.4203294758555067
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 3.6083809260692457
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 3.6083809260692457
# DEBUG:Fragmenstein:Connecting 56 with 132 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Molecules will be joined via atoms 56+132 (0.0 Å) via the addition of -1 atoms.
# INFO:Fragmenstein:Molecule disconnected in 4 parts. Please inspect final product!
# DEBUG:Fragmenstein:Connecting 24 with 133 would have a 0.0 penalised distance of 0.7033386633069642
# DEBUG:Fragmenstein:Connecting 24 with 133 would have a 0.0 penalised distance of 2.0774809376288164
# DEBUG:Fragmenstein:Connecting 24 with 133 would have a 0.0 penalised distance of 2.0774809376288164
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Connecting 0 with 1 would have a 0.0 penalised distance of 0.0
# DEBUG:Fragmenstein:Molecules will be joined via atoms 0+1 (0.0 Å) via the addition of -1 atoms.
# INFO:Fragmenstein:Molecule disconnected in 3 parts. Please inspect final product!
# DEBUG:Fragmenstein:Connecting 0 with 26 would have a 0.0 penalised distance of 2.0774809376288164
# DEBUG:Fragmenstein:Connecting 0 with 2 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 24 with 133 would have a 0.0 penalised distance of 0.7033386633069642
# DEBUG:Fragmenstein:Connecting 24 with 133 would have a 0.0 penalised distance of 0.7033386633069642
# DEBUG:Fragmenstein:Molecules will be joined via atoms 24+133 (0.7033386633069642 Å) via the addition of 0 atoms.
# INFO:Fragmenstein:Molecule disconnected in 2 parts. Please inspect final product!
# DEBUG:Fragmenstein:Connecting 133 with 134 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Connecting 133 with 134 would have a 0.0 penalised distance of 1.7713346432463546
# DEBUG:Fragmenstein:Molecules will be joined via atoms 133+134 (1.7713346432463546 Å) via the addition of 0 atoms.
# DEBUG:Fragmenstein:Expanded
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 102), ('AROMATIC', 45), ('DOUBLE', 8)]; Atoms: [('H', 58), ('C', 52), ('N', 13), ('O', 10), ('Br', 2), ('Cl', 1)]
# CRITICAL:Fragmenstein:Absorption required for the atom pairs: [[30, 0], [18, 44], [49, 31], [50, 32], [51, 33], [52, 41], [53, 42], [54, 34], [55, 35], [57, 43], [58, 45], [59, 36], [63, 46], [114, 107], [115, 108], [116, 109], [117, 110], [118, 111], [105, 119], [121, 112], [60, 122], [123, 61], [124, 62], [125, 64], [126, 65], [127, 66], [129, 67], [130, 68], [131, 69], [56, 132], [133, 24], [134, 135]]
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 75), ('AROMATIC', 39), ('DOUBLE', 6)]; Atoms: [('H', 43), ('C', 41), ('N', 12), ('O', 6), ('Cl', 1), ('Br', 1)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 93), ('AROMATIC', 21), ('DOUBLE', 6)]; Atoms: [('H', 43), ('C', 41), ('N', 12), ('O', 6), ('Cl', 1), ('Br', 1)]
# DEBUG:Fragmenstein:------------ Aromatic correction done ------------
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# WARNING:Fragmenstein:This molecule (name.0~name.1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 1 bridging atoms and replacing with fused ring
# DEBUG:Fragmenstein:This molecule (name.0~name.1) has a fused ring
# DEBUG:Fragmenstein:Fragments: 11; Bonds: [('SINGLE', 89), ('AROMATIC', 6), ('DOUBLE', 2)]; Atoms: [('H', 43), ('C', 40), ('N', 12), ('O', 6), ('Cl', 1), ('Br', 1)]
# DEBUG:Fragmenstein:------------ ring fixes done ------------
# DEBUG:Fragmenstein:Storing molecule #4 in `.modifications`
# DEBUG:Fragmenstein:downgrading bond 55
# DEBUG:Fragmenstein:downgrading bond 56
# DEBUG:Fragmenstein:downgrading bond 58
# DEBUG:Fragmenstein:downgrading bond 70
# DEBUG:Fragmenstein:downgrading bond 71
# DEBUG:Fragmenstein:downgrading bond 80
# DEBUG:Fragmenstein:Fragments: 11; Bonds: [('SINGLE', 95), ('DOUBLE', 2)]; Atoms: [('H', 43), ('C', 40), ('N', 12), ('O', 6), ('Cl', 1), ('Br', 1)]
# DEBUG:Fragmenstein:------------ oddity fixes done ------------
# DEBUG:Fragmenstein:Fragments: 11; Bonds: [('SINGLE', 156), ('DOUBLE', 2)]; Atoms: [('H', 104), ('C', 40), ('N', 12), ('O', 6), ('Cl', 1), ('Br', 1)]
# DEBUG:Fragmenstein:------------ hydrogens done ------------
# ...
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Current deque rotation count -54
# DEBUG:Fragmenstein:Current deque rotation count -55
# DEBUG:Fragmenstein:Current deque rotation count -56
# DEBUG:Fragmenstein:Current deque rotation count -57
# DEBUG:Fragmenstein:Current deque rotation count -58
# DEBUG:Fragmenstein:Current deque rotation count -59
# DEBUG:Fragmenstein:Current deque rotation count -60
# DEBUG:Fragmenstein:Current deque rotation count -61
# DEBUG:Fragmenstein:Current deque rotation count -62
# DEBUG:Fragmenstein:Current deque rotation count -63
# DEBUG:Fragmenstein:Current deque rotation count -64
# DEBUG:Fragmenstein:Current deque rotation count -65
# DEBUG:Fragmenstein:Current deque rotation count -66
# DEBUG:Fragmenstein:Current deque rotation count -67
# DEBUG:Fragmenstein:Current deque rotation count -68
# DEBUG:Fragmenstein:Current deque rotation count -69
# DEBUG:Fragmenstein:Current deque rotation count -70
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing C at position 0
# DEBUG:Fragmenstein:Parsing C at position 1
# DEBUG:Fragmenstein:Parsing N at position 17
# DEBUG:Fragmenstein:Parsing N at position 3
# DEBUG:Fragmenstein:Parsing S at position 6
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing C at position 24
# DEBUG:Fragmenstein:Parsing O at position 34
# DEBUG:Fragmenstein:Parsing S at position 7
# DEBUG:Fragmenstein:Parsing C at position 16
# DEBUG:Fragmenstein:Parsing C at position 18
# DEBUG:Fragmenstein:Parsing C at position 19
# DEBUG:Fragmenstein:Parsing C at position 22
# DEBUG:Fragmenstein:Parsing O at position 2
# DEBUG:Fragmenstein:Parsing N at position 13
# DEBUG:Fragmenstein:Parsing N at position 14
# DEBUG:Fragmenstein:Parsing C at position 15
# DEBUG:Fragmenstein:Parsing C at position 20
# DEBUG:Fragmenstein:Parsing C at position 21
# DEBUG:Fragmenstein:Parsing N at position 23
# DEBUG:Fragmenstein:Parsing N at position 28
# DEBUG:Fragmenstein:Parsing C at position 9
# DEBUG:Fragmenstein:Parsing C at position 12
# DEBUG:Fragmenstein:Parsing C at position 25
# DEBUG:Fragmenstein:Parsing C at position 26
# DEBUG:Fragmenstein:Parsing C at position 27
# DEBUG:Fragmenstein:Parsing O at position 4
# DEBUG:Fragmenstein:Parsing O at position 10
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing N at position 30
# DEBUG:Fragmenstein:Parsing O at position 35
# DEBUG:Fragmenstein:Parsing O at position 36
# DEBUG:Fragmenstein:Parsing C at position 8
# DEBUG:Fragmenstein:Parsing C at position 31
# DEBUG:Fragmenstein:Parsing S at position 32
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing H at position 37
# DEBUG:Fragmenstein:Parsing H at position 38
# DEBUG:Fragmenstein:Parsing H at position 39
# DEBUG:Fragmenstein:Parsing H at position 40
# DEBUG:Fragmenstein:Parsing H at position 41
# DEBUG:Fragmenstein:Parsing H at position 61
# DEBUG:Fragmenstein:Parsing H at position 62
# DEBUG:Fragmenstein:Parsing H at position 51
# DEBUG:Fragmenstein:Parsing H at position 52
# DEBUG:Fragmenstein:Parsing H at position 53
# DEBUG:Fragmenstein:Parsing H at position 58
# DEBUG:Fragmenstein:Parsing H at position 48
# DEBUG:Fragmenstein:Parsing H at position 49
# DEBUG:Fragmenstein:Parsing H at position 50
# DEBUG:Fragmenstein:Parsing H at position 54
# DEBUG:Fragmenstein:Parsing H at position 55
# DEBUG:Fragmenstein:Parsing H at position 56
# DEBUG:Fragmenstein:Parsing H at position 57
# DEBUG:Fragmenstein:Parsing H at position 59
# DEBUG:Fragmenstein:Parsing H at position 60
# DEBUG:Fragmenstein:Parsing H at position 43
# DEBUG:Fragmenstein:Parsing H at position 46
# DEBUG:Fragmenstein:Parsing H at position 47
# DEBUG:Fragmenstein:Parsing H at position 63
# DEBUG:Fragmenstein:Parsing H at position 64
# DEBUG:Fragmenstein:Parsing H at position 65
# DEBUG:Fragmenstein:Parsing H at position 44
# DEBUG:Fragmenstein:Parsing H at position 45
# DEBUG:Fragmenstein:Parsing H at position 66
# DEBUG:Fragmenstein:Parsing H at position 67
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 42
# DEBUG:Fragmenstein:Parsing H at position 68
# DEBUG:Fragmenstein:Parsing H at position 69
# DEBUG:Fragmenstein:Parsing H at position 70
# DEBUG:Fragmenstein:Parsing H at position 71
# DEBUG:Fragmenstein:Parsing H at position 72
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0-hit1 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Current deque rotation count -54
# DEBUG:Fragmenstein:Current deque rotation count -55
# DEBUG:Fragmenstein:Current deque rotation count -56
# DEBUG:Fragmenstein:Current deque rotation count -57
# DEBUG:Fragmenstein:Current deque rotation count -58
# DEBUG:Fragmenstein:Current deque rotation count -59
# DEBUG:Fragmenstein:Current deque rotation count -60
# DEBUG:Fragmenstein:Current deque rotation count -61
# DEBUG:Fragmenstein:Current deque rotation count -62
# DEBUG:Fragmenstein:Current deque rotation count -63
# DEBUG:Fragmenstein:Current deque rotation count -64
# DEBUG:Fragmenstein:Current deque rotation count -65
# DEBUG:Fragmenstein:Current deque rotation count -66
# DEBUG:Fragmenstein:Current deque rotation count -67
# DEBUG:Fragmenstein:Current deque rotation count -68
# DEBUG:Fragmenstein:Current deque rotation count -69
# DEBUG:Fragmenstein:Current deque rotation count -70
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing C at position 0
# DEBUG:Fragmenstein:Parsing C at position 1
# DEBUG:Fragmenstein:Parsing N at position 17
# DEBUG:Fragmenstein:Parsing N at position 3
# DEBUG:Fragmenstein:Parsing S at position 6
# DEBUG:Fragmenstein:Parsing O at position 5
# DEBUG:Fragmenstein:Parsing C at position 24
# DEBUG:Fragmenstein:Parsing O at position 34
# DEBUG:Fragmenstein:Parsing S at position 7
# DEBUG:Fragmenstein:Parsing C at position 16
# DEBUG:Fragmenstein:Parsing C at position 18
# DEBUG:Fragmenstein:Parsing C at position 19
# DEBUG:Fragmenstein:Parsing C at position 22
# DEBUG:Fragmenstein:Parsing O at position 2
# DEBUG:Fragmenstein:Parsing N at position 13
# DEBUG:Fragmenstein:Parsing N at position 14
# DEBUG:Fragmenstein:Parsing C at position 15
# DEBUG:Fragmenstein:Parsing C at position 20
# DEBUG:Fragmenstein:Parsing C at position 21
# DEBUG:Fragmenstein:Parsing N at position 23
# DEBUG:Fragmenstein:Parsing N at position 28
# DEBUG:Fragmenstein:Parsing C at position 9
# DEBUG:Fragmenstein:Parsing C at position 12
# DEBUG:Fragmenstein:Parsing C at position 25
# DEBUG:Fragmenstein:Parsing C at position 26
# DEBUG:Fragmenstein:Parsing C at position 27
# DEBUG:Fragmenstein:Parsing O at position 4
# DEBUG:Fragmenstein:Parsing O at position 10
# DEBUG:Fragmenstein:Parsing C at position 11
# DEBUG:Fragmenstein:Parsing C at position 29
# DEBUG:Fragmenstein:Parsing N at position 30
# DEBUG:Fragmenstein:Parsing O at position 35
# DEBUG:Fragmenstein:Parsing O at position 36
# DEBUG:Fragmenstein:Parsing C at position 8
# DEBUG:Fragmenstein:Parsing C at position 31
# DEBUG:Fragmenstein:Parsing S at position 32
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing H at position 37
# DEBUG:Fragmenstein:Parsing H at position 38
# DEBUG:Fragmenstein:Parsing H at position 39
# DEBUG:Fragmenstein:Parsing H at position 40
# DEBUG:Fragmenstein:Parsing H at position 41
# DEBUG:Fragmenstein:Parsing H at position 61
# DEBUG:Fragmenstein:Parsing H at position 62
# DEBUG:Fragmenstein:Parsing H at position 51
# DEBUG:Fragmenstein:Parsing H at position 52
# DEBUG:Fragmenstein:Parsing H at position 53
# DEBUG:Fragmenstein:Parsing H at position 58
# DEBUG:Fragmenstein:Parsing H at position 48
# DEBUG:Fragmenstein:Parsing H at position 49
# DEBUG:Fragmenstein:Parsing H at position 50
# DEBUG:Fragmenstein:Parsing H at position 54
# DEBUG:Fragmenstein:Parsing H at position 55
# DEBUG:Fragmenstein:Parsing H at position 56
# DEBUG:Fragmenstein:Parsing H at position 57
# DEBUG:Fragmenstein:Parsing H at position 59
# DEBUG:Fragmenstein:Parsing H at position 60
# DEBUG:Fragmenstein:Parsing H at position 43
# DEBUG:Fragmenstein:Parsing H at position 46
# DEBUG:Fragmenstein:Parsing H at position 47
# DEBUG:Fragmenstein:Parsing H at position 63
# DEBUG:Fragmenstein:Parsing H at position 64
# DEBUG:Fragmenstein:Parsing H at position 65
# DEBUG:Fragmenstein:Parsing H at position 44
# DEBUG:Fragmenstein:Parsing H at position 45
# DEBUG:Fragmenstein:Parsing H at position 66
# DEBUG:Fragmenstein:Parsing H at position 67
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 42
# DEBUG:Fragmenstein:Parsing H at position 68
# DEBUG:Fragmenstein:Parsing H at position 69
# DEBUG:Fragmenstein:Parsing H at position 70
# DEBUG:Fragmenstein:Parsing H at position 71
# DEBUG:Fragmenstein:Parsing H at position 72
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0-hit1 - placing monster in structure
# DEBUG:Fragmenstein:hit0-hit1 - saving params
# DEBUG:Fragmenstein:hit0-hit1 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0-hit1 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0-hit1 - saving mols from monster
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.5:  6.315521898180952 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.25:  4.220017781571455 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.125:  2.6380649691830005 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.0625:  1.5981497982336403 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.03125:  1.5895257442758535 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.015625:  0.33105576383057667 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.0078125:  0.005138854656028258 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.00390625:  0.002864336192679673 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# WARNING:Fragmenstein:hit0-hit1 - failed to minimise without constraints:  -0.07558921415304987 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0-hit1 - calculating mRMSD
# INFO:Fragmenstein:hit0-hit1 - final score: -0.07558921415304987 kcal/mol, RMSD: 1.6603313103384563.
# DEBUG:Fragmenstein:hit0-hit1 - saving pose from igor
# DEBUG:Fragmenstein:hit0-hit1 - calculating Gibbs
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# INFO:Fragmenstein:hit0-hit1 - Time taken: 103.73870730400085

# %%
# Process each SMILES string with the reference molecule using Victor
for i, smile in enumerate(smiles_list):
    hit_mol = Chem.AddHs(AllChem.MolFromSmiles(smile))
    AllChem.EmbedMolecule(hit_mol, AllChem.ETKDG())
    victor_with_ref = Victor(hits=[reference_mol, hit_mol], pdb_filename=protein_pdb_path)
    try:
        victor_with_ref.combine()
    except Chem.AtomValenceException:
        logging.info(f'Atom valence exception occurred for molecule {i+1} with reference, trying to rectify...')
        victor_with_ref.rectify(collapse_rings=True, joining_cutoff=3.0)
        victor_with_ref.combine()

    optimized_with_ref_molecule = victor_with_ref.minimized_mol

    # Append 2D structure to the list
    mol_2d_structures.append(optimized_with_ref_molecule)

    optimized_with_ref_smiles = Chem.MolToSmiles(optimized_with_ref_molecule)
    minimized_smiles_list.append(optimized_with_ref_smiles)

    # Calculate Lipinski's descriptors for the molecule combined with the reference
    mw_ref = Descriptors.ExactMolWt(optimized_with_ref_molecule)
    logp_ref = Descriptors.MolLogP(optimized_with_ref_molecule)
    hba_ref = Descriptors.NumHAcceptors(optimized_with_ref_molecule)
    hbd_ref = Descriptors.NumHDonors(optimized_with_ref_molecule)

    # Append data to molecule_data list
    molecule_data.append([optimized_with_ref_smiles, mw_ref, logp_ref, hba_ref, hbd_ref, f'optimized_with_ref_molecule_{i}.mol'])
# Out:
# DEBUG:Fragmenstein:hit0-hit1 - harmonising warheads on hits in "first" mode
# DEBUG:Fragmenstein:Merging: ['hit0', 'hit1']
# DEBUG:Fragmenstein:Merged
# DEBUG:Fragmenstein:Starting ring expansion
# DEBUG:Fragmenstein:64 (formerly 133 existed already: fused ring or similar.
# DEBUG:Fragmenstein:65 (formerly 105 existed already: fused ring or similar.
# DEBUG:Fragmenstein:Restoring original bonding if any.
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5
ROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'SINGLE'], ['AROMATIC', 'AROMATIC', 'AROMATIC'], ['AROMATIC', 'AROMATIC', 'AROMATIC']], 'current_is': [102, 103, 104, 105, 106, 107]}
# DEBUG:Fragmenstein:ring bond #0 between 102 107(<=713,712)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #0 between 102 103(<=713,714)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #1 between 103 102(<=714,713)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #1 between 103 113(<=714,715)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 103 104(<=714,721)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #2 between 104 103(<=721,714)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #2 between 104 105(<=721,722)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 105 104(<=722,721)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #3 between 105 106(<=722,723)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #3 between 105 59(<=722,752)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 106 105(<=723,722)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #4 between 106 107(<=723,712)  added as AROMATIC
# DEBUG:Fragmenstein:ring bond #5 between 107 102(<=712,713)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:ring bond #5 between 107 106(<=712,723)  exists already (has AROMATIC as expected AROMATIC)
# DEBUG:Fragmenstein:Restoring ring {'atom': <rdkit.Chem.rdchem.Atom object at 0x7c0b5d2aadc0>, 'ori_name': 'hit1', 'elements': ['C', 'C', 'O', 'C', 'C', 'N'], 'neighbors': [[715, 717, 744], [716, 718, 746, 747], [717, 719], [718, 720, 748, 749], [719, 715, 750, 751], [714, 716, 720]], 'ori_is': [716, 717, 718, 719, 720, 715], 'xs': [6.058142004771364, 7.027292726677339, 7.809697947093025, 7.366727484710817, 5.856587845723717, 5.242119014438013], 'ys': [2.3354663240593774, 2.127862745300823, 1.0162599951416633, 0.10871878744695929, -0.12023429925947794, 1.147734343466438], 'zs': [0.5354932940838188, 1.6769527250913792, 1.5033641010501677, 0.5736806578901128, 0.7483065465930318, 0.4095351953424232], 'bonds': [['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE', 'SINGLE'], ['SINGLE', 'SINGLE', 'SINGLE']], 'current_is': [108, 109, 110, 111, 112, 113]}
# DEBUG:Fragmenstein:ring bond #0 between 108 113(<=716,715)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 108 109(<=716,717)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #0 between 108 52(<=716,744)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 109 108(<=717,716)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #1 between 109 110(<=717,718)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 109 53(<=717,746)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #1 between 109 54(<=717,747)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #2 between 110 109(<=718,717)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #2 between 110 111(<=718,719)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 111 110(<=719,718)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #3 between 111 112(<=719,720)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 111 55(<=719,748)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #3 between 111 56(<=719,749)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 112 111(<=720,719)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #4 between 112 113(<=720,715)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 112 57(<=720,750)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #4 between 112 58(<=720,751)  added as SINGLE
# DEBUG:Fragmenstein:ring bond #5 between 113 103(<=715,714)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 113 108(<=715,716)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:ring bond #5 between 113 112(<=715,720)  exists already (has SINGLE as expected SINGLE)
# DEBUG:Fragmenstein:Adding novel bonding (if any)...
# DEBUG:Fragmenstein:determining novel bond between ring markers 29 and 60
# DEBUG:Fragmenstein:Copying atom bonding from 105 to 63, force=True
# DEBUG:Fragmenstein:... Forcing bond between 63 and 104 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 63 and 106 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 63 and 59 during bond copying
# DEBUG:Fragmenstein:Copying atom bonding from 105 to 64, force=True
# DEBUG:Fragmenstein:... Forcing bond between 64 and 104 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 64 and 106 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 64 and 59 during bond copying
# INFO:Fragmenstein:A novel fused ring pair was found
# DEBUG:Fragmenstein:determining novel bond between ring markers 30 and 60
# INFO:Fragmenstein:A novel bond-connected ring pair was found
# DEBUG:Fragmenstein:Copying atom bonding from 106 to 71, force=True
# DEBUG:Fragmenstein:... Forcing bond between 71 and 105 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 71 and 107 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 71 and 63 during bond copying
# DEBUG:Fragmenstein:determining novel bond between ring markers 33 and 61
# INFO:Fragmenstein:A novel bond-connected ring pair was found
# DEBUG:Fragmenstein:Copying atom bonding from 112 to 84, force=True
# DEBUG:Fragmenstein:... Forcing bond between 84 and 111 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 84 and 113 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 84 and 57 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 84 and 58 during bond copying
# DEBUG:Fragmenstein:determining novel bond between ring markers 33 and 60
# DEBUG:Fragmenstein:Copying atom bonding from 102 to 89, force=True
# DEBUG:Fragmenstein:... Forcing bond between 89 and 107 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 89 and 103 during bond copying
# INFO:Fragmenstein:A novel spiro ring pair was found
# DEBUG:Fragmenstein:determining novel bond between ring markers 30 and 51
# INFO:Fragmenstein:A novel bond-connected ring pair was found
# DEBUG:Fragmenstein:Copying atom bonding from 101 to 69, force=True
# DEBUG:Fragmenstein:... Forcing bond between 69 and 96 during bond copying
# DEBUG:Fragmenstein:... Forcing bond between 69 and 100 during bond copying
# DEBUG:Fragmenstein:_get_novel_other_pairs - close_pairs @ 1.0: [(3, 39), (23, 58), (29, 59), (39, 3), (58, 23), (59, 29), (59, 29), (29, 59), (3, 39), (23, 58), (29, 59), (39, 3), (58, 23), (59, 29), (59, 29), (29, 59)]
# DEBUG:Fragmenstein:_get_novel_other_pairs - bonded_pairs @ 1.0: [(30, 35), (42, 2), (61, 8)]
# DEBUG:Fragmenstein:determining novel bond between ring marker 29 and non-ring 59
# DEBUG:Fragmenstein:(DetMergeNovOther *29, 59). Other is within ring. Forcing absoption
# INFO:Fragmenstein:(DetMergeNovOther: 59, 63). An atom was absorbed to ring. d: 0.9197263469370155 p: 2.0
# DEBUG:Fragmenstein:Copying atom bonding from 59 to 63, force=None
# DEBUG:Fragmenstein:... Potentially adding bond between 63 and 60 during bond copying
# DEBUG:Fragmenstein:Bond between 63 and 60 would make a triangle, skipping
# DEBUG:Fragmenstein:... Forcing bond between 63 and 105 during bond copying
# DEBUG:Fragmenstein:determining novel bond between ring marker 30 and non-ring 35
# INFO:Fragmenstein:(DetMergeNovOther: 35, 69). A novel bonding to ring may be added. d: 2.0680222367926278 p: 2.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 42 and non-ring 2
# INFO:Fragmenstein:(DetMergeNovOther: 2, 90). A novel bonding to ring may be added. d: 2.161677507729315 p: 0.0
# DEBUG:Fragmenstein:determining novel bond between ring marker 61 and non-ring 8
# INFO:Fragmenstein:(DetMergeNovOther: 8, 108). A novel bonding to ring may be added. d: 2.4754816091132112 p: 1.0
# DEBUG:Fragmenstein:Square present (5, 61, 93, 79).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 79 and 93
# DEBUG:Fragmenstein:Triangle present (53, 54, 92).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 54 and 92
# DEBUG:Fragmenstein:Triangle present (53, 54, 61).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 61 and 53
# DEBUG:Fragmenstein:Square present (74, 79, 91, 98).
# DEBUG:Fragmenstein:Removing triangle/square forming bond between 79 and 91
# DEBUG:Fragmenstein:`_emergency_joining` called
# DEBUG:Fragmenstein:Expanded
# DEBUG:Fragmenstein:============== Rectifier fix started =============
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 77), ('AROMATIC', 32), ('DOUBLE', 2)]; Atoms: [('H', 41), ('C', 40), ('N', 10), ('O', 5), ('Cl', 2), ('F', 1)]
# CRITICAL:Fragmenstein:Absorption required for the atom pairs: [[34, 3]]
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 77), ('AROMATIC', 32), ('DOUBLE', 2)]; Atoms: [('H', 41), ('C', 40), ('N', 10), ('O', 5), ('F', 1), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ overclose safeguard done ------------
# DEBUG:Fragmenstein:Downgrading non-aromatic ring to single bond
# DEBUG:Fragmenstein:Fragments: 1; Bonds: [('SINGLE', 81), ('AROMATIC', 28), ('DOUBLE', 2)]; Atoms: [('H', 41), ('C', 40), ('N', 10), ('O', 5), ('F', 1), ('Cl', 1)]
# DEBUG:Fragmenstein:------------ Aromatic correction done ------------
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:non ring atom bonded to bridgehead
# INFO:Fragmenstein:Zero-atom bridged ring issue: bond between 29-58 removed
# INFO:Fragmenstein:Zero-atom bridged ring issue: bond between 52-53 removed
# INFO:Fragmenstein:Zero-atom bridged ring issue: bond between 64-65 removed
# INFO:Fragmenstein:Zero-atom bridged ring issue: bond between 97-73 removed
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 3 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 2 bridging atoms and replacing with fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:mysterious ring system 9 + 6
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:mysterious ring system 13 + 6
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(2, 56, 49, 50, 51, 52, 47, 88, 89, 90, 91, 68, 73), (9, 57, 58, 59, 26, 24), (25, 24, 9, 57, 61, 60, 29), (48, 86, 85, 92, 88, 47), (49, 50, 53, 54, 55, 56), (69, 70, 71, 72, 73, 68), (75, 76, 77, 78, 79, 74)] share [] with [] in the inside and [] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:mysterious ring system 13 + 6
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(0, 66, 67, 59, 26, 79, 74), (2, 56, 49, 50, 51, 52, 47, 88, 89, 90, 91, 68, 73), (62, 63, 64, 65, 66, 67), (69, 70, 71, 72, 73, 68), (75, 76, 77, 78, 79, 74), (80, 54, 84, 83, 82, 81)] share [] with [] in the inside and [] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:mysterious ring system 9 + 6
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# CRITICAL:Fragmenstein:This is impossible. [(0, 66, 67, 59, 26, 79, 74), (2, 56, 49, 50, 51, 52, 47, 88, 89, 90, 91, 68, 73), (25, 24, 9, 57, 61, 60, 29), (49, 50, 53, 54, 55, 56), (69, 70, 71, 72, 73, 68), (75, 76, 77, 78, 79, 74), (80, 54, 84, 83, 82, 81)] share [] with [] in the inside and [] on the edge?
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# WARNING:Fragmenstein:This is really odd! Why is there a bond already??
# WARNING:Fragmenstein:Too many trials to remove bridge.
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge: leaving/spiro
# DEBUG:Fragmenstein:This molecule (hit0-hit1) has a fused ring
# WARNING:Fragmenstein:This molecule (hit0-hit1) has a bridge that will be removed
# WARNING:Fragmenstein:Removing 0 bridging atoms and replacing with fused ring
# ...
# DEBUG:Fragmenstein:Parsing H at position 107
# DEBUG:Fragmenstein:Parsing H at position 108
# DEBUG:Fragmenstein:Parsing H at position 122
# DEBUG:Fragmenstein:Parsing H at position 98
# DEBUG:Fragmenstein:Parsing H at position 109
# DEBUG:Fragmenstein:Parsing H at position 96
# DEBUG:Fragmenstein:Parsing H at position 97
# DEBUG:Fragmenstein:Parsing H at position 99
# DEBUG:Fragmenstein:Parsing H at position 100
# DEBUG:Fragmenstein:Parsing H at position 120
# DEBUG:Fragmenstein:Parsing H at position 91
# DEBUG:Fragmenstein:Parsing H at position 92
# DEBUG:Fragmenstein:Parsing H at position 95
# DEBUG:Fragmenstein:Parsing H at position 124
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 93
# DEBUG:Fragmenstein:Parsing H at position 94
# DEBUG:Fragmenstein:Parsing H at position 74
# DEBUG:Fragmenstein:Parsing H at position 75
# DEBUG:Fragmenstein:Parsing H at position 76
# DEBUG:Fragmenstein:Parsing H at position 77
# DEBUG:Fragmenstein:Parsing H at position 78
# DEBUG:Fragmenstein:Parsing H at position 79
# DEBUG:Fragmenstein:Parsing H at position 101
# DEBUG:Fragmenstein:Parsing H at position 103
# DEBUG:Fragmenstein:Parsing H at position 102
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Making all PDBResidueInfo resn=LIG resi=1 chain=X
# DEBUG:Fragmenstein:hit0-hit1 - is not covalent.
# DEBUG:Fragmenstein:`fix_mol` called...
# DEBUG:Fragmenstein:LIG is being converted (`.convert_mol`)
# DEBUG:Fragmenstein:Filling ICOOR
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by being not hydrogen or dummy
# DEBUG:Fragmenstein:Parsing forth line onwards
# DEBUG:Fragmenstein:Current deque rotation count 0
# DEBUG:Fragmenstein:Ordering atoms without a shuffle first
# DEBUG:Fragmenstein:Ordering atoms by distance from root, and being not hydrogen or dummy
# DEBUG:Fragmenstein:Current deque rotation count -1
# DEBUG:Fragmenstein:Current deque rotation count -2
# DEBUG:Fragmenstein:Current deque rotation count -3
# DEBUG:Fragmenstein:Current deque rotation count -4
# DEBUG:Fragmenstein:Current deque rotation count -5
# DEBUG:Fragmenstein:Current deque rotation count -6
# DEBUG:Fragmenstein:Current deque rotation count -7
# DEBUG:Fragmenstein:Current deque rotation count -8
# DEBUG:Fragmenstein:Current deque rotation count -9
# DEBUG:Fragmenstein:Current deque rotation count -10
# DEBUG:Fragmenstein:Current deque rotation count -11
# DEBUG:Fragmenstein:Current deque rotation count -12
# DEBUG:Fragmenstein:Current deque rotation count -13
# DEBUG:Fragmenstein:Current deque rotation count -14
# DEBUG:Fragmenstein:Current deque rotation count -15
# DEBUG:Fragmenstein:Current deque rotation count -16
# DEBUG:Fragmenstein:Current deque rotation count -17
# DEBUG:Fragmenstein:Current deque rotation count -18
# DEBUG:Fragmenstein:Current deque rotation count -19
# DEBUG:Fragmenstein:Current deque rotation count -20
# DEBUG:Fragmenstein:Current deque rotation count -21
# DEBUG:Fragmenstein:Current deque rotation count -22
# DEBUG:Fragmenstein:Current deque rotation count -23
# DEBUG:Fragmenstein:Current deque rotation count -24
# DEBUG:Fragmenstein:Current deque rotation count -25
# DEBUG:Fragmenstein:Current deque rotation count -26
# DEBUG:Fragmenstein:Current deque rotation count -27
# DEBUG:Fragmenstein:Current deque rotation count -28
# DEBUG:Fragmenstein:Current deque rotation count -29
# DEBUG:Fragmenstein:Current deque rotation count -30
# DEBUG:Fragmenstein:Current deque rotation count -31
# DEBUG:Fragmenstein:Current deque rotation count -32
# DEBUG:Fragmenstein:Current deque rotation count -33
# DEBUG:Fragmenstein:Current deque rotation count -34
# DEBUG:Fragmenstein:Current deque rotation count -35
# DEBUG:Fragmenstein:Current deque rotation count -36
# DEBUG:Fragmenstein:Current deque rotation count -37
# DEBUG:Fragmenstein:Current deque rotation count -38
# DEBUG:Fragmenstein:Current deque rotation count -39
# DEBUG:Fragmenstein:Current deque rotation count -40
# DEBUG:Fragmenstein:Current deque rotation count -41
# DEBUG:Fragmenstein:Current deque rotation count -42
# DEBUG:Fragmenstein:Current deque rotation count -43
# DEBUG:Fragmenstein:Current deque rotation count -44
# DEBUG:Fragmenstein:Current deque rotation count -45
# DEBUG:Fragmenstein:Current deque rotation count -46
# DEBUG:Fragmenstein:Current deque rotation count -47
# DEBUG:Fragmenstein:Current deque rotation count -48
# DEBUG:Fragmenstein:Current deque rotation count -49
# DEBUG:Fragmenstein:Current deque rotation count -50
# DEBUG:Fragmenstein:Current deque rotation count -51
# DEBUG:Fragmenstein:Current deque rotation count -52
# DEBUG:Fragmenstein:Current deque rotation count -53
# DEBUG:Fragmenstein:Current deque rotation count -54
# DEBUG:Fragmenstein:Current deque rotation count -55
# DEBUG:Fragmenstein:Current deque rotation count -56
# DEBUG:Fragmenstein:Current deque rotation count -57
# DEBUG:Fragmenstein:Current deque rotation count -58
# DEBUG:Fragmenstein:Current deque rotation count -59
# DEBUG:Fragmenstein:Current deque rotation count -60
# DEBUG:Fragmenstein:Current deque rotation count -61
# DEBUG:Fragmenstein:Current deque rotation count -62
# DEBUG:Fragmenstein:Current deque rotation count -63
# DEBUG:Fragmenstein:Current deque rotation count -64
# DEBUG:Fragmenstein:Current deque rotation count -65
# DEBUG:Fragmenstein:Current deque rotation count -66
# DEBUG:Fragmenstein:Current deque rotation count -67
# DEBUG:Fragmenstein:Current deque rotation count -68
# DEBUG:Fragmenstein:Current deque rotation count -69
# DEBUG:Fragmenstein:Current deque rotation count -70
# DEBUG:Fragmenstein:Current deque rotation count -71
# DEBUG:Fragmenstein:Current deque rotation count -72
# DEBUG:Fragmenstein:Current deque rotation count -73
# DEBUG:Fragmenstein:Current deque rotation count -74
# DEBUG:Fragmenstein:Current deque rotation count -75
# DEBUG:Fragmenstein:Current deque rotation count -76
# DEBUG:Fragmenstein:Current deque rotation count -77
# DEBUG:Fragmenstein:Current deque rotation count -78
# DEBUG:Fragmenstein:Current deque rotation count -79
# DEBUG:Fragmenstein:Current deque rotation count -80
# DEBUG:Fragmenstein:Current deque rotation count -81
# DEBUG:Fragmenstein:Current deque rotation count -82
# DEBUG:Fragmenstein:Current deque rotation count -83
# DEBUG:Fragmenstein:Current deque rotation count -84
# DEBUG:Fragmenstein:Current deque rotation count -85
# DEBUG:Fragmenstein:Current deque rotation count -86
# DEBUG:Fragmenstein:Current deque rotation count -87
# DEBUG:Fragmenstein:Current deque rotation count -88
# DEBUG:Fragmenstein:Current deque rotation count -89
# DEBUG:Fragmenstein:Current deque rotation count -90
# DEBUG:Fragmenstein:Current deque rotation count -91
# DEBUG:Fragmenstein:Current deque rotation count -92
# DEBUG:Fragmenstein:Current deque rotation count -93
# DEBUG:Fragmenstein:Current deque rotation count -94
# DEBUG:Fragmenstein:Current deque rotation count -95
# DEBUG:Fragmenstein:Current deque rotation count -96
# DEBUG:Fragmenstein:Current deque rotation count -97
# DEBUG:Fragmenstein:Current deque rotation count -98
# DEBUG:Fragmenstein:Current deque rotation count -99
# DEBUG:Fragmenstein:Current deque rotation count -100
# DEBUG:Fragmenstein:Current deque rotation count -101
# DEBUG:Fragmenstein:Current deque rotation count -102
# DEBUG:Fragmenstein:Current deque rotation count -103
# DEBUG:Fragmenstein:Current deque rotation count -104
# DEBUG:Fragmenstein:Current deque rotation count -105
# DEBUG:Fragmenstein:Current deque rotation count -106
# DEBUG:Fragmenstein:Current deque rotation count -107
# DEBUG:Fragmenstein:Current deque rotation count -108
# DEBUG:Fragmenstein:Current deque rotation count -109
# DEBUG:Fragmenstein:Current deque rotation count -110
# DEBUG:Fragmenstein:Current deque rotation count -111
# DEBUG:Fragmenstein:Current deque rotation count -112
# DEBUG:Fragmenstein:Current deque rotation count -113
# DEBUG:Fragmenstein:Current deque rotation count -114
# DEBUG:Fragmenstein:Current deque rotation count -115
# DEBUG:Fragmenstein:Current deque rotation count -116
# DEBUG:Fragmenstein:Current deque rotation count -117
# DEBUG:Fragmenstein:Current deque rotation count -118
# DEBUG:Fragmenstein:Current deque rotation count -119
# DEBUG:Fragmenstein:Current deque rotation count -120
# DEBUG:Fragmenstein:Current deque rotation count -121
# DEBUG:Fragmenstein:Filling ATOM records...
# DEBUG:Fragmenstein:Parsing C at position 0
# DEBUG:Fragmenstein:Parsing N at position 1
# DEBUG:Fragmenstein:Parsing C at position 15
# DEBUG:Fragmenstein:Parsing N at position 16
# DEBUG:Fragmenstein:Parsing N at position 20
# DEBUG:Fragmenstein:Parsing C at position 17
# DEBUG:Fragmenstein:Parsing C at position 19
# DEBUG:Fragmenstein:Parsing C at position 18
# DEBUG:Fragmenstein:Parsing C at position 22
# DEBUG:Fragmenstein:Parsing C at position 21
# DEBUG:Fragmenstein:Parsing C at position 43
# DEBUG:Fragmenstein:Parsing O at position 4
# DEBUG:Fragmenstein:Parsing C at position 40
# DEBUG:Fragmenstein:Parsing C at position 42
# DEBUG:Fragmenstein:Parsing N at position 6
# DEBUG:Fragmenstein:Parsing O at position 35
# DEBUG:Fragmenstein:Parsing C at position 41
# DEBUG:Fragmenstein:Parsing C at position 49
# DEBUG:Fragmenstein:Parsing C at position 5
# DEBUG:Fragmenstein:Parsing C at position 7
# DEBUG:Fragmenstein:Parsing C at position 36
# DEBUG:Fragmenstein:Parsing C at position 45
# DEBUG:Fragmenstein:Parsing C at position 50
# DEBUG:Fragmenstein:Parsing C at position 54
# DEBUG:Fragmenstein:Parsing O at position 8
# DEBUG:Fragmenstein:Parsing C at position 9
# DEBUG:Fragmenstein:Parsing C at position 10
# DEBUG:Fragmenstein:Parsing C at position 37
# DEBUG:Fragmenstein:Parsing C at position 44
# DEBUG:Fragmenstein:Parsing C at position 51
# DEBUG:Fragmenstein:Parsing C at position 53
# DEBUG:Fragmenstein:Parsing N at position 3
# DEBUG:Fragmenstein:Parsing Br at position 11
# DEBUG:Fragmenstein:Parsing C at position 38
# DEBUG:Fragmenstein:Parsing N at position 48
# DEBUG:Fragmenstein:Parsing C at position 52
# DEBUG:Fragmenstein:Parsing C at position 27
# DEBUG:Fragmenstein:Parsing O at position 39
# DEBUG:Fragmenstein:Parsing C at position 47
# DEBUG:Fragmenstein:Parsing C at position 26
# DEBUG:Fragmenstein:Parsing C at position 28
# DEBUG:Fragmenstein:Parsing C at position 46
# DEBUG:Fragmenstein:Parsing N at position 55
# DEBUG:Fragmenstein:Parsing C at position 23
# DEBUG:Fragmenstein:Parsing C at position 25
# DEBUG:Fragmenstein:Parsing N at position 56
# DEBUG:Fragmenstein:Parsing C at position 57
# DEBUG:Fragmenstein:Parsing C at position 12
# DEBUG:Fragmenstein:Parsing C at position 24
# DEBUG:Fragmenstein:Parsing C at position 34
# DEBUG:Fragmenstein:Parsing C at position 13
# DEBUG:Fragmenstein:Parsing C at position 14
# DEBUG:Fragmenstein:Parsing N at position 29
# DEBUG:Fragmenstein:Parsing C at position 33
# DEBUG:Fragmenstein:Parsing F at position 2
# DEBUG:Fragmenstein:Parsing C at position 30
# DEBUG:Fragmenstein:Parsing C at position 32
# DEBUG:Fragmenstein:Parsing C at position 31
# DEBUG:Fragmenstein:Parsing H at position 58
# DEBUG:Fragmenstein:Parsing H at position 59
# DEBUG:Fragmenstein:Parsing H at position 60
# DEBUG:Fragmenstein:Parsing H at position 61
# DEBUG:Fragmenstein:Parsing H at position 80
# DEBUG:Fragmenstein:Parsing H at position 81
# DEBUG:Fragmenstein:Parsing H at position 86
# DEBUG:Fragmenstein:Parsing H at position 82
# DEBUG:Fragmenstein:Parsing H at position 84
# DEBUG:Fragmenstein:Parsing H at position 85
# DEBUG:Fragmenstein:Parsing H at position 83
# DEBUG:Fragmenstein:Parsing H at position 89
# DEBUG:Fragmenstein:Parsing H at position 90
# DEBUG:Fragmenstein:Parsing H at position 87
# DEBUG:Fragmenstein:Parsing H at position 88
# DEBUG:Fragmenstein:Parsing H at position 114
# DEBUG:Fragmenstein:Parsing H at position 110
# DEBUG:Fragmenstein:Parsing H at position 112
# DEBUG:Fragmenstein:Parsing H at position 113
# DEBUG:Fragmenstein:Parsing H at position 67
# DEBUG:Fragmenstein:Parsing H at position 111
# DEBUG:Fragmenstein:Parsing H at position 64
# DEBUG:Fragmenstein:Parsing H at position 65
# DEBUG:Fragmenstein:Parsing H at position 66
# DEBUG:Fragmenstein:Parsing H at position 104
# DEBUG:Fragmenstein:Parsing H at position 105
# DEBUG:Fragmenstein:Parsing H at position 118
# DEBUG:Fragmenstein:Parsing H at position 119
# DEBUG:Fragmenstein:Parsing H at position 121
# DEBUG:Fragmenstein:Parsing H at position 68
# DEBUG:Fragmenstein:Parsing H at position 69
# DEBUG:Fragmenstein:Parsing H at position 70
# DEBUG:Fragmenstein:Parsing H at position 71
# DEBUG:Fragmenstein:Parsing H at position 72
# DEBUG:Fragmenstein:Parsing H at position 106
# DEBUG:Fragmenstein:Parsing H at position 115
# DEBUG:Fragmenstein:Parsing H at position 116
# DEBUG:Fragmenstein:Parsing H at position 117
# DEBUG:Fragmenstein:Parsing H at position 123
# DEBUG:Fragmenstein:Parsing H at position 62
# DEBUG:Fragmenstein:Parsing H at position 63
# DEBUG:Fragmenstein:Parsing H at position 107
# DEBUG:Fragmenstein:Parsing H at position 108
# DEBUG:Fragmenstein:Parsing H at position 122
# DEBUG:Fragmenstein:Parsing H at position 98
# DEBUG:Fragmenstein:Parsing H at position 109
# DEBUG:Fragmenstein:Parsing H at position 96
# DEBUG:Fragmenstein:Parsing H at position 97
# DEBUG:Fragmenstein:Parsing H at position 99
# DEBUG:Fragmenstein:Parsing H at position 100
# DEBUG:Fragmenstein:Parsing H at position 120
# DEBUG:Fragmenstein:Parsing H at position 91
# DEBUG:Fragmenstein:Parsing H at position 92
# DEBUG:Fragmenstein:Parsing H at position 95
# DEBUG:Fragmenstein:Parsing H at position 124
# DEBUG:Fragmenstein:Parsing H at position 73
# DEBUG:Fragmenstein:Parsing H at position 93
# DEBUG:Fragmenstein:Parsing H at position 94
# DEBUG:Fragmenstein:Parsing H at position 74
# DEBUG:Fragmenstein:Parsing H at position 75
# DEBUG:Fragmenstein:Parsing H at position 76
# DEBUG:Fragmenstein:Parsing H at position 77
# DEBUG:Fragmenstein:Parsing H at position 78
# DEBUG:Fragmenstein:Parsing H at position 79
# DEBUG:Fragmenstein:Parsing H at position 101
# DEBUG:Fragmenstein:Parsing H at position 103
# DEBUG:Fragmenstein:Parsing H at position 102
# DEBUG:Fragmenstein:Filling CHI
# DEBUG:Fragmenstein:Filling BOND
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:Mol has a ring, adding a `CUT_BOND` entry (`.convert_mol`)
# DEBUG:Fragmenstein:hit0-hit1 - placing monster in structure
# DEBUG:Fragmenstein:hit0-hit1 - saving params
# DEBUG:Fragmenstein:hit0-hit1 - saving holo (unminised)
# DEBUG:Fragmenstein:hit0-hit1 - saving constraint
# DEBUG:Fragmenstein:Testing params (no saving)
# DEBUG:Fragmenstein:hit0-hit1 - saving mols from monster
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.5:  12.61800377307181 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.25:  8.780301436530502 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.125:  3.7130289819987308 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - coord_constraint lowered: 0.0625:  0.8000397420134142 kcal/mol.
# DEBUG:Fragmenstein:hit0-hit1 - Igor minimising
# DEBUG:Fragmenstein:hit0-hit1 - making ligand w/ dummy (if present)
# DEBUG:Fragmenstein:hit0-hit1 - calculating mRMSD
# INFO:Fragmenstein:hit0-hit1 - final score: -1.264974731083175 kcal/mol, RMSD: 1.3229386419923366.
# DEBUG:Fragmenstein:hit0-hit1 - saving pose from igor
# DEBUG:Fragmenstein:hit0-hit1 - calculating Gibbs
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# DEBUG:Fragmenstein:hit0-hit1 - Completed
# INFO:Fragmenstein:hit0-hit1 - Time taken: 80.87961483001709

# %%
# Assuming each list has the same length and corresponding indices
for i in range(len(minimized_smiles_list)):
    smile = minimized_smiles_list[i]
    mol_2d = mol_2d_structures[i]
    # Correctly unpack all six items from each entry in molecule_data
    mw, logp, hba, hbd, file_name = molecule_data[i][1:]  # Skipping the first item (SMILES string)

    # Print the SMILES string and Lipinski's descriptors
    print(f"Molecule {i+1}:")
    print(f"SMILES: {smile}")
    print(f"Lipinski's Descriptors: MW={mw}, LogP={logp}, HBA={hba}, HBD={hbd}")

    # Display the 2D structure
    display(MolsToGridImage([mol_2d], molsPerRow=1, subImgSize=(300, 300)))

    print("\n-----\n")

# Print the original input SMILES and their 2D structures for comparison
original_smiles = [smiles1, smiles2]  # Replace with your original SMILES strings
for smile in original_smiles:
    mol = Chem.MolFromSmiles(smile)
    print(f"Original SMILES: {smile}")
    display(MolsToGridImage([mol], molsPerRow=1, subImgSize=(300, 300)))
# Out:
# Molecule 1:
# SMILES: [H]c1nc(N([H])C(=O)C([H])([H])N2C(=O)c3c([H])nc(N4C([H])([H])C([H])([H])OC([H])([H])C4([H])[H])nc3N=C2N2C([H])([H])C([H])([H])OC([H])([H])C2([H])[H])c([H])c([H])c1Cl
# Lipinski's Descriptors: MW=486.1530788960001, LogP=0.7758000000000005, HBA=10, HBD=1
# -----
#
# Molecule 2:
# SMILES: [H]c1c([H])c(C([H])([H])N2C(=O)c3c(nc([H])n3C([H])(C([H])([H])[H])C([H])([H])[H])N(C([H])([H])C(=O)N([H])c3c([H])c([H])c(C([H])([H])[H])c([H])c3[H])C2=O)c([H])c([H])c1Br
# Lipinski's Descriptors: MW=509.1062517280001, LogP=4.756020000000005, HBA=5, HBD=1
# -----
#
# Molecule 3:
# SMILES: [H]N(C([H])([H])[H])C([H])(N([H])C([H])([H])[H])C([H])([H])N([H])C([H])([H])[C@@]1(C([H])([H])[H])OC([H])([H])[C@@]([H])(N([H])[H])[C@@]([H])(OO[C@@]2([H])N([H])C([H])([H])C([H])([H])OC2([H])[H])O1
# Lipinski's Descriptors: MW=349.23251909200087, LogP=-2.348599999999993, HBA=10, HBD=5
# -----
#
# Molecule 4:
# SMILES: [H]OC([H])([H])[C@@]([H])(N([H])[H])C([H])([H])O[C@]([H])(N([H])C(=O)C([H])([H])N(c1nc([H])n(C([H])(C([H])([H])[H])C([H])([H])[H])c1[H])[C@]1([H])C([H])([H])C([H])([H])C([H])([H])C([H])(c2nc([H])c([H])c([H])c2F)C1([H])[H])[C@]([H])(C([H])([H])C1([H])N([H])C([H])(N([H])C([H])([H])[H])N([H])C([H])([H])C1([H])C([H])([H])Oc1c([H])c(Br)c([H])c([H])c1C([H])([H])[H])C([H])([H])C([H])(C([H])([H])[H])C([H])([H])C([H])([H])[H]
# Lipinski's Descriptors: MW=871.4483419440019, LogP=5.582420000000006, HBA=12, HBD=6
# -----
#
# Molecule 5:
# SMILES: [H]OC1([H])N2SO[S@]3([H])OC([H])(N([H])[H])C([H])([H])C([H])([H])C([H])([H])C([H])([H])N([H])[C@@]3([H])C([H])([H])N(C(=O)C1([H])[H])C1([H])N3C([H])([H])C([H])([H])O[C@@]3([H])OS[C@@]([H])(C([H])([H])[H])N3C([H])([H])C([H])([H])[C@@]2([H])O[C@@]3([H])N1[H]
# Lipinski's Descriptors: MW=583.1916595240012, LogP=-0.48989999999999373, HBA=15, HBD=5
# -----
#
# Original SMILES: O=C(Cn1c(N2CCOCC2)nc2nc(N3CCOCC3)ncc2c1=O)Nc1ccc(Cl)cn1
# Original SMILES: Cc1ccc(NC(=O)Cn2c(=O)n(Cc3ccc(Br)cc3)c(=O)c3c2ncn3C(C)C)cc1

# %%
# Output all data to a CSV file
with open('all_molecule_data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['SMILES', 'Molecular Weight', 'LogP', 'HBA', 'HBD', '2D Structure File'])
    writer.writerows(molecule_data)

logging.info("All molecule data has been saved to all_molecule_data.csv")

# %%
# Victor.enable_logfile('victor_log.log', logging.INFO)
